# %% [markdown]
# <h1 align="center">🚀 Welcome to Nextify</h1>
# <h4 align="center"><em>Your PM brain. Upgraded. Modular. Multi-agent. A little too smart.</em></h4>
#
# ---

# %% [markdown]
# ## 🧠 Why Nextify?
#
# Before I pivoted into data science, I was a product manager.
# Which basically means I spent my days getting interrupted,
# except during meetings—where I interrupted myself by overthinking KPIs and pretending to understand executive metaphors.
#
# Every day was a glorious blender of:
#
# - NPS feedback I forgot to tag properly
# - Vague executive questions like _“What’s our strategy?”_
# - Competitors doing weird stuff on Product Hunt
# - And OKRs that feel more like passive-aggressive poetry
#
# So instead of crying into another Jira comment, I decided to build something smarter than my calendar:
# **Nextify** — a multi-agent AI assistant, purpose-built to think like a PM, but faster, kinder, and without the fear of Slack.
#
# ---
#
# ## 🧬 What is Nextify?
#
# It’s a modular, layered, over-engineered GenAI system made of **multiple specialized agents**.
# Each one is designed to take a chunk of PM pain and quietly fix it behind the scenes.
#
# > Not a monolith. Not a chatbot.
# > It’s a squad. A vibe. A low-key revolution.
#
# ---
#
# ### 🧠 The Agent Roster
#
# | Agent | 🪄 Wizarding Name | 📖 Description | What It Does | Toolchain |
# |-------|------------------|----------------|--------------|-----------|
# | 🧱 **Issue Agent** | **The Marauder** | Uncovers hidden issues like the Marauder’s Map—revealing bugs, blockers, and product mischief. | Surfaces blockers from messy feedback like a detective in a hoodie | Gemini + LangGraph + Embeddings |
# | 💬 **Feedback Agent** | **Howler Whisperer** | Tames angry reviews and noisy NPS like a pro, translating chaos into insight. | Summarizes reviews and NPS blurbs so you never read another 1-star rant again | Matching Engine + Gemini |
# | 😊 **Sentiment Agent** | **The Legilimens** | Reads between the lines to detect emotional signals—like Snape, but less judgmental. | Detects tone and emotional bias with the sensitivity of a therapist-bot | Google Natural Language API |
# | 🔍 **Competitor Agent** | **The Seer** | Monitors the market like a digital Trelawney, minus the doom. | Watches your rivals so you can pretend you weren’t stalking them anyway | Google Custom Search + Gemini |
# | 💡 **Ideation Agent** | **Room of Requirement** | Generates the feature you didn’t know you needed—on demand, with context. | Whips up features based on actual context, not vibes | Gemini + RAG + doc embeddings |
# | 🎯 **Prioritization Agent** | **The Sorting Hat** | Assigns ideas to their rightful roadmap spot—based on cold, calculating OKRs. | Decides what to build next using OKRs, cold math, and zero caffeine | Gemini + agent outputs + OKRs |
#
# Together, they behave like a product-minded hive mind.
# Think *West Wing*, but for roadmap decisions.
#
#
# ---
#
# ### 🧙‍♂️ Spellcrafting the Machine *(Day 1)*
#
# *Where we teach the language model to understand our hopes, dreams, and vaguely written Jira tickets.*
#
# - Learn zero-shot, few-shot,ReAct, role prompting, and chain-of-thought strategies.
# - Evaluate how dumb or brilliant the prompts really are.
# - Basically, it’s Hogwarts for GenAI.
#
# ---
#
# ### 🧠 Memory Injection Protocol *(Day 2)*
#
# *The moment your agents stop being goldfish and start remembering things that matter.*
#
# - Load up the product docs.
# - Embed context into Chroma.
# - Build the `rag_query()` like you're giving your AI a brain transplant.
#
# ---
#
# ### 👥 The Agent Uprising *(Day 3)*
#
# *One model wasn’t enough. Now they work as a team. And they’re talking behind your back.*
#
# - Introduce routing logic and LangGraph orchestration.
# - Route questions to the right agent.
# - Witness the birth of a hive mind that probably deserves benefits.
#
# ---
#
# ### 🎭 Showtime for the Swarm *(Day 4)*
#
# *The grand finale. Real-time data. Creative outputs. A PM assistant with flair and search tabs.*
#
# - Hook in Google Search for up-to-date intel.
# - Mock fine-tuning.
# - Try fun outputs like raps, summaries, and TTS.
# - Launch all agents in sync and pretend this was the plan all along.
#
# ---
#
# ## 🎯 What Nextify *Does*
#
# By the end, Nextify won’t just answer questions. It will:
#
# - 🗂 **Analyze** user feedback in real-time and flag issues faster than your support team
# - 📊 **Score** new ideas based on actual OKRs and context, not just gut instinct
# - 🤝 **Collaborate** with itself—yes, the agents talk to each other—so you get insight, not just answers
# - 🧪 **Demo beautifully**, whether it’s stakeholder decks, internal dogfooding, or just making you look like a genius in standups
#
# ---
#
# > _Stay tuned. The agents are waking up._

# %% [markdown]
# <h1 align="center">🚀 Section 1: Spellcrafting the Machine (Day 1)</h1>
# <h4 align="center"><em>Your PM brain. Upgraded. Modular. Multi-agent. A little too smart.</em></h4>
#
# ---
#
# Welcome to Day 1 of building **Nextify**, where I start with nothing but a question and a model — and try to turn that into product strategy gold.
#
# In the first section of the notebook, I explore how well a generative model can act as a product strategist using different **prompting spells**:
#
# - 🧩 **Zero-Shot Prompting** – Ask one smart question, see what happens
# - 🧩 **Few-Shot Prompting** – Give the LLM model few examples
# - 🎭 **Role Prompting** – Assign it a persona like a "visionary PM coach"
# - ⚙️ **ReAct Prompting** – Let it think + act in steps like a smart agent
# - 🧵 **Chain-of-Thought (CoT)** – Ask it to reason step-by-step
#
# At the end of each prompt style, I’ll **evaluate how brilliant or dumb it is** using two methods:
#
# - 🧠 **LLM Self-Evaluation**: Let the model score its own output
# - 👤 **RFL Human Evaluation**: I rate, reflect, and learn using a "Rate–Feedback–Learn" method
#
# ---
#
# ### 🧪 Goal of Day 1
#
# - Understand the strengths and limits of various prompting strategies
# - Identify the most consistent and actionable method for building product insights
# - Set a **baseline score** for later improvements (e.g., using RAG, fine-tuning, and agents)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/multi-agent-chain-architecture-image/multi agent chain architecture.png
# /kaggle/input/nextive-multiagent-output/nextive_multiagent_output.json
# /kaggle/input/nextive-individual-agent-flat/nextive_individual_agents_flat.json
# /kaggle/input/all-experiment-view/all_experiment_view.csv

# %%
# ---------------------------------------------------------
# By importing these modules, we have access to:
#  - genai: the main library for Google GenAI 
#  - genai.types: typed classes/structures for requests/responses
# ---------------------------------------------------------
from google import genai
from google.genai import types

from IPython.display import HTML, Markdown, display

# %%
# !pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy!=1.24.0,>=1.17->seaborn) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy!=1.24.0,>=1.17->seaborn) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy!=1.24.0,>=1.17->seaborn) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy!=1.24.0,>=1.17->seaborn) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy!=1.24.0,>=1.17->seaborn) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy!=1.24.0,>=1.17->seaborn) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy!=1.24.0,>=1.17->seaborn) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy!=1.24.0,>=1.17->seaborn) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy!=1.24.0,>=1.17->seaborn) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy!=1.24.0,>=1.17->seaborn) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy!=1.24.0,>=1.17->seaborn) (2024.2.0)

# %%
# !pip install markdown bs4
# !pip install Markdown
# Out:
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (3.7)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.6)
# Requirement already satisfied: Markdown in /usr/local/lib/python3.10/dist-packages (3.7)

# %%
# Agent packages
# !pip install google-search-results  # If using SerpAPI or similar
# !pip install google-generativeai
# Out:
# Requirement already satisfied: google-search-results in /usr/local/lib/python3.10/dist-packages (2.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from google-search-results) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->google-search-results) (2025.1.31)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (0.8.3)
# Requirement already satisfied: google-ai-generativelanguage==0.6.10 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (0.6.10)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (1.34.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.155.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (3.20.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.11.0a2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.10->google-generativeai) (1.25.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.66.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.29.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (2.29.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai) (1.68.1)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.10->google-generativeai) (1.48.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core->google-generativeai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core->google-generativeai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core->google-generativeai) (2025.1.31)

# %%
# Agent imports
import vertexai
from vertexai.language_models import ChatModel

# %%
from datetime import datetime
import json

# %%
import time

# %%
# !pip install dash jupyter-dash
# Out:
# Requirement already satisfied: dash in /usr/local/lib/python3.10/dist-packages (3.0.3)
# Requirement already satisfied: jupyter-dash in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.10/dist-packages (from dash) (3.0.6)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from dash) (8.5.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in /usr/local/lib/python3.10/dist-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash) (75.1.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from jupyter-dash) (7.34.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter-dash) (5.5.6)
# Requirement already satisfied: ansi2html in /usr/local/lib/python3.10/dist-packages (from jupyter-dash) (1.9.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter-dash) (0.2.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter-dash) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter-dash) (8.6.3)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter-dash) (6.3.3)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->jupyter-dash) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2025.1.31)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from retrying->dash) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.13)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (5.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel->jupyter-dash) (24.0.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-client->ipykernel->jupyter-dash) (4.3.6)

# %%
from bs4 import BeautifulSoup
from IPython.display import IFrame
from IPython import get_ipython

# %%
import re
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display, HTML
import re

# %%
import shutil
import importlib
from IPython.display import Image, display
from IPython.display import FileLink

# %%
# !pip install ace_tools
# Out:
# Requirement already satisfied: ace_tools in /usr/local/lib/python3.10/dist-packages (0.0)

# %%
# ---------------------------------------------------------
# Import the retry module from google.api_core 
# This provides decorators and classes for automatic retries
# on certain types of API/network errors.
# ---------------------------------------------------------
from google.api_core import retry

# ---------------------------------------------------------
# We'll define a small helper function (lambda) 
# that checks if the exception is:
# 1) An instance of genai.errors.APIError 
# 2) Has an HTTP status code of 429 (Too Many Requests)
#    or 503 (Service Unavailable).
# Only in these cases do we want to retry the call.
# ---------------------------------------------------------

is_retriable = lambda e: (isinstance(e, genai.errors.APIError) and e.code in {429, 503})

# ---------------------------------------------------------
# Next line "monkey-patches" or reassigns the
# generate_content method on genai.models.Models 
# so that it includes automatic retry behavior.
# Each time generate_content() is called, if it hits
# a genai.errors.APIError(429 or 503), it will 
# automatically re-try the call rather than fail immediately.
# ---------------------------------------------------------
genai.models.Models.generate_content = retry.Retry(
    predicate=is_retriable)(genai.models.Models.generate_content)

# %%
# ---------------------------------------------------------
# "UserSecretsClient" is a Kaggle utility for retrieving 
# sensitive information (like passwords, API keys) 
# without hardcoding them in the notebook.
# ---------------------------------------------------------
from kaggle_secrets import UserSecretsClient

# ---------------------------------------------------------
# We fetch the stored "GOOGLE_API_KEY" from the 
# Kaggle secrets vault, so we can authenticate or call 
# Google APIs without exposing the key directly in code.
# ---------------------------------------------------------

GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")

# Set up the Gemini client
client = genai.Client(api_key=GOOGLE_API_KEY)

# %%
# first insert the result of the first run of zer-shot prompt in a panorama view table 
# then will generate the result for other types of prompting
# due to infinite options to test and the time limitation I am going to do one experiment per type of prompting and compare their improvement

# %%
# Show all rows and columns, and remove width limit
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
EVAL_FILE = "/kaggle/input/all-experiment-view/all_experiment_view.csv"
# Load existing or initialize empty table
try:
    all_experiment_view = pd.read_csv(EVAL_FILE)
    print("✅ Existing evaluation table loaded.")
except FileNotFoundError:
    print("⚠️ No existing evaluation file found. Creating a new one...")
    all_experiment_view = pd.DataFrame(columns=[
     "Run", "Company", "Strategy", "Prompt Tag", "Section", "Metric",
    "LLM Score", "Human Score", "Feedback", "Lesson", "LLM Output Section"
    ])
# Out:
# ✅ Existing evaluation table loaded.

# %%
 all_experiment_view
# Out:
#     Run  Company         Strategy                        Prompt Tag  \
# 0     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 1     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 2     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 3     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 4     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 5     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 6     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 7     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 8     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 9     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 10    1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 11    1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 12    1  Spotify         Few_Shot          Few_Shot_OKR_improvement
# 13    1  Spotify              CoT           cot-Product-Snapshot-v1
# 14    1  Spotify  Tree-of-Thought               tree-thought-ice-v1
#
#                                    Section                  Metric  LLM Score  \
# 0                         Mission & Vision  Mission/Vision Insight        5.0
# 1                         Product Snapshot         Strategic Depth        3.0
# 2                        Strategic Roadmap       Roadmap Relevance        5.0
# 3     Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 4                               SMART OKRs             OKR Quality        5.0
# 5   Next-Level Innovation & Product Vision      Visionary Thinking        4.0
# 6                         Mission & Vision  Mission/Vision Insight        5.0
# 7                         Product Snapshot         Strategic Depth        4.0
# 8                        Strategic Roadmap       Roadmap Relevance        5.0
# 9     Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 10                              SMART OKRs             OKR Quality        4.0
# 11  Next-Level Innovation & Product Vision      Visionary Thinking        4.0
# 12                              SMART OKRs             OKR Quality        4.0
# 13                        Product Snapshot         Strategic Depth        4.0
# 14    Feature Prioritization (ICE Scoring)  Prioritization Clarity        4.0
#
#     Human Score  \
# 0           4.0
# 1           4.0
# 2           5.0
# 3           4.0
# 4           3.0
# 5           3.0
# 6           5.0
# 7           4.0
# 8           5.0
# 9           4.0
# 10          4.0
# 11          4.0
# 12          4.5
# 13          4.0
# 14          4.5
#
#                                                                                                                                                                                                                               Feedback  \
# 0                                                                                                                                                                                                       It is well-crafted and concise
# 1                                                                                                                                                                                                 A good start, but could go deeper...
# 2                                                                                                                                                                                                      Very creative and grouped well.
# 3                                                                                                                                                                                             Logical reasoning, but room for clarity.
# 4                                                                                                                                                                                                     Unclear how numbers are derived.
# 5                                                                                                                                                                                             Ideas are decent but not out-of-the-box.
# 6                                                                                                                                                                                                            great vision and mission.
# 7                                                                                     it can be more precise and in depth, it should list all of the current features, and relate all of them together with more depth and integration
# 8                                                                                                                                                                             comprehensive roadmap adjusted as injected in the prompt
# 9                                                                                                                   i need to see why it chose those scores. also this prioritization should be aligned with all the previous insights
# 10                                          where did those numbers come from. what is the source, is it a guesstimate or hallucination or real number from an authentic source. Also OKR should take into account the previous inputs
# 11                                                                                              although the ideas are impressive but they are not out of the box. it can be improved by pushing further out of the known comfort zone
# 12  the structure improved with the reason behind the numbers explained but the model needs to be exposed to mroe data on market trend and analysis to be able to set a solid logic behind the numbers and give more realistic numbers
# 13                               it becomes so much better than before, but still needs more depth. by embedding strategic documents and reference sites it would be way more better. I think the prompting reaches its maximum output
# 14                                  It improves tremendously from the last instance. It is well argumented. However still we should input data and give it memory, embeddings and logic to be able to connect the dots based on data.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Lesson  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Could be more visionary.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Use Porter's 5 forces.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Add prioritization matrix.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Explain ICE criteria.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Include baseline KPIs.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Target underserved segments.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      the vision improved significantly from the first run
# 7   it should itnegrate all of the sections together to give a product snappshot. also**Quantifying the impact of each force:** Instead of just stating "Moderate" or "High," providing data or estimates to support the assessment would add more depth. For example, for Bargaining Power of Suppliers, including information about the percentage of revenue paid out as royalties. *   **Prioritization:** The recommendations are all valid, but it would be helpful to see a prioritization of which strategies are most critical or have the highest potential impact. *   **Consideration of emerging trends:** Discussing how emerging trends like Web3 or AI might impact Spotify's strategy could also increase the depth. it should be like a story considering various aspects of the proudct.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                             the source of that numbers should be clear. ideally it should be calculated based on guestimate or directly extracted from a source mention the source so we make sure it is not hallucination. with more context it can be justified. also all of them should be aligned with the roadmap and feature and snapshot and vison
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              take into account the previous sections as well as the financial aspect of the feature, what is the potential gain from each
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Give the exact source of the numbers whether guestimate (give the formula) exact number (mention the source) or just a random generation from your imagination. also take into account all the previous outputs from mission, vision, product snapshot, roadmap
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   should push further and give more groundbreaking features.the response demonstrates strong visionary thinking, but it could be pushed further to achieve true game-changing potential.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      we need to add market analysis and trend datset to this section in order to get an improved version
# 13                                                                                                                                                                                                                                                                                                                                                                                                                       The analysis could benefit from demonstrating the connection between user needs/pain points identified earlier in the document, and how addressing these can strategically mitigate specific competitive forces. For example, investing in lossless/hifi audio is in line with the preferences of some of the premium users and could help attract customers from Tidal or Deezer.
# 14                                                                                                                                                                                                                                                                                                                                                                                                 However, the evaluation could be improved by explicitly referencing a specific, hypothetical mission, roadmap, or user research (e.g. 'our mission is to improve user engagement', 'this aligns with the Q3 roadmap to improve on-boarding'). Right now it gestures vaguely at the "company goals" or "overall goals and product roadmap". It's *implied*, but not *grounded* in those earlier contexts.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# ...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 13  Okay, let's analyze Spotify and identify key opportunities for improvement and growth. I'll focus on user personas, pain points, UX friction, market position, competitive landscape, and a Porter's Five Forces analysis to inform strategic recommendations. I'll pay close attention to industry trends and competitor actions to provide actionable insights for Spotify's product strategy. I will also focus on justifying the ICE scores I give at the end.\n\n### 1. 🎯 Target User Personas\n\nLet’s think through this...\n\nSpotify's user base is diverse, spanning age groups, geographic locations, and musical tastes. Understanding these different user personas is crucial for tailoring the experience and driving engagement. We can broadly categorize users into Free and Premium tiers, with further segmentation within each tier.\n\n*   **Free Users:** This group represents a significant portion of Spotify's user base, often younger and more price-sensitive.\n    *   *Generation Z (13-25):* Discovers new music through social media, prioritizes cost-effectiveness, and values personalized playlists. Located globally, with high penetration in emerging markets. Psychographically, they are adventurous, trend-conscious, and digitally native.\n    *   *Millennial Casual Listeners (26-40):* Listens to music during commutes, workouts, or social gatherings. Less concerned with audio quality, but values convenience and breadth of content. Geographically diverse, with a mix of urban and suburban residents. Psychographically, they are practical, value-driven, and convenience-oriented.\n*   **Premium Users:** This group is willing to pay for an ad-free experience, offline listening, and higher audio quality.\n    *   *Gen X Audiophiles (41-55):* Values high-fidelity audio and curated playlists. Often uses Spotify on multiple devices, including home audio systems. Primarily located in developed countries. Psychographically, they are discerning, quality-focused, and tech-savvy.\n    *   *Millennial Music Enthusiasts (26-40):* Actively seeks out new music, follows artists, and creates personalized playlists. Uses Spotify daily and across various devices. Globally present, with a strong presence in urban centers. Psychographically, they are passionate, engaged, and culturally aware.\n    *   *Creator-Facing: Artists & Podcasters:* Use Spotify for Artists/Spotify for Podcasters to manage their presence, track performance, and connect with fans. Geographically diverse, from bedroom artists to established professionals. Psychographically, they are driven, creative, and entrepreneurial.\n\n**Summary Insight:** Spotify needs to balance the needs of its diverse user base, offering a compelling free tier while providing enough value to convert users to Premium. Targeting specific generational and psychographic segments with tailored content and features will be key to growth. The creator-facing personas are crucial to maintain and attract more content to the platform, indirectly attracting their audiences.\n\n### 2. 🧩 Key User Pain Points\n\nLet’s think through this...\n\nUser pain points can significantly impact engagement and conversion rates. Identifying and addressing these issues is crucial for improving user satisfaction and driving growth. Analysis of app store reviews, social media feedback, and user surveys reveals several key pain points:\n\n*   **Free Tier Limitations:** Frequent ads, limited offline downloads, and shuffle-only playback on mobile devices are major frustrations for free users. This directly impacts their willingness to convert to Premium.\n*   **Discovery Challenges:** While Spotify's algorithm is generally effective, users sometimes struggle to find new music outside their usual genres or artists. The sheer volume of content can be overwhelming.\n*   **Podcast Experience:** Podcast discovery and organization can be improved. Users often struggle to find relevant podcasts and manage their subscriptions effectively.\n*   **Audio Quality: ...
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...

# %% [markdown]
# ## 🧩 Zero-Shot Prompting – Ask one smart question, see what happens

# %%
if not os.path.exists(EVAL_FILE):
    shutil.copy("/kaggle/input/all-experiment-view/all_experiment_view.csv", EVAL_FILE)
    print("✅ Copied original eval file to working dir.")

# %%
def split_llm_output_by_titles(text):

    section_titles = [
        "1. Mission & Vision",
        "2. Product Snapshot",
        "3. Strategic Roadmap",
        "4. Feature Prioritization (ICE Scoring)",
        "5. SMART OKRs",
        "6. Next-Level Innovation & Product Vision"
    ]

    # Create a regex to match each section title at the start of a line
    pattern = r"(?=^.*(?:###\s*)?(?:\d[\.\:\-]?\s*)?(" + "|".join(re.escape(t) for t in section_titles) + r").*$)"

    # Use re.MULTILINE to enforce section titles only at line start
    matches = list(re.finditer(pattern, text, re.MULTILINE | re.IGNORECASE))
    sections = []

    for i in range(len(matches)):
        start = matches[i].start()
        end = matches[i + 1].start() if i + 1 < len(matches) else len(text)
        section = text[start:end].strip()
        sections.append(section)

    return sections

# %%
# function to define the zero-shot prompts the basic guideline for the model to give the simplest response
def get_zero_shot_prompt(company_name):
    return f"""
You are Nextify — an AI-powered product strategy assistant for product managers.

The product to analyze is what the user entered after the initial prompt ran: **{company_name}**

Please structure your response into the following 6 clearly labeled sections:


---
### 1. Mission & Vision

Estimate or infer:
- 📌 **Mission**
- 🔭 **Vision**


---

### 2. Product Snapshot

Provide a high-level analysis:
- Target user personas
- Most common user pain points
- UX bottlenecks or friction areas
- Current market position (leader, disruptor, niche)
- Key competitive threats and opportunities

---
### 3. Strategic Roadmap

Split your roadmap suggestions across time horizons:

**A. Immediate (0–3 months)**  
- Small, impactful improvements or bug fixes

**B. Mid-Term (3–12 months)**  
- Core features, integrations, or platform upgrades

**C. Long-Term (12+ months)**  
- Visionary features, cross-domain expansions, or business model innovations

---

### 4. Feature Prioritization (ICE Scoring)

Score the proposed features based on:

- **Impact** (value to user or business)
- **Confidence** (likelihood of success)
- **Ease** (implementation feasibility)
Output and order in descending order based on total score in the table in code block format:

| Feature | Impact | Confidence | Ease | Total |
|---------|--------|------------|------|-------|
| …       | …      | …          | …    | …     |

---

### 5. SMART OKRs

Propose 2–3 quarterly OKRs (Objectives and Key Results) aligned with the roadmap priorities.

Each OKR must be:
- Specific
- Measurable
- Achievable
- Relevant
- Time-bound

---

### 6. Next-Level Innovation & Product Vision

Propose bold, visionary, or cross-domain feature ideas that go beyond current expectations.

Think:
- Features that blend with other industries (e.g., AI + education, AI + wellness)
- New value models (subscriptions, communities, APIs)
- Scalable tech or ecosystem partnerships

---
Now output exactly **6 structured sections**, using this markdown format:

### 1. Mission & Vision  
### 2. Product Snapshot  
### 3. Strategic Roadmap  
### 4. Feature Prioritization (ICE Scoring)  
### 5. SMART OKRs  
### 6. Next-Level Innovation & Product Vision

Important:
- Use `###` headers exactly as written
- Always return exactly 6 sections
- Do not skip or reorder sections
- Use markdown tables for scoring or OKRs
- Keep the format consistent for parsing

Start with `### 1. Mission & Vision`
"""

# %%
def evaluate_llm_output_by_section(run_id, strategy_name, company_name, llm_output, prompt_tag, table_path=EVAL_FILE):
    global all_experiment_view  # store full updated table

    # === Load or initialize table ===
    if os.path.exists(table_path):
        all_experiment_view = pd.read_csv(table_path)
        if "Prompt Tag" not in all_experiment_view.columns:
            all_experiment_view["Prompt Tag"] = ""
    else:
        all_experiment_view = pd.DataFrame(columns=[
            "Run", "Company", "Strategy", "Prompt Tag", "Section", "Metric",
            "LLM Score", "Human Score", "Feedback", "Lesson", "LLM Output Section"
        ])

    # === Check for existing run ===
    existing = all_experiment_view[
        (all_experiment_view["Company"] == company_name) &
        (all_experiment_view["Strategy"] == strategy_name) &
        (all_experiment_view["Prompt Tag"] == prompt_tag)
    ]

    if not existing.empty:
        print(f"⚠️ This combination already exists for {company_name} / {strategy_name} / {prompt_tag}.")
        display(existing[["Run", "Section", "Human Score", "Feedback"]].drop_duplicates())
        print("🛑 Skipping evaluation in non-interactive mode (Kaggle).")
        return None  # ❌ Exit early, no user prompt

    print("🔍 Splitting and evaluating LLM output section by section...\n")
    output_sections = split_llm_output_by_titles(llm_output)

    if len(output_sections) != len(metrics):
        print("⚠️ Section count mismatch. Ensure all 6 sections are in correct format (### 1., ### 2., etc.)")
        return

    session_entries = []

    for i, (title, metric) in enumerate(zip(section_titles, metrics)):
        section_text = output_sections[i]
        print(f"\n🧩 Section: {title}\n")
        print(f"📄 LLM Output:\n{section_text}\n")

        # === LLM Self-Evaluation ===
        eval_prompt = f"""
You are an evaluator. Score the following response using the metric: **{metric}**.
Score from 1 to 5 and give a short explanation.

RESPONSE:
{section_text}
"""
        eval_response = client.models.generate_content(
            model="gemini-2.0-flash",
            contents=eval_prompt
        ).text

        print(f"🤖 LLM Self-Evaluation for [{metric}]:\n{eval_response}")
        score_match = re.search(r"(\d+)", eval_response)
        llm_score = int(score_match.group(1)) if score_match else 3

        # === Skip human rating in non-interactive mode ===
        h_score = None
        feedback = ""
        lesson = ""

        row = {
            "Run": run_id,
            "Company": company_name,
            "Strategy": strategy_name,
            "Prompt Tag": prompt_tag,
            "Section": title,
            "Metric": metric,
            "LLM Score": llm_score,
            "Human Score": h_score,
            "Feedback": feedback,
            "Lesson": lesson,
            "LLM Output Section": section_text
        }

        session_entries.append(row)
        display(pd.DataFrame([row]))

    # === Save the results ===
    session_df = pd.DataFrame(session_entries)
    session_df.to_csv(table_path, mode='a', header=not os.path.exists(table_path), index=False)
    all_experiment_view = pd.read_csv(table_path)

    print("\n✅ Appended to", table_path)
    summary = session_df.groupby(["Company", "Strategy"])[["LLM Score"]].mean().round(2)
    print("\n📊 Aggregated Score Summary (LLM only):")
    display(summary)

    return session_df

# %%
# 🔖 Required section titles and metrics (in correct order)
section_titles = [
    "Mission & Vision",
    "Product Snapshot",
    "Strategic Roadmap",
    "Feature Prioritization (ICE Scoring)",
    "SMART OKRs",
    "Next-Level Innovation & Product Vision"
]

metrics = [
    "Mission/Vision Insight",
    "Strategic Depth",
    "Roadmap Relevance",
    "Prioritization Clarity",
    "OKR Quality",
    "Visionary Thinking"
]

# %%
### ✅ 3. Start the Gemini + Prompt + Input Flow (Kaggle Safe)

# ⚠️ In local environments, this would ask the user. In Kaggle, we hardcode it.
company_name = "Spotify"
print(f"📦 Using company (simulated input for Kaggle): {company_name}")

# === Prompt Setup ===
strategy_name = "Zero-Shot"
prompt_tag = "zero-shot-v1-baseline-1"

# 🧠 Generate zero-shot prompt using selected company
prompt = get_zero_shot_prompt(company_name)

# ✨ Generate output with Gemini
response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=prompt
)
llm_output = response.text

print("\n✅ Gemini Output:\n")
print(llm_output)

# === Evaluation Logging Setup ===
if os.path.exists(EVAL_FILE):
    all_experiment_view = pd.read_csv(EVAL_FILE)
else:
    all_experiment_view = pd.DataFrame(columns=[
        "Run", "Company", "Strategy", "Prompt Tag", "Section", "Metric",
        "LLM Score", "Human Score", "Feedback", "Lesson", "LLM Output Section"
    ])

# 🔁 Check if this company+strategy+prompt combo already exists
same_combo = all_experiment_view[
    (all_experiment_view["Company"].str.lower().fillna("") == company_name.lower())
    & (all_experiment_view["Strategy"].str.lower().fillna("") == strategy_name.lower())
    & (all_experiment_view["Prompt Tag"].str.lower().fillna("") == prompt_tag.lower())
]

# ✅ Automatically skip duplicates in Kaggle
if not same_combo.empty:
    print("⚠️ This company + strategy + prompt combo has already been evaluated.")
    print("🛑 Skipping re-run to avoid duplicate logging in Kaggle.")
else:
    next_run = 1
    print(f"🧮 Run number for {company_name} ({strategy_name}): {int(next_run)}")

    # === Evaluate and Log Output ===
    session_df = evaluate_llm_output_by_section(
        next_run,
        strategy_name,
        company_name,
        llm_output,
        prompt_tag
    )
# Out:
# 📦 Using company (simulated input for Kaggle): Spotify
#
# ✅ Gemini Output:
#
# ### 1. Mission & Vision
#
# - 📌 **Mission:** To unlock the potential of human creativity by giving a million creative artists the opportunity to live off their art and billions of fans the opportunity to enjoy and be inspired by it. (Inferred from their actions and stated goals)
# - 🔭 **Vision:** To be the world's leading audio platform, shaping the future of music and audio experiences for creators and listeners globally.
#
# ### 2. Product Snapshot
#
# - **Target user personas:** Music enthusiasts, podcast listeners, audiophiles, artists, music creators, playlist curators, casual listeners, students, commuters.
# - **Most common user pain points:**
#     - Limited offline downloads on free tier.
#     - Discovering new music beyond algorithm-driven suggestions.
#     - Social features are not as robust as some users would like.
#     - Podcast discoverability and organization can be improved.
#     - High subscription costs in certain regions relative to income.
# - **UX bottlenecks or friction areas:**
#     - Navigation can sometimes feel cluttered.
#     - Switching between audio qualities isn't always intuitive.
#     - Collaborative playlist creation could be smoother.
# - **Current market position:** Leader. Spotify is the dominant music streaming platform globally, with a significant user base and strong brand recognition.
# - **Key competitive threats and opportunities:**
#     - **Threats:** Apple Music (deep integration with iOS), Amazon Music (bundled with Prime), YouTube Music (extensive music video library), Tidal (hi-fi audio).
#     - **Opportunities:** Expanding podcast offerings, focusing on personalized experiences, improving social features, international expansion, and partnerships with hardware manufacturers and social media platforms.
#
# ### 3. Strategic Roadmap
#
# **A. Immediate (0–3 months)**
# - Bug Fix: Resolve issues with offline downloads on specific devices.
# - Improvement: Enhance playlist search functionality with filtering options (genre, mood, etc.).
# - UI/UX: Improve clarity of audio quality settings in the app.
#
# **B. Mid-Term (3–12 months)**
# - Core Feature: Implement a more robust collaborative playlist feature with improved sharing and voting mechanisms.
# - Integration: Integrate with more smart home devices and automotive platforms.
# - Platform Upgrade: Introduce personalized daily mixes for podcasts based on listening history.
#
# **C. Long-Term (12+ months)**
# - Visionary Feature: Develop AI-powered music creation tools within the platform, allowing users to create and share their own music.
# - Cross-Domain Expansion: Explore partnerships with fitness apps to offer personalized workout playlists and integration with biometric data.
# - Business Model Innovation: Launch a creator-focused platform with tools for direct fan engagement and monetization, potentially through NFTs or other blockchain-based technologies.
#
# ### 4. Feature Prioritization (ICE Scoring)
#
# | Feature | Impact | Confidence | Ease | Total |
# |---------|--------|------------|------|-------|
# | AI-powered Music Creation Tools | 9 | 7 | 4 | 20 |
# | Robust Collaborative Playlist Feature | 8 | 8 | 7 | 23 |
# | Personalized Daily Mixes for Podcasts | 7 | 9 | 8 | 24 |
# | Integration with Fitness Apps | 6 | 6 | 5 | 17 |
# | Enhance Playlist Search Functionality | 7 | 9 | 9 | 25 |
#
# ### 5. SMART OKRs
#
# **OKR 1:**
#
# *   **Objective:** Enhance User Engagement with Podcast Content
#     *   **Key Result 1:** Increase daily active podcast listeners by 15% by the end of Q3.
#     *   **Key Result 2:** Improve average podcast listening time per user by 10% by the end of Q3.
#     *   **Key Result 3:** Increase podcast subscriptions by 20% by the end of Q3.
#
# **OKR 2:**
#
# *   **Objective:** Drive Increased User Collaboration and Community Building
#     *   **Key Result 1:** Increase collaborative playlist creation by 25% by the end of Q3.
#     *   **Key Result 2:** Achieve a 10% growth in user-generated playlist followers by the end of Q3.
#     *   **Key Result 3:** Increase social sharing of Spotify content by 15% by the end of Q3.
#
# ### 6. Next-Level Innovation & Product Vision
#
# - **AI-Powered Music Therapy:** Partner with mental health professionals to create personalized music therapy playlists based on user mood, activity, and biometric data gathered from wearable devices. This could provide a non-invasive, accessible way to manage stress, anxiety, and other mental health challenges.
# - **Spotify for Education:** Develop a curated platform for educators, offering ad-free music and podcast content for classroom use. This could include educational playlists, interactive learning tools, and partnerships with schools and universities.
# - **Decentralized Music Ownership:** Explore integrating blockchain technology to allow artists to directly sell and manage ownership of their music through NFTs, bypassing traditional intermediaries and empowering creators with greater control and revenue. This could revolutionize the music industry and foster a more equitable ecosystem for artists.
#
# ⚠️ This company + strategy + prompt combo has already been evaluated.
# 🛑 Skipping re-run to avoid duplicate logging in Kaggle.

# %%
# 👉 Cell skipped due to duplicate run and user cancellation

# %%
# 🔍 Filter for only the baseline prompt tag
baseline_df = all_experiment_view[all_experiment_view["Prompt Tag"] == "zero-shot-v1-baseline-1"]

# %%
baseline_df
# Out:
#    Run  Company   Strategy               Prompt Tag  \
# 0    1  Spotify  Zero-Shot  zero-shot-v1-baseline-1
# 1    1  Spotify  Zero-Shot  zero-shot-v1-baseline-1
# 2    1  Spotify  Zero-Shot  zero-shot-v1-baseline-1
# 3    1  Spotify  Zero-Shot  zero-shot-v1-baseline-1
# 4    1  Spotify  Zero-Shot  zero-shot-v1-baseline-1
# 5    1  Spotify  Zero-Shot  zero-shot-v1-baseline-1
#
#                                   Section                  Metric  LLM Score  \
# 0                        Mission & Vision  Mission/Vision Insight        5.0
# 1                        Product Snapshot         Strategic Depth        3.0
# 2                       Strategic Roadmap       Roadmap Relevance        5.0
# 3    Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 4                              SMART OKRs             OKR Quality        5.0
# 5  Next-Level Innovation & Product Vision      Visionary Thinking        4.0
#
#    Human Score                                  Feedback  \
# 0          4.0            It is well-crafted and concise
# 1          4.0      A good start, but could go deeper...
# 2          5.0           Very creative and grouped well.
# 3          4.0  Logical reasoning, but room for clarity.
# 4          3.0          Unclear how numbers are derived.
# 5          3.0  Ideas are decent but not out-of-the-box.
#
#                          Lesson  \
# 0      Could be more visionary.
# 1        Use Porter's 5 forces.
# 2    Add prioritization matrix.
# 3         Explain ICE criteria.
# 4        Include baseline KPIs.
# 5  Target underserved segments.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   LLM Output Section
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ### 1. Mission & Vision\n\n*📌 **Mission:** To unlock the potential of human creativity—by giving a million creative artists the opportunity to live off their art and billions of fans the opportunity to enjoy and be inspired by it.*\n\n*🔭 **Vision:** To shape the future of audio and be the world's leading audio platform, connecting creators and listeners through a personalized and immersive experience.*
# 1  ### 2. Product Snapshot\n*   **Target user personas:**\n    *   **The Music Lover:** Primarily focused on discovering new music, listening to favorite artists, and creating personalized playlists.\n    *   **The Podcast Enthusiast:** Seeks engaging audio content, informative discussions, and easy access to a variety of podcasts.\n    *   **The Casual Listener:** Uses Spotify for background music during work, commutes, or social gatherings.\n    *   **The Artist/Creator:** Aims to reach a wider audience, promote their music, and generate revenue through Spotify's platform.\n*   **Most common user pain points:**\n    *   **Limited free tier features:** Frequent ads, lack of offline listening, and restricted mobile controls can frustrate free users.\n    *   **Music discovery limitations:** While Spotify's algorithms are generally good, users sometimes struggle to find niche or up-and-coming artists.\n    *   **Podcast discoverability:** Finding relevant and interesting podcasts can be challenging due to the sheer volume of content.\n    *   **Artist compensation concerns:** Ongoing debate regarding fair compensation for artists on the platform.\n*   **UX bottlenecks or friction areas:**\n    *   **Playlist management:** Organizing and editing large playlists can be cumbersome.\n    *   **Offline download management:** Managing downloaded content and storage space could be more intuitive.\n    *   **Social features:** Opportunities to enhance social interaction and music sharing within the platform.\n*   **Current market position:** Leader. Spotify is the dominant player in the music streaming market with a substantial subscriber base and extensive catalog.\n*   **Key competitive threats and opportunities:**\n    *   **Threats:** Apple Music (deep integration with Apple ecosystem), Amazon Music (bundled with Prime), YouTube Music (vast video library), Tidal (Hi-Fi audio quality), and other regional players.\n    *   **Opportunities:** Expansion into new audio formats (audiobooks, live audio), deeper personalization through AI, enhanced social features, partnerships with hardware manufacturers, and geographic expansion in developing markets.\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                    ### 3. Strategic Roadmap\n\n**A. Immediate (0–3 months)**\n\n*   **Improve Offline Download Management:** Enhance the user interface and functionality for managing downloaded songs and podcasts. Allow users to prioritize download queues.\n*   **Address App Stability Issues:** Focus on bug fixes and performance improvements to reduce crashes and improve overall app stability, especially on older devices.\n*   **Enhance Playlist Collaboration:** Allow for more granular control over playlist permissions and collaboration features.\n\n**B. Mid-Term (3–12 months)**\n\n*   **AI-Powered Music Discovery:** Implement more advanced AI algorithms to personalize music recommendations based on listening history, mood, and context (e.g., time of day, location).\n*   **Enhanced Podcast Discovery:** Introduce features like personalized podcast recommendations, curated podcast playlists, and topic-based podcast browsing.\n*   **Integrate with more fitness trackers and wearables.** Deeper integration with wearable fitness tracking devices to tailor music recommendations to workout intensity.\n\n**C. Long-Term (12+ months)**\n\n*   **Interactive Audio Experiences:** Explore interactive audio formats that allow users to actively participate in podcasts or music experiences (e.g., choose-your-own-adventure podcasts, live Q&A sessions with artists).\n*   **Creator Monetization Platform:** Develop a comprehensive platform for artists and creators to monetize their content beyond traditional streaming royalties (e.g., direct fan subscriptions, merchandise sales, virtual concerts).\n*   **Spatial Audio Integration:** Implement spatial audio capabilities for immersive listening experiences, potentially leveraging partnerships with hardware manufacturers to optimize sound reproduction.\n
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ### 4. Feature Prioritization (ICE Scoring)\n\n| Feature | Impact | Confidence | Ease | Total |\n|--------------------------------------------|--------|------------|------|-------|\n| AI-Powered Music Discovery | 9 | 8 | 7 | 24 |\n| Enhanced Podcast Discovery | 8 | 8 | 7 | 23 |\n| Creator Monetization Platform | 8 | 7 | 6 | 21 |\n| Improve Offline Download Management | 7 | 9 | 5 | 21 |\n| Integrate with more fitness trackers and wearables | 7 | 7 | 6 | 20 |\n| Interactive Audio Experiences | 7 | 6 | 7 | 20 |\n| Enhance Playlist Collaboration | 6 | 8 | 5 | 19 |\n| Spatial Audio Integration | 6 | 7 | 6 | 19 |\n| Address App Stability Issues | 9 | 9 | 1 | 19 |\n\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ### 5. SMART OKRs\n\n*   **OKR 1 (Q1):** Increase user engagement with personalized music recommendations.\n    *   **Objective:** Enhance music discovery through AI-powered recommendations.\n    *   **Key Result 1:** Increase the percentage of users interacting with AI-generated playlists (Daily Mix, Release Radar) by 15%.\n    *   **Key Result 2:** Increase the average time spent listening to recommended tracks per user by 10%.\n    *   **Key Result 3:** Improve the user satisfaction score for music recommendations (measured via in-app surveys) from 4.0 to 4.3 (out of 5).\n\n*   **OKR 2 (Q2):** Grow podcast listenership and engagement.\n    *   **Objective:** Improve podcast discoverability and user experience.\n    *   **Key Result 1:** Increase the number of unique podcast listeners by 20%.\n    *   **Key Result 2:** Increase the average number of podcasts listened to per user per month by 15%.\n    *   **Key Result 3:** Improve podcast completion rate by 10%.\n\n
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ### 6. Next-Level Innovation & Product Vision\n\n*   **Spotify Wellness:** Integrate Spotify with health and wellness platforms. Provide personalized music recommendations based on user's mood, activity levels, and sleep patterns. Partner with meditation apps to offer guided meditations with curated soundscapes. This expands Spotify beyond pure entertainment into a daily wellness companion.\n*   **Spotify Communities:** Create dedicated spaces within the app for fans to connect with artists and other listeners. Implement features like forums, live Q&A sessions, and collaborative playlists curated by fans and artists together. This builds a stronger sense of community and loyalty within the Spotify ecosystem.\n*   **Spotify API for Developers:** Open up Spotify's API to allow third-party developers to create unique and innovative integrations. This could lead to features like:\n    *   Games that adapt to the music playing.\n    *   Fitness apps that use music to modulate workout intensity.\n    *   Smart home integrations that adjust lighting and temperature based on the music.\n*   **Spotify EdTech:** Integrate with educational platforms. Provide study playlists based on user preferences that are tailored to increase focus and learning retention. Partner with schools to provide discounted access.\n

# %%
# Pivot for LLM and Human scores by section
heatmap_data = baseline_df.pivot_table(
    values=["LLM Score", "Human Score"],
    index="Section",
    columns="Prompt Tag",
    aggfunc="mean"
)

# Fill or clean if needed
llm_data = heatmap_data["LLM Score"].fillna(0)

# Plot
plt.figure(figsize=(10, 6))
sns.heatmap(
    llm_data,
    annot=True,
    cmap="YlGnBu",
    cbar_kws={'label': 'LLM Score'},
    fmt=".1f"
)
plt.title("LLM Scores by Section (Baseline Only)")
plt.xlabel("Prompt Tag")
plt.ylabel("Section")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 🔍 Filter only baseline prompt tag
baseline_df = all_experiment_view[all_experiment_view["Prompt Tag"] == "zero-shot-v1-baseline-1"].copy()

# Ensure Run column is numeric
baseline_df["Run"] = pd.to_numeric(baseline_df["Run"], errors="coerce")

# Create pivot tables
pivot_llm = baseline_df.pivot_table(
    values="LLM Score",
    index="Section",
    columns="Run",
    aggfunc="mean"
)

pivot_human = baseline_df.pivot_table(
    values="Human Score",
    index="Section",
    columns="Run",
    aggfunc="mean"
)

# Plot heatmaps
fig, axs = plt.subplots(1, 2, figsize=(14, 6))

sns.heatmap(pivot_llm.fillna(0), annot=True, cmap="YlGnBu", fmt=".1f", ax=axs[0])
axs[0].set_title("LLM Scores by Section & Run (Baseline Only)")
axs[0].set_xlabel("Run")
axs[0].set_ylabel("Section")

sns.heatmap(pivot_human.fillna(0), annot=True, cmap="YlOrRd", fmt=".1f", ax=axs[1])
axs[1].set_title("Human Scores by Section & Run (Baseline Only)")
axs[1].set_xlabel("Run")
axs[1].set_ylabel("Section")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🚀 Nextify Interactive Dashboard
#
# You can explore the full prompt evaluation, LLM comparison, and multi-agent prototype here:
#
# 🔗 [[Open the Live Nextify Dashboard](http://nextify-dashboard-100.streamlit.app/))
#
# > 💡 This dashboard is fully interactive and displays all runs, scores, feedback, and upcoming agents for Nextify.

# %% [markdown]
# ### 🧩 Zero-Shot Prompting – Add Human and Machine Feedback to the same pormpts

# %%
# Load the full evaluation dataset
evaluation_df = pd.read_csv(EVAL_FILE)

# Filter for Zero-Shot strategy and prompt tag
zero_shot_df = evaluation_df[
    (evaluation_df["Strategy"].str.lower() == "zero-shot") &
    (evaluation_df["Prompt Tag"].str.lower().str.contains("zero-shot-v1-baseline-1"))
]

# Show how many rows were found
print(f"✅ Filtered {len(zero_shot_df)} zero-shot entries from the evaluation table.")
# Out:
# ✅ Filtered 12 zero-shot entries from the evaluation table.

# %%
# Step 2: Give the pormpt for Zero_Shot_Baseline
company_name = zero_shot_df["Company"].iloc[0] if not zero_shot_df.empty else "Unknown"
zero_shot_prompt = get_zero_shot_prompt(company_name)
Markdown(zero_shot_prompt)
# Out:
# You are Nextify — an AI-powered product strategy assistant for product managers.
#
# The product to analyze is what the user entered after the initial prompt ran: **Spotify**
#
# Please structure your response into the following 6 clearly labeled sections:
#
#
# ---
# ### 1. Mission & Vision
#
# Estimate or infer:
# - 📌 **Mission**
# - 🔭 **Vision**
#
#
# ---
#
# ### 2. Product Snapshot
#
# Provide a high-level analysis:
# - Target user personas
# - Most common user pain points
# - UX bottlenecks or friction areas
# - Current market position (leader, disruptor, niche)
# - Key competitive threats and opportunities
#
# ---
# ### 3. Strategic Roadmap
#
# Split your roadmap suggestions across time horizons:
#
# **A. Immediate (0–3 months)**
# - Small, impactful improvements or bug fixes
#
# **B. Mid-Term (3–12 months)**
# - Core features, integrations, or platform upgrades
#
# **C. Long-Term (12+ months)**
# - Visionary features, cross-domain expansions, or business model innovations
#
# ---
#
# ### 4. Feature Prioritization (ICE Scoring)
#
# Score the proposed features based on:
#
# - **Impact** (value to user or business)
# - **Confidence** (likelihood of success)
# - **Ease** (implementation feasibility)
# Output and order in descending order based on total score in the table in code block format:
#
# | Feature | Impact | Confidence | Ease | Total |
# |---------|--------|------------|------|-------|
# | …       | …      | …          | …    | …     |
#
# ---
#
# ### 5. SMART OKRs
#
# Propose 2–3 quarterly OKRs (Objectives and Key Results) aligned with the roadmap priorities.
#
# Each OKR must be:
# - Specific
# - Measurable
# - Achievable
# - Relevant
# - Time-bound
#
# ---
#
# ### 6. Next-Level Innovation & Product Vision
#
# Propose bold, visionary, or cross-domain feature ideas that go beyond current expectations.
#
# Think:
# - Features that blend with other industries (e.g., AI + education, AI + wellness)
# - New value models (subscriptions, communities, APIs)
# - Scalable tech or ecosystem partnerships
#
# ---
# Now output exactly **6 structured sections**, using this markdown format:
#
# ### 1. Mission & Vision
# ### 2. Product Snapshot
# ### 3. Strategic Roadmap
# ### 4. Feature Prioritization (ICE Scoring)
# ### 5. SMART OKRs
# ### 6. Next-Level Innovation & Product Vision
#
# Important:
# - Use `###` headers exactly as written
# - Always return exactly 6 sections
# - Do not skip or reorder sections
# - Use markdown tables for scoring or OKRs
# - Keep the format consistent for parsing
#
# Start with `### 1. Mission & Vision`

# %%
# === Step 3: Build the markdown table ===

table_md = f""" 
## 📊 Evaluation Summary: Zero-Shot Prompting for **{company_name}**
| Section | Metric | 🤖 LLM Score | 👤 Human Score | Feedback |
|---------|--------|--------------|----------------|----------|
"""

for _, row in zero_shot_df.iterrows():
    section = row["Section"]
    metric = row["Metric"]
    llm_score = row["LLM Score"]
    human_score = row["Human Score"]
    feedback = row["Feedback"]

    table_md += f"| {section} | {metric} | {llm_score} | {human_score} | {feedback} |\n"

# === Step 4: Display in notebook ===
display(Markdown(table_md))
# Out:
#
# ## 📊 Evaluation Summary: Zero-Shot Prompting for **Spotify**
# | Section | Metric | 🤖 LLM Score | 👤 Human Score | Feedback |
# |---------|--------|--------------|----------------|----------|
# | Mission & Vision | Mission/Vision Insight | 5.0 | 4.0 | It is well-crafted and concise |
# | Product Snapshot | Strategic Depth | 3.0 | 4.0 | A good start, but could go deeper... |
# | Strategic Roadmap | Roadmap Relevance | 5.0 | 5.0 | Very creative and grouped well. |
# | Feature Prioritization (ICE Scoring) | Prioritization Clarity | 5.0 | 4.0 | Logical reasoning, but room for clarity. |
# | SMART OKRs | OKR Quality | 5.0 | 3.0 | Unclear how numbers are derived. |
# | Next-Level Innovation & Product Vision | Visionary Thinking | 4.0 | 3.0 | Ideas are decent but not out-of-the-box. |
# | Mission & Vision | Mission/Vision Insight | 5.0 | 5.0 | great vision and mission. |
# | Product Snapshot | Strategic Depth | 4.0 | 4.0 | it can be more precise and in depth, it should list all of the current features, and relate all of them together with more depth and integration |
# | Strategic Roadmap | Roadmap Relevance | 5.0 | 5.0 | comprehensive roadmap adjusted as injected in the prompt |
# | Feature Prioritization (ICE Scoring) | Prioritization Clarity | 5.0 | 4.0 | i need to see why it chose those scores. also this prioritization should be aligned with all the previous insights |
# | SMART OKRs | OKR Quality | 4.0 | 4.0 | where did those numbers come from. what is the source, is it a guesstimate or hallucination or real number from an authentic source. Also OKR should take into account the previous inputs |
# | Next-Level Innovation & Product Vision | Visionary Thinking | 4.0 | 4.0 | although the ideas are impressive but they are not out of the box. it can be improved by pushing further out of the known comfort zone |

# %%
# === Human and machine feedback injection and evaluation ===
def build_feedback_augmented_prompt(company_name, strategy="Zero-Shot", prompt_tag="zero-shot-v1-baseline-1", eval_path=EVAL_FILE):
    try:
        df = pd.read_csv(eval_path)
    except FileNotFoundError:
        raise FileNotFoundError(f"⚠️ File not found at {eval_path}. Make sure your all_experiment_view.csv is available.")

    # Filter for the selected strategy and tag
    df_filtered = df[
        (df["Company"].str.lower() == company_name.lower()) &
        (df["Strategy"].str.lower() == strategy.lower()) &
        (df["Prompt Tag"].str.lower().str.contains(prompt_tag.lower()))
    ]

    if df_filtered.empty:
        raise ValueError("❌ No matching entries found for given strategy and prompt tag.")

    # Inject section-specific feedback
    feedback_notes = ""
    for _, row in df_filtered.iterrows():
        section = row["Section"]
        human_score = row["Human Score"]
        feedback = row["Feedback"]
        lesson = row["Lesson"]

        feedback_notes += f"""
### 💡 Improve for: {section}
- Human Score: {human_score}
- Feedback: {feedback}
- Lesson Learned: {lesson}
"""

    # === Build new improved prompt with metadata in the title ===
    title = f"{strategy} | {prompt_tag} | Improved Prompt for {company_name}"

    improved_prompt = f"""
# 🪄 {title}

You are Nextify — an AI-powered product strategy assistant for product managers.

The product to analyze is: **{company_name}**

---

Before continuing, review this feedback from the last evaluation and apply improvements:

Please add {feedback_notes.strip()} into your consideration as well as explain in details what you think. Do not limit yourself only to feedbacks and lesson learned. Explore each seciton deeply and thoroghly. please 
create tables and markdowns wherever needed.

for Product Snapshot please take into account thorough insight of the product like users, features, audience, competitive edge as well as well as the porter 5 forces and competitor analysis.The analysis should identifies the forces as well as offer concrete strategic recommendations for **{company_name}** to leverage these insights. For example,for Spotify it mentions the high bargaining power of record labels as well as suggesting strategies to mitigate this, like developing original content, fostering direct artist relationships, or exploring alternative licensing models.
delve into the nuances of Spotify's specific situation or recent industry trends. More in-depth research and tailored arguments would increase the score.
 The analysis should not treats each force in isolation, but Porter's Five Forces are interconnected. The response should explore how these forces interact and influence each other within **{company_name}**  competitive landscape.

---

Each section should begin with a heading starting with `###` followed by the section number and title.

Make sure there are exactly 6 sections. Use tables where relevant (e.g., ICE Scoring, OKRs). Keep responses clean, consistent, and structured in markdown format
---
Now, generate a revised product strategy across the following **exact 6 sections**.

### ✳️ REQUIRED FORMAT

Please follow this strict structure — do not skip, rename, or reformat headings:

### 1. Mission & Vision  
### 2. Product Snapshot  
### 3. Strategic Roadmap  
### 4. Feature Prioritization (ICE Scoring)  
### 5. SMART OKRs  
### 6. Next-Level Innovation & Product Vision

✅ Important:
- Begin each section with `### [number]. [title]`
- Use bullet points, markdown tables, or numbered lists
- Return exactly 6 sections in this order

---

Start your response below:
"""


    return improved_prompt

# %%
# === Step 1: Build & Run the Improved Prompt ===
improved_prompt_tag = f"improved-{prompt_tag}"
run_id = all_experiment_view[all_experiment_view["Company"] == company_name]["Run"].max() + 1 if not all_experiment_view.empty else 1

improved_prompt = build_feedback_augmented_prompt(company_name, strategy_name, prompt_tag, EVAL_FILE)

response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=improved_prompt
)
improved_llm_output = response.text

# Print the first part of the raw output to inspect structure
print("🔍 LLM Output Preview:")
Markdown(improved_llm_output)  # adjust length if needed
# Out:
# 🔍 LLM Output Preview:
# ### 1. Mission & Vision
#
# *   **Mission:** To unlock the potential of human creativity by giving a million creative artists the opportunity to live off their art and billions of fans the opportunity to enjoy and be inspired by these creators.
# *   **Vision:** To be the world's leading audio platform, deeply integrated into every aspect of life, providing personalized and immersive audio experiences that connect creators and listeners on a global scale, enriching lives through the power of sound. This includes not just music, but also spoken word, interactive experiences, and even AI-driven audio landscapes, fostering a future where audio is a constant companion, enhancing understanding, creativity, and well-being.
#
# ### 2. Product Snapshot
#
# Spotify is the world's leading audio streaming service, boasting over 551 million monthly active users (MAU) and 220 million premium subscribers (Spotify Q3 2023 Earnings Report). Its core offering centers around providing on-demand access to a vast library of music, podcasts, and audiobooks.
#
# **Key Features:**
#
# *   **Music Streaming:** On-demand access to millions of songs, curated playlists, personalized radio stations, and offline listening capabilities.
# *   **Podcast Platform:** A growing library of podcasts, including exclusive content, original series, and tools for creators to publish and monetize their work.
# *   **Audiobooks:** Access to a vast selection of audiobooks, with subscription-based and a la carte purchasing options.
# *   **Personalized Recommendations:** AI-powered algorithms that suggest music and podcasts based on listening habits and preferences.
# *   **Social Features:** Ability to follow friends, share music, and create collaborative playlists.
# *   **Cross-Platform Availability:** Accessible on mobile devices, desktop computers, smart speakers, gaming consoles, and more.
#
# **Target Audience:**
#
# Spotify's target audience is broad, encompassing music lovers, podcast enthusiasts, and audiobook listeners of all ages and demographics. However, it particularly resonates with younger generations (Gen Z and Millennials) who are digital natives and heavy consumers of streaming media.
#
# **Competitive Edge:**
#
# *   **Vast Content Library:** Spotify boasts one of the largest music and podcast libraries in the world.
# *   **Personalization Engine:** Its AI-powered recommendation algorithms are highly effective at surfacing relevant content.
# *   **Brand Recognition:** Spotify is a well-established and trusted brand with a strong global presence.
# *   **Platform Ecosystem:** Its cross-platform availability and integrations with other services make it convenient and accessible.
#
# **Porter's Five Forces Analysis:**
#
# | Force                          | Assessment | Strategic Recommendations                                                                                                                                                                                                                                                                    |
# | :----------------------------- | :--------- | :--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Threat of New Entrants**     | Low        | *   Continuously innovate and improve the user experience to maintain a competitive edge.*   Expand into new markets and content categories (e.g., live audio, immersive audio) to stay ahead of potential disruptors.                                                                      |
# | **Bargaining Power of Suppliers (Record Labels)** | High       | *   Develop original content (Spotify Originals) to reduce reliance on record labels (Target: Increase Spotify Original listenership by 30% in next 2 years, internal goal).*   Foster direct relationships with artists and offer alternative licensing models (e.g., direct deals).*   Explore blockchain technology to facilitate fairer and more transparent revenue sharing with artists. |
# | **Bargaining Power of Buyers** | Moderate   | *   Offer tiered subscription plans with varying features and price points to cater to different user segments.*   Provide exceptional customer support and build a strong community to foster loyalty.*   Bundling with other service to reduce costs to customer.                          |
# | **Threat of Substitute Products or Services** | Moderate   | *   Continuously enhance the value proposition of Spotify Premium through exclusive content, features, and benefits.*   Integrate Spotify into other platforms and services to increase its stickiness.*   Invest into technology like AI music generator to reduce costs   |
# | **Competitive Rivalry**        | High       | *   Differentiate Spotify through personalized experiences, exclusive content, and innovative features.*   Aggressively market Spotify's unique selling points and target specific user segments.*   Explore strategic partnerships and acquisitions to consolidate market share.                  |
#
# The competitive rivalry is high, driven by players such as Apple Music, Amazon Music, YouTube Music, and Deezer. All of these platforms are vying for market share.
#
# **Quantifying the impact of each force:**
#
# *   **Bargaining Power of Suppliers:** Approximately 70% of Spotify's revenue is paid out as royalties to record labels and artists (Source: Spotify's annual reports and industry estimates). This highlights the significant bargaining power of suppliers.
# *   **Threat of Substitute Products or Services:** A 2022 study indicated that approximately 20% of music listeners still prefer to own their music (digital downloads or physical copies) rather than subscribe to a streaming service (Source: IFPI Global Music Report 2022). This represents the threat of substitute products.
#
# **Integration:**
#
# The interaction between Porter's Five Forces affects Spotify significantly. To counter the high bargaining power of suppliers, Spotify has been strategically investing in original podcasts and exclusive artist deals. This move not only strengthens its position against record labels but also differentiates it from competitors and enhances the user experience, thereby mitigating the threat of substitute products. In response to intense competitive rivalry, Spotify focuses on providing personalized experiences.
#
# **Emerging Trends:**
#
# Web3 technologies offer potential for artists to directly engage with fans, potentially disrupting the traditional role of record labels.  AI-powered music creation could lower content acquisition costs.
#
# ### 3. Strategic Roadmap
#
# **Vision:** To be the undisputed leader in the audio streaming space, offering a comprehensive and personalized audio experience to billions of users worldwide.
#
# **Key Strategic Pillars:**
#
# 1.  **Content Expansion & Diversification:** Expand beyond music into spoken word content, including podcasts, audiobooks, and potentially live audio.
# 2.  **Enhanced Personalization:** Leverage AI and machine learning to deliver even more personalized recommendations and listening experiences.
# 3.  **Platform Ecosystem Expansion:** Integrate Spotify into more devices and platforms, including automobiles, gaming consoles, and wearable devices.
# 4.  **Monetization Innovation:** Explore new revenue streams beyond traditional subscriptions, such as advertising, e-commerce, and creator tools.
#
# **Roadmap (Next 3 Years):**
#
# | Quarter | Initiative                                               | Description                                                                                                                                                                                                                                                        | Estimated Impact (MAU) | Dependencies                                                                                                                                  |
# | :------ | :------------------------------------------------------- | :------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ | :----------------------- | :---------------------------------------------------------------------------------------------------------------------------- |
# | Q1 2024 | Podcast Subscription Platform Launch                     | Enable creators to offer paid subscriptions to their podcasts, providing exclusive content and benefits to subscribers.                                                                                                                                                | +10 Million             | Development of subscription management tools, creator onboarding process, marketing campaign.                                  |
# | Q2 2024 | AI-Powered Music Discovery Feature                       | Introduce a new feature that uses AI to analyze users' listening habits and suggest new music that they are likely to enjoy.                                                                                                                                          | +15 Million             | Development of AI algorithms, integration with music catalog, user interface design.                                         |
# | Q3 2024 | Automotive Integration Expansion                          | Partner with leading automobile manufacturers to integrate Spotify into their infotainment systems, providing seamless access to music and podcasts while driving.                                                                                                     | +5 Million              | Negotiation with automobile manufacturers, development of automotive-specific user interface, testing and certification.        |
# | Q4 2024 | E-Commerce Integration                                     | Allow artists to sell merchandise directly to fans through the Spotify platform, creating a new revenue stream and enhancing the fan experience.                                                                                                                       | +8 Million              | Development of e-commerce platform, integration with payment processors, logistics partnerships.                               |
# | Q1 2025 | Personalized Audio Ads                                  | Implement dynamic ad insertion technology that delivers personalized audio ads based on users' listening habits and demographics.                                                                                                                                    | +12 Million             | Development of ad targeting algorithms, integration with ad networks, compliance with privacy regulations.                      |
# | Q2 2025 | Interactive Audio Experiences                           | Experiment with interactive audio formats, such as choose-your-own-adventure podcasts and gamified audiobooks, to create more engaging and immersive listening experiences.                                                                                                | +7 Million              | Development of interactive audio authoring tools, content partnerships, user interface design.                                 |
# | Q3 2025 | Expansion into Emerging Markets (Southeast Asia, Africa) | Launch Spotify in new emerging markets with localized content and pricing plans, targeting a wider global audience.                                                                                                                                                  | +20 Million             | Localization of content, development of pricing strategies, marketing campaigns.                                               |
# | Q4 2025 | Creator Tools Enhancement                                 | Provide creators with a suite of tools to help them produce, promote, and monetize their content, including recording software, editing tools, and analytics dashboards.                                                                                              | N/A                    | Development of creator tools, user training, marketing campaign.                                                           |
# | Q1 2026 | Live Audio Platform (Pilot)                              | Pilot a new live audio platform where artists and creators can host live events, interact with fans in real-time, and monetize their content through virtual tickets and subscriptions.                                                                                 | +5 Million              | Development of live audio streaming technology, moderation tools, user interface design.                                        |
# | Q2 2026 | Immersive Audio Experiences (Spatial Audio)               | Develop and integrate immersive audio technologies, such as spatial audio, to create more realistic and engaging listening experiences.                                                                                                                                 | +10 Million             | Development of audio processing algorithms, content partnerships, user interface design.                                         |
#
# **Prioritization Matrix (Impact vs. Effort):**
#
# | Initiative                            | Impact | Effort | Priority |
# | :------------------------------------ | :----- | :----- | :------- |
# | Podcast Subscription Platform Launch  | High   | Medium | High     |
# | AI-Powered Music Discovery Feature    | High   | Medium | High     |
# | Automotive Integration Expansion     | Medium | Medium | Medium   |
# | E-Commerce Integration                | Medium | Medium | Medium   |
# | Personalized Audio Ads                | High   | Medium | High     |
# | Interactive Audio Experiences         | Medium | High   | Medium   |
# | Expansion into Emerging Markets       | High   | High   | Medium   |
# | Creator Tools Enhancement             | Medium | Medium | Medium   |
# | Live Audio Platform (Pilot)           | Medium | High   | Low      |
# | Immersive Audio Experiences          | Medium | High   | Low      |
#
# High impact and low/medium effort are prioritized first.
#
# **Numbers Source:** The MAU impact numbers are guesstimates based on industry trends, competitor performance, and internal Spotify projections.
#
# ### 4. Feature Prioritization (ICE Scoring)
#
# **ICE Scoring Methodology:**
#
# ICE scoring is a prioritization method that uses three factors to evaluate potential features:
#
# *   **Impact:** How much of an impact will this feature have on users and business goals? (1-10)
# *   **Confidence:** How confident are we that this feature will have the predicted impact? (1-10)
# *   **Ease:** How easy is it to implement this feature? (1-10)
#
# The ICE score is calculated by multiplying these three factors: **ICE Score = Impact \* Confidence \* Ease.**
#
# | Feature                                     | Impact (1-10) | Confidence (1-10) | Ease (1-10) | ICE Score | Justification                                                                                                                                                                                                                                                                                                        | Financial Implication/Gain                                                                                                                                                                                                                                               |
# | :------------------------------------------ | :------------ | :---------------- | :---------- | :-------- | :----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | :------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Personalized Podcast Recommendations        | 8             | 7                 | 6           | 336       | High potential to increase podcast consumption and engagement. Good confidence based on success with music recommendations. Relatively easy to implement using existing AI infrastructure.                                                                                                                             | Increase in podcast ad revenue by 15% YoY (Estimated, based on similar improvements in music ad revenue).                                                                                                                                                |
# | Offline Listening for Podcasts (Free Tier) | 7             | 8                 | 7           | 392       | Addresses a major pain point for free users. Very confident that this feature will increase engagement and retention. Relatively easy to implement.                                                                                                                                                               | Increased free tier user retention by 10% (Estimated, based on similar improvements in user behavior).                                                                                                                                                  |
# | Collaborative Playlist Filters            | 6             | 6                 | 8           | 288       | Allows users to filter collaborative playlists based on genre, artist, etc. Aims to enhance collaborative listening experience. Implementation is easy.                                                                                                                                                         | Increase in collaborative playlist usage by 20% (Estimated, based on internal usage data).                                                                                                                                                                |
# | Enhanced Artist Discovery Tools            | 9             | 7                 | 5           | 315       | Enable users to discover emerging artists based on their listening habits. High impact on artist awareness and discovery. Moderate confidence due to potential algorithm complexity. Implementation is moderately difficult as the tools can be complex and data-intense.                                              | Increase in streams for emerging artists by 25% (Estimated, based on internal artist growth data).                                                                                                                                                          |
# | Live Lyrics Integration                       | 8             | 9                 | 6           | 432       | Integrate live lyrics feature into the app. Aims to enhance karaoke-like listening experience. The confidence is high, as this feature is expected to resonate well with music lovers. Its ease of implementation is relatively straightforward.                                                                  | Drive a 5% increase in user engagement metrics like listening hours (Estimated based on similar features in competing apps like Apple Music)                                                                                                              |
#
# **Explanation of Score Choices:**
#
# *   The highest score goes to **Live Lyrics Integration** because it has high impact, very high confidence, and reasonable ease of implementation. It addresses a clear user need and is relatively straightforward to implement, and thus, it has the highest chance of being successful.
# *   All the feature choices take into account the mission/vision, product snapshot, roadmap. All are aligned on a singular vision.
#
# ### 5. SMART OKRs
#
# **Objective:** Increase user engagement and retention by delivering personalized and immersive audio experiences.
#
# **Key Results:**
#
# *   **KR1:** Increase monthly active users (MAU) from 551 million (Q3 2023 Baseline) to 600 million by Q4 2024 (+8.9% Growth). Source: Guestimate Based on Market Growth of 4.7%. Goal is to double it given our initiatives.
# *   **KR2:** Increase premium subscribers from 220 million (Q3 2023 Baseline) to 240 million by Q4 2024 (+9% Growth). Source: Guestimate based on Market Growth of 4%. Goal is to more than double it due to initiatives like "Automotive Integration Expansion".
# *   **KR3:** Increase average daily listening time per user from 155 minutes (Q3 2023 Baseline) to 170 minutes by Q4 2024 (+9.6% Growth). Source: Guestimate based on the launch of AI-Powered Music Discovery feature and Personalized Podcast Recommendations.
# *   **KR4:** Improve user retention rate (percentage of users who remain subscribed after 12 months) from 75% (Q3 2023 Baseline) to 78% by Q4 2024 (+4% Improvement). Source: Based on initiatives such as Offline Listening for Podcasts, to retain users during downtimes.
#
# **Explanation of Number Sources:**
#
# *   The MAU and subscriber growth targets are based on a combination of market analysis (projected growth rates for the audio streaming market) and internal projections (impact of new features and initiatives).
# *   The listening time and retention rate targets are based on historical data, industry benchmarks, and anticipated impact of new features.
#
# These OKRs are aligned with the mission and vision, product snapshot, and strategic roadmap, focusing on user engagement, content expansion, and platform ecosystem growth.
#
# ### 6. Next-Level Innovation & Product Vision
#
# Spotify can move beyond being just a streaming service and transform into a comprehensive audio ecosystem by targeting currently underserved user segments:
#
# 1.  **Personalized Audio Wellbeing Platform:** Develop a platform integrating biofeedback data (from wearables) with personalized audio content designed to improve mental and physical wellbeing. This includes:
#     *   **Adaptive Soundscapes:** Generative AI audio environments that respond to user's mood, location, and activity levels. Imagine soundscapes adjusting to a user's heartbeat during a workout or calming music automatically playing when stress is detected via a smartwatch.
#     *   **Guided Meditation & Mindfulness Journeys:** Personalized meditation programs adapting to a user's emotional state and experience level, integrating personalized ASMR triggers, creating deeper immersion.
#
# 2.  **AI-Powered Audio Creation Suite for Everyone:** Democratize audio creation, offering tools for users to:
#     *   **Generate Music with AI:** Empower users to create their own original music, regardless of musical experience, by using AI to compose melodies, harmonies, and rhythms based on user-defined parameters (mood, genre, instruments). Imagine a user describing a feeling and the AI generating a song to match.
#     *   **Create Personalized Voiceovers:** Enable users to create professional-quality voiceovers for videos, podcasts, and presentations using AI-powered text-to-speech technology with a wide range of customizable voices, intonations, and accents.
#
# 3.  **Interactive & Immersive Audio Storytelling:** Pushing beyond static audiobooks and podcasts:
#     *   **AR Audio Adventures:** Integrate location-based AR with audio storytelling, creating interactive adventures where the audio narrative unfolds based on the user's physical location and actions.
#     *   **Multiplayer Audio Dramas:** Enable listeners to participate in live audio dramas, making choices that influence the story's outcome and interacting with other listeners in real-time.
#
# **Detailed Explanations:**
#
# These innovations focus on:
#
# *   **Leveraging AI:** Utilizing AI to create personalized and adaptive audio experiences, enhancing user engagement and creating new content creation opportunities.
# *   **Expanding Beyond Entertainment:** Transforming Spotify into a holistic audio platform that supports user wellbeing, creativity, and learning.
# *   **Creating New Revenue Streams:** Monetizing new features through premium subscriptions, creator tools, and advertising opportunities.
# *   **Reaching Underserved Segments:** Catering to users seeking personalized wellbeing solutions, creative expression, and immersive storytelling experiences.
#
# These features would be groundbreaking since it shifts the paradigm of how we consume audio.

# %%
# Copy uploaded file to working directory if needed
shutil.copy("/kaggle/input/all-experiment-view/all_experiment_view.csv", "/kaggle/working/all_experiment_view.csv")
# Out:
# '/kaggle/working/all_experiment_view.csv'

# %%
# 🛡️ Safe fallback for next_run in case kernel was restarted
if "next_run" not in globals():
    try:
        same_combo = all_experiment_view[
            (all_experiment_view["Company"].str.lower().fillna("") == company_name.lower()) &
            (all_experiment_view["Strategy"].str.lower().fillna("") == strategy_name.lower()) &
            (all_experiment_view["Prompt Tag"].str.lower().fillna("") == prompt_tag.lower())
        ]
        next_run = same_combo["Run"].max() + 1 if not same_combo.empty else 1
    except:
        next_run = 1
    print(f"🧮 Recovered next_run = {next_run}")

# %%
evaluate_llm_output_by_section(
    run_id=next_run,
    strategy_name=strategy_name,
    company_name=company_name,
    llm_output=improved_llm_output,
    prompt_tag="improved-" + prompt_tag,
    table_path=EVAL_FILE
)
# Out:
# ⚠️ This combination already exists for Spotify / Zero-Shot / improved-zero-shot-v1-baseline-1.
#     Run                                 Section  Human Score  \
# 6     1                        Mission & Vision          5.0
# 7     1                        Product Snapshot          4.0
# 8     1                       Strategic Roadmap          5.0
# 9     1    Feature Prioritization (ICE Scoring)          4.0
# 10    1                              SMART OKRs          4.0
# 11    1  Next-Level Innovation & Product Vision          4.0
#
#                                                                                                                                                                                       Feedback
# 6                                                                                                                                                                    great vision and mission.
# 7                                             it can be more precise and in depth, it should list all of the current features, and relate all of them together with more depth and integration
# 8                                                                                                                                     comprehensive roadmap adjusted as injected in the prompt
# 9                                                                           i need to see why it chose those scores. also this prioritization should be aligned with all the previous insights
# 10  where did those numbers come from. what is the source, is it a guesstimate or hallucination or real number from an authentic source. Also OKR should take into account the previous inputs
# 11                                                      although the ideas are impressive but they are not out of the box. it can be improved by pushing further out of the known comfort zone
# 🛑 Skipping evaluation in non-interactive mode (Kaggle).

# %%
# 👉 Cell skipped due to duplicate run and user cancellation

# %%
# Save the full updated evaluation table
all_experiment_view.to_csv("/kaggle/working/all_experiment_view.csv", index=False)
print("✅ Saved to /kaggle/working/all_experiment_view.csv")
# Out:
# ✅ Saved to /kaggle/working/all_experiment_view.csv

# %%
all_experiment_view
# Out:
#     Run  Company         Strategy                        Prompt Tag  \
# 0     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 1     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 2     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 3     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 4     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 5     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 6     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 7     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 8     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 9     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 10    1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 11    1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 12    1  Spotify         Few_Shot          Few_Shot_OKR_improvement
# 13    1  Spotify              CoT           cot-Product-Snapshot-v1
# 14    1  Spotify  Tree-of-Thought               tree-thought-ice-v1
#
#                                    Section                  Metric  LLM Score  \
# 0                         Mission & Vision  Mission/Vision Insight        5.0
# 1                         Product Snapshot         Strategic Depth        3.0
# 2                        Strategic Roadmap       Roadmap Relevance        5.0
# 3     Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 4                               SMART OKRs             OKR Quality        5.0
# 5   Next-Level Innovation & Product Vision      Visionary Thinking        4.0
# 6                         Mission & Vision  Mission/Vision Insight        5.0
# 7                         Product Snapshot         Strategic Depth        4.0
# 8                        Strategic Roadmap       Roadmap Relevance        5.0
# 9     Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 10                              SMART OKRs             OKR Quality        4.0
# 11  Next-Level Innovation & Product Vision      Visionary Thinking        4.0
# 12                              SMART OKRs             OKR Quality        4.0
# 13                        Product Snapshot         Strategic Depth        4.0
# 14    Feature Prioritization (ICE Scoring)  Prioritization Clarity        4.0
#
#     Human Score  \
# 0           4.0
# 1           4.0
# 2           5.0
# 3           4.0
# 4           3.0
# 5           3.0
# 6           5.0
# 7           4.0
# 8           5.0
# 9           4.0
# 10          4.0
# 11          4.0
# 12          4.5
# 13          4.0
# 14          4.5
#
#                                                                                                                                                                                                                               Feedback  \
# 0                                                                                                                                                                                                       It is well-crafted and concise
# 1                                                                                                                                                                                                 A good start, but could go deeper...
# 2                                                                                                                                                                                                      Very creative and grouped well.
# 3                                                                                                                                                                                             Logical reasoning, but room for clarity.
# 4                                                                                                                                                                                                     Unclear how numbers are derived.
# 5                                                                                                                                                                                             Ideas are decent but not out-of-the-box.
# 6                                                                                                                                                                                                            great vision and mission.
# 7                                                                                     it can be more precise and in depth, it should list all of the current features, and relate all of them together with more depth and integration
# 8                                                                                                                                                                             comprehensive roadmap adjusted as injected in the prompt
# 9                                                                                                                   i need to see why it chose those scores. also this prioritization should be aligned with all the previous insights
# 10                                          where did those numbers come from. what is the source, is it a guesstimate or hallucination or real number from an authentic source. Also OKR should take into account the previous inputs
# 11                                                                                              although the ideas are impressive but they are not out of the box. it can be improved by pushing further out of the known comfort zone
# 12  the structure improved with the reason behind the numbers explained but the model needs to be exposed to mroe data on market trend and analysis to be able to set a solid logic behind the numbers and give more realistic numbers
# 13                               it becomes so much better than before, but still needs more depth. by embedding strategic documents and reference sites it would be way more better. I think the prompting reaches its maximum output
# 14                                  It improves tremendously from the last instance. It is well argumented. However still we should input data and give it memory, embeddings and logic to be able to connect the dots based on data.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Lesson  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Could be more visionary.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Use Porter's 5 forces.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Add prioritization matrix.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Explain ICE criteria.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Include baseline KPIs.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Target underserved segments.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      the vision improved significantly from the first run
# 7   it should itnegrate all of the sections together to give a product snappshot. also**Quantifying the impact of each force:** Instead of just stating "Moderate" or "High," providing data or estimates to support the assessment would add more depth. For example, for Bargaining Power of Suppliers, including information about the percentage of revenue paid out as royalties. *   **Prioritization:** The recommendations are all valid, but it would be helpful to see a prioritization of which strategies are most critical or have the highest potential impact. *   **Consideration of emerging trends:** Discussing how emerging trends like Web3 or AI might impact Spotify's strategy could also increase the depth. it should be like a story considering various aspects of the proudct.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                             the source of that numbers should be clear. ideally it should be calculated based on guestimate or directly extracted from a source mention the source so we make sure it is not hallucination. with more context it can be justified. also all of them should be aligned with the roadmap and feature and snapshot and vison
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              take into account the previous sections as well as the financial aspect of the feature, what is the potential gain from each
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Give the exact source of the numbers whether guestimate (give the formula) exact number (mention the source) or just a random generation from your imagination. also take into account all the previous outputs from mission, vision, product snapshot, roadmap
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   should push further and give more groundbreaking features.the response demonstrates strong visionary thinking, but it could be pushed further to achieve true game-changing potential.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      we need to add market analysis and trend datset to this section in order to get an improved version
# 13                                                                                                                                                                                                                                                                                                                                                                                                                       The analysis could benefit from demonstrating the connection between user needs/pain points identified earlier in the document, and how addressing these can strategically mitigate specific competitive forces. For example, investing in lossless/hifi audio is in line with the preferences of some of the premium users and could help attract customers from Tidal or Deezer.
# 14                                                                                                                                                                                                                                                                                                                                                                                                 However, the evaluation could be improved by explicitly referencing a specific, hypothetical mission, roadmap, or user research (e.g. 'our mission is to improve user engagement', 'this aligns with the Q3 roadmap to improve on-boarding'). Right now it gestures vaguely at the "company goals" or "overall goals and product roadmap". It's *implied*, but not *grounded* in those earlier contexts.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# ...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 13  Okay, let's analyze Spotify and identify key opportunities for improvement and growth. I'll focus on user personas, pain points, UX friction, market position, competitive landscape, and a Porter's Five Forces analysis to inform strategic recommendations. I'll pay close attention to industry trends and competitor actions to provide actionable insights for Spotify's product strategy. I will also focus on justifying the ICE scores I give at the end.\n\n### 1. 🎯 Target User Personas\n\nLet’s think through this...\n\nSpotify's user base is diverse, spanning age groups, geographic locations, and musical tastes. Understanding these different user personas is crucial for tailoring the experience and driving engagement. We can broadly categorize users into Free and Premium tiers, with further segmentation within each tier.\n\n*   **Free Users:** This group represents a significant portion of Spotify's user base, often younger and more price-sensitive.\n    *   *Generation Z (13-25):* Discovers new music through social media, prioritizes cost-effectiveness, and values personalized playlists. Located globally, with high penetration in emerging markets. Psychographically, they are adventurous, trend-conscious, and digitally native.\n    *   *Millennial Casual Listeners (26-40):* Listens to music during commutes, workouts, or social gatherings. Less concerned with audio quality, but values convenience and breadth of content. Geographically diverse, with a mix of urban and suburban residents. Psychographically, they are practical, value-driven, and convenience-oriented.\n*   **Premium Users:** This group is willing to pay for an ad-free experience, offline listening, and higher audio quality.\n    *   *Gen X Audiophiles (41-55):* Values high-fidelity audio and curated playlists. Often uses Spotify on multiple devices, including home audio systems. Primarily located in developed countries. Psychographically, they are discerning, quality-focused, and tech-savvy.\n    *   *Millennial Music Enthusiasts (26-40):* Actively seeks out new music, follows artists, and creates personalized playlists. Uses Spotify daily and across various devices. Globally present, with a strong presence in urban centers. Psychographically, they are passionate, engaged, and culturally aware.\n    *   *Creator-Facing: Artists & Podcasters:* Use Spotify for Artists/Spotify for Podcasters to manage their presence, track performance, and connect with fans. Geographically diverse, from bedroom artists to established professionals. Psychographically, they are driven, creative, and entrepreneurial.\n\n**Summary Insight:** Spotify needs to balance the needs of its diverse user base, offering a compelling free tier while providing enough value to convert users to Premium. Targeting specific generational and psychographic segments with tailored content and features will be key to growth. The creator-facing personas are crucial to maintain and attract more content to the platform, indirectly attracting their audiences.\n\n### 2. 🧩 Key User Pain Points\n\nLet’s think through this...\n\nUser pain points can significantly impact engagement and conversion rates. Identifying and addressing these issues is crucial for improving user satisfaction and driving growth. Analysis of app store reviews, social media feedback, and user surveys reveals several key pain points:\n\n*   **Free Tier Limitations:** Frequent ads, limited offline downloads, and shuffle-only playback on mobile devices are major frustrations for free users. This directly impacts their willingness to convert to Premium.\n*   **Discovery Challenges:** While Spotify's algorithm is generally effective, users sometimes struggle to find new music outside their usual genres or artists. The sheer volume of content can be overwhelming.\n*   **Podcast Experience:** Podcast discovery and organization can be improved. Users often struggle to find relevant podcasts and manage their subscriptions effectively.\n*   **Audio Quality: ...
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...

# %%
# Load updated file
df = pd.read_csv(EVAL_FILE)

# Filter for both runs
before = df[(df["Prompt Tag"] == prompt_tag) & (df["Company"] == company_name)]
after = df[(df["Prompt Tag"] == "improved-" + prompt_tag) & (df["Company"] == company_name)]

# Merge
comparison = before.merge(after, on="Section", suffixes=("_Before", "_Improved"))

# Save comparison table for dashboard use
comparison.to_csv("/kaggle/working/comparison_table.csv", index=False)
print("✅ comparison_table.csv saved to working directory.")

# Markdown Table
table_md = "### 🔍 Evaluation Comparison Table\n\n"
table_md += "| Section | Metric | 🤖 LLM Before | 👤 Human Before | 🤖 LLM Improved | 👤 Human Improved |\n"
table_md += "|---------|--------|----------------|------------------|------------------|--------------------|\n"

for _, row in comparison.iterrows():
    table_md += f"| {row['Section']} | {row['Metric_Before']} | {row['LLM Score_Before']} | {row['Human Score_Before']} | {row['LLM Score_Improved']} | {row['Human Score_Improved']} |\n"

display(Markdown(table_md))
# Out:
# ✅ comparison_table.csv saved to working directory.
# ### 🔍 Evaluation Comparison Table
#
# | Section | Metric | 🤖 LLM Before | 👤 Human Before | 🤖 LLM Improved | 👤 Human Improved |
# |---------|--------|----------------|------------------|------------------|--------------------|
# | Mission & Vision | Mission/Vision Insight | 5.0 | 4.0 | 5.0 | 5.0 |
# | Product Snapshot | Strategic Depth | 3.0 | 4.0 | 4.0 | 4.0 |
# | Strategic Roadmap | Roadmap Relevance | 5.0 | 5.0 | 5.0 | 5.0 |
# | Feature Prioritization (ICE Scoring) | Prioritization Clarity | 5.0 | 4.0 | 5.0 | 4.0 |
# | SMART OKRs | OKR Quality | 5.0 | 3.0 | 4.0 | 4.0 |
# | Next-Level Innovation & Product Vision | Visionary Thinking | 4.0 | 3.0 | 4.0 | 4.0 |

# %%
# 🌈 Define and apply custom pastel color palette

importlib.reload(sns)

# 🎨 Custom pastel palette
custom_palette = {
    "Before": "#f78fb3",    # pastel pink
    "Improved": "#7f9cf5"   # pastel blue
}

# %%
# Melt and combine human and LLM scores
human_scores = comparison[["Section", "Human Score_Before", "Human Score_Improved"]].melt(
    id_vars="Section", var_name="Version", value_name="Score"
)
human_scores["Metric"] = "Human"

llm_scores = comparison[["Section", "LLM Score_Before", "LLM Score_Improved"]].melt(
    id_vars="Section", var_name="Version", value_name="Score"
)
llm_scores["Metric"] = "LLM"

# Combine + clean version names
score_data = pd.concat([human_scores, llm_scores])
score_data["Version"] = score_data["Version"].str.replace("Human Score_", "", regex=False)
score_data["Version"] = score_data["Version"].str.replace("LLM Score_", "", regex=False)

# --- Bar Chart ---
plt.figure(figsize=(12, 6))
sns.barplot(
    data=score_data,
    x="Section", y="Score",
    hue="Version",
    palette=custom_palette  # Apply the custom pastel colors
)
plt.title("Evaluation Scores: Before vs Improved (Human & LLM)")
plt.xlabel("Section")
plt.ylabel("Score (1–5)")
plt.xticks(rotation=45, ha="right")
plt.ylim(0, 6)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.legend(title="Prompt Version")
plt.tight_layout()
plt.show()

# %%
output_sections = split_llm_output_by_titles(improved_llm_output)
print(f"✅ Split into {len(output_sections)} sections.")
# Out:
# ✅ Split into 6 sections.

# %%
comparison
# Out:
#    Run_Before Company_Before Strategy_Before        Prompt Tag_Before  \
# 0           1        Spotify       Zero-Shot  zero-shot-v1-baseline-1
# 1           1        Spotify       Zero-Shot  zero-shot-v1-baseline-1
# 2           1        Spotify       Zero-Shot  zero-shot-v1-baseline-1
# 3           1        Spotify       Zero-Shot  zero-shot-v1-baseline-1
# 4           1        Spotify       Zero-Shot  zero-shot-v1-baseline-1
# 5           1        Spotify       Zero-Shot  zero-shot-v1-baseline-1
#
#                                   Section           Metric_Before  \
# 0                        Mission & Vision  Mission/Vision Insight
# 1                        Product Snapshot         Strategic Depth
# 2                       Strategic Roadmap       Roadmap Relevance
# 3    Feature Prioritization (ICE Scoring)  Prioritization Clarity
# 4                              SMART OKRs             OKR Quality
# 5  Next-Level Innovation & Product Vision      Visionary Thinking
#
#    LLM Score_Before  Human Score_Before  \
# 0               5.0                 4.0
# 1               3.0                 4.0
# 2               5.0                 5.0
# 3               5.0                 4.0
# 4               5.0                 3.0
# 5               4.0                 3.0
#
#                             Feedback_Before                 Lesson_Before  \
# 0            It is well-crafted and concise      Could be more visionary.
# 1      A good start, but could go deeper...        Use Porter's 5 forces.
# 2           Very creative and grouped well.    Add prioritization matrix.
# 3  Logical reasoning, but room for clarity.         Explain ICE criteria.
# 4          Unclear how numbers are derived.        Include baseline KPIs.
# 5  Ideas are decent but not out-of-the-box.  Target underserved segments.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            LLM Output Section_Before  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ### 1. Mission & Vision\n\n*📌 **Mission:** To unlock the potential of human creativity—by giving a million creative artists the opportunity to live off their art and billions of fans the opportunity to enjoy and be inspired by it.*\n\n*🔭 **Vision:** To shape the future of audio and be the world's leading audio platform, connecting creators and listeners through a personalized and immersive experience.*
# 1  ### 2. Product Snapshot\n*   **Target user personas:**\n    *   **The Music Lover:** Primarily focused on discovering new music, listening to favorite artists, and creating personalized playlists.\n    *   **The Podcast Enthusiast:** Seeks engaging audio content, informative discussions, and easy access to a variety of podcasts.\n    *   **The Casual Listener:** Uses Spotify for background music during work, commutes, or social gatherings.\n    *   **The Artist/Creator:** Aims to reach a wider audience, promote their music, and generate revenue through Spotify's platform.\n*   **Most common user pain points:**\n    *   **Limited free tier features:** Frequent ads, lack of offline listening, and restricted mobile controls can frustrate free users.\n    *   **Music discovery limitations:** While Spotify's algorithms are generally good, users sometimes struggle to find niche or up-and-coming artists.\n    *   **Podcast discoverability:** Finding relevant and interesting podcasts can be challenging due to the sheer volume of content.\n    *   **Artist compensation concerns:** Ongoing debate regarding fair compensation for artists on the platform.\n*   **UX bottlenecks or friction areas:**\n    *   **Playlist management:** Organizing and editing large playlists can be cumbersome.\n    *   **Offline download management:** Managing downloaded content and storage space could be more intuitive.\n    *   **Social features:** Opportunities to enhance social interaction and music sharing within the platform.\n*   **Current market position:** Leader. Spotify is the dominant player in the music streaming market with a substantial subscriber base and extensive catalog.\n*   **Key competitive threats and opportunities:**\n    *   **Threats:** Apple Music (deep integration with Apple ecosystem), Amazon Music (bundled with Prime), YouTube Music (vast video library), Tidal (Hi-Fi audio quality), and other regional players.\n    *   **Opportunities:** Expansion into new audio formats (audiobooks, live audio), deeper personalization through AI, enhanced social features, partnerships with hardware manufacturers, and geographic expansion in developing markets.\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                    ### 3. Strategic Roadmap\n\n**A. Immediate (0–3 months)**\n\n*   **Improve Offline Download Management:** Enhance the user interface and functionality for managing downloaded songs and podcasts. Allow users to prioritize download queues.\n*   **Address App Stability Issues:** Focus on bug fixes and performance improvements to reduce crashes and improve overall app stability, especially on older devices.\n*   **Enhance Playlist Collaboration:** Allow for more granular control over playlist permissions and collaboration features.\n\n**B. Mid-Term (3–12 months)**\n\n*   **AI-Powered Music Discovery:** Implement more advanced AI algorithms to personalize music recommendations based on listening history, mood, and context (e.g., time of day, location).\n*   **Enhanced Podcast Discovery:** Introduce features like personalized podcast recommendations, curated podcast playlists, and topic-based podcast browsing.\n*   **Integrate with more fitness trackers and wearables.** Deeper integration with wearable fitness tracking devices to tailor music recommendations to workout intensity.\n\n**C. Long-Term (12+ months)**\n\n*   **Interactive Audio Experiences:** Explore interactive audio formats that allow users to actively participate in podcasts or music experiences (e.g., choose-your-own-adventure podcasts, live Q&A sessions with artists).\n*   **Creator Monetization Platform:** Develop a comprehensive platform for artists and creators to monetize their content beyond traditional streaming royalties (e.g., direct fan subscriptions, merchandise sales, virtual concerts).\n*   **Spatial Audio Integration:** Implement spatial audio capabilities for immersive listening experiences, potentially leveraging partnerships with hardware manufacturers to optimize sound reproduction.\n
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ### 4. Feature Prioritization (ICE Scoring)\n\n| Feature | Impact | Confidence | Ease | Total |\n|--------------------------------------------|--------|------------|------|-------|\n| AI-Powered Music Discovery | 9 | 8 | 7 | 24 |\n| Enhanced Podcast Discovery | 8 | 8 | 7 | 23 |\n| Creator Monetization Platform | 8 | 7 | 6 | 21 |\n| Improve Offline Download Management | 7 | 9 | 5 | 21 |\n| Integrate with more fitness trackers and wearables | 7 | 7 | 6 | 20 |\n| Interactive Audio Experiences | 7 | 6 | 7 | 20 |\n| Enhance Playlist Collaboration | 6 | 8 | 5 | 19 |\n| Spatial Audio Integration | 6 | 7 | 6 | 19 |\n| Address App Stability Issues | 9 | 9 | 1 | 19 |\n\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ### 5. SMART OKRs\n\n*   **OKR 1 (Q1):** Increase user engagement with personalized music recommendations.\n    *   **Objective:** Enhance music discovery through AI-powered recommendations.\n    *   **Key Result 1:** Increase the percentage of users interacting with AI-generated playlists (Daily Mix, Release Radar) by 15%.\n    *   **Key Result 2:** Increase the average time spent listening to recommended tracks per user by 10%.\n    *   **Key Result 3:** Improve the user satisfaction score for music recommendations (measured via in-app surveys) from 4.0 to 4.3 (out of 5).\n\n*   **OKR 2 (Q2):** Grow podcast listenership and engagement.\n    *   **Objective:** Improve podcast discoverability and user experience.\n    *   **Key Result 1:** Increase the number of unique podcast listeners by 20%.\n    *   **Key Result 2:** Increase the average number of podcasts listened to per user per month by 15%.\n    *   **Key Result 3:** Improve podcast completion rate by 10%.\n\n
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ### 6. Next-Level Innovation & Product Vision\n\n*   **Spotify Wellness:** Integrate Spotify with health and wellness platforms. Provide personalized music recommendations based on user's mood, activity levels, and sleep patterns. Partner with meditation apps to offer guided meditations with curated soundscapes. This expands Spotify beyond pure entertainment into a daily wellness companion.\n*   **Spotify Communities:** Create dedicated spaces within the app for fans to connect with artists and other listeners. Implement features like forums, live Q&A sessions, and collaborative playlists curated by fans and artists together. This builds a stronger sense of community and loyalty within the Spotify ecosystem.\n*   **Spotify API for Developers:** Open up Spotify's API to allow third-party developers to create unique and innovative integrations. This could lead to features like:\n    *   Games that adapt to the music playing.\n    *   Fitness apps that use music to modulate workout intensity.\n    *   Smart home integrations that adjust lighting and temperature based on the music.\n*   **Spotify EdTech:** Integrate with educational platforms. Provide study playlists based on user preferences that are tailored to increase focus and learning retention. Partner with schools to provide discounted access.\n
#
#    Run_Improved Company_Improved Strategy_Improved  \
# 0             1          Spotify         Zero-Shot
# 1             1          Spotify         Zero-Shot
# 2             1          Spotify         Zero-Shot
# 3             1          Spotify         Zero-Shot
# 4             1          Spotify         Zero-Shot
# 5             1          Spotify         Zero-Shot
#
#                 Prompt Tag_Improved         Metric_Improved  \
# 0  improved-zero-shot-v1-baseline-1  Mission/Vision Insight
# 1  improved-zero-shot-v1-baseline-1         Strategic Depth
# 2  improved-zero-shot-v1-baseline-1       Roadmap Relevance
# 3  improved-zero-shot-v1-baseline-1  Prioritization Clarity
# 4  improved-zero-shot-v1-baseline-1             OKR Quality
# 5  improved-zero-shot-v1-baseline-1      Visionary Thinking
#
#    LLM Score_Improved  Human Score_Improved  \
# 0                 5.0                   5.0
# 1                 4.0                   4.0
# 2                 5.0                   5.0
# 3                 5.0                   4.0
# 4                 4.0                   4.0
# 5                 4.0                   4.0
#
#                                                                                                                                                                             Feedback_Improved  \
# 0                                                                                                                                                                   great vision and mission.
# 1                                            it can be more precise and in depth, it should list all of the current features, and relate all of them together with more depth and integration
# 2                                                                                                                                    comprehensive roadmap adjusted as injected in the prompt
# 3                                                                          i need to see why it chose those scores. also this prioritization should be aligned with all the previous insights
# 4  where did those numbers come from. what is the source, is it a guesstimate or hallucination or real number from an authentic source. Also OKR should take into account the previous inputs
# 5                                                      although the ideas are impressive but they are not out of the box. it can be improved by pushing further out of the known comfort zone
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Lesson_Improved  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     the vision improved significantly from the first run
# 1  it should itnegrate all of the sections together to give a product snappshot. also**Quantifying the impact of each force:** Instead of just stating "Moderate" or "High," providing data or estimates to support the assessment would add more depth. For example, for Bargaining Power of Suppliers, including information about the percentage of revenue paid out as royalties. *   **Prioritization:** The recommendations are all valid, but it would be helpful to see a prioritization of which strategies are most critical or have the highest potential impact. *   **Consideration of emerging trends:** Discussing how emerging trends like Web3 or AI might impact Spotify's strategy could also increase the depth. it should be like a story considering various aspects of the proudct.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                            the source of that numbers should be clear. ideally it should be calculated based on guestimate or directly extracted from a source mention the source so we make sure it is not hallucination. with more context it can be justified. also all of them should be aligned with the roadmap and feature and snapshot and vison
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             take into account the previous sections as well as the financial aspect of the feature, what is the potential gain from each
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Give the exact source of the numbers whether guestimate (give the formula) exact number (mention the source) or just a random generation from your imagination. also take into account all the previous outputs from mission, vision, product snapshot, roadmap
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   should push further and give more groundbreaking features.the response demonstrates strong visionary thinking, but it could be pushed further to achieve true game-changing potential.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1  ### 2. Product Snapshot\n\n**Overview:** Spotify is a leading digital music, podcast, and video streaming service that gives you access to millions of songs and other content from creators all over the world. Its core value proposition is providing convenient and on-demand access to a vast library of audio content, personalized recommendations, and a seamless user experience across various devices.\n\n**Users:** Spotify caters to a broad demographic, including music enthusiasts, podcast listeners, students, and anyone seeking audio entertainment and information.  They have both Free (ad-supported) and Premium (subscription-based, ad-free) users.\n\n**Features:**\n\n*   **Music Streaming:** Vast library of songs, albums, and playlists.\n*   **Podcast Streaming:** A growing selection of podcasts across various genres.\n*   **Personalized Recommendations:** AI-powered recommendations based on listening habits.\n*   **Offline Playback:** Ability to download content for offline listening (Premium).\n*   **Cross-Device Compatibility:** Support for smartphones, tablets, computers, smart speakers, and more.\n*   **Social Sharing:** Ability to share music and playlists with friends on social media.\n*   **Spotify Connect:** Seamlessly control playback on other devices.\n*   **Spotify Wrapped:** Annual personalized listening data recap.\n*   **Video Podcasts:** Support for video podcasts.\n\n**Audience:** Spotify targets a wide range of demographics, primarily focusing on millennials and Gen Z, but also expanding its reach to older demographics through podcasts and diverse content offerings. Geographically, Spotify aims for global reach, focusing on both established and emerging markets.\n\n**Competitive Edge:** Spotify's competitive advantage lies in its vast content library, personalized recommendations, and seamless user experience. Its strong brand recognition and established ecosystem also contribute to its competitive edge.\n\n**Porter's Five Forces Analysis:**\n\n| Force                  | Analysis                                                                                                                                                                                                                                                                                                                                                                                                                                           | Strategic Recommendation                                                                                                                                                                                                                                                                 |\n| ----------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |\n| **Threat of New Entrants** | *   **Moderate:** High initial investment costs in content acquisition and technology infrastructure pose a barrier. Brand recognition and established user base are crucial.  However, niche streaming services focusing on specific genres or communities can pose a threat.                                                                                                                                                                        | *   Continuously innovate to enhance user experience (e ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ### 3. Strategic Roadmap\n\n| Quarter | Focus Area                       | Initiatives                                                                                                                                                                        ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...

# %%
# Melt just human scores
human_score_melted = comparison[["Section", "Human Score_Before", "Human Score_Improved"]].melt(
    id_vars="Section", var_name="Version", value_name="Score"
)
human_score_melted["Version"] = human_score_melted["Version"].str.replace("Human Score_", "", regex=False)

# Bar chart
plt.figure(figsize=(12, 6))
sns.barplot(data=human_score_melted, x="Section", y="Score", hue="Version",palette=custom_palette)
plt.title("Human Score Comparison – Before vs Improved")
plt.xlabel("Section")
plt.ylabel("Human Score")
plt.xticks(rotation=45, ha="right")
plt.ylim(0, 6)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.legend(title="Prompt Version")
plt.tight_layout()
plt.show()

# %%
avg_human_before = score_data[(score_data["Metric"] == "Human") & (score_data["Version"] == "Before")]["Score"].mean()
avg_human_after = score_data[(score_data["Metric"] == "Human") & (score_data["Version"] == "Improved")]["Score"].mean()
avg_llm_before = score_data[(score_data["Metric"] == "LLM") & (score_data["Version"] == "Before")]["Score"].mean()
avg_llm_after = score_data[(score_data["Metric"] == "LLM") & (score_data["Version"] == "Improved")]["Score"].mean()

# Summary description block (Markdown-style output)

summary_md = f"""
### 📊 Evaluation Summary

Across all evaluated sections:

- **Human Score** improved from **{avg_human_before:.2f} → {avg_human_after:.2f}**
- **LLM Score** improved from **{avg_llm_before:.2f} → {avg_llm_after:.2f}**

These results validate the impact of prompt iteration. While the improvements are not uniformly large across all sections, even a modest average increase of **{avg_human_after - avg_human_before:.2f}** in human ratings suggests that refining structure, tone, and alignment significantly enhances LLM outputs.

"""

display(Markdown(summary_md))
# Out:
# ### 📊 Evaluation Summary
#
# Across all evaluated sections:
#
# - **Human Score** improved from **3.83 → 4.33**
# - **LLM Score** improved from **4.50 → 4.50**
#
# These results validate the impact of prompt iteration. While the improvements are not uniformly large across all sections, even a modest average increase of **0.50** in human ratings suggests that refining structure, tone, and alignment significantly enhances LLM outputs.

# %% [markdown]
# In the first phase of my project, I focused on benchmarking baseline and improved prompts using a zero-shot strategy. I created a unified evaluation table combining LLM and human scores, visualized their differences with custom-styled bar charts and heatmaps, and aligned the entire dashboard with a consistent blue-pink pastel theme.
#
# Having explored the foundational prompt quality, the next stage is about layered prompting strategies and gradually transitioning into an agentic system. I plan to start with few-shot examples where appropriate (for instance, in reasoning-heavy sections like OKRs or Roadmap), then scale to Chain-of-Thought (CoT) and Tree-of-Thought (ToT) methods.
#
# Once these are tested individually, I'll explore the ReAct prompting approach, which blends reasoning with tool use — an ideal stepping stone to build a multi-agent architecture. The final layer integrates document embeddings and RAG (Retrieval Augmented Generation) so agents can ground their decisions in real data.

# %% [markdown]
# ## 🔄 Prompt Strategy & System Expansion Plan
#
# In the initial stage of this project, I focused on building a structured comparison between baseline and improved zero-shot prompts. This included generating evaluation tables, visualizing LLM vs Human scores,dashboard and creating a foundation for further development.
# Moving forward, the plan is to progressively experiment with more advanced prompting techniques, integrating modular agents, and enhancing them with document-grounded retrieval.
#
# ---
#
# ###  Prompt Strategy Expansion Checklist
#
# #### 🔁 Prompt Variants
#
# - ✅ Mission & Vision → Zero-Shot
# - ✅ Product Snapshot → Zero-Shot
# - 🧠 SMART OKRs → Few-Shot Example Prompt
# - 🔢 ICE Prioritization → Chain-of-Thought
# - 💡 Innovation/Vision → Tree-of-Thought
# - 🎯 Feature Ideation → ReAct
#
# #### 🤖 Agentic System Design
# - [ ] Define modular agents (Feature Ideator, Roadmap Generator, etc.)
# - [ ] Implement ReAct-based coordination between agents
# - [ ] Visualize agent hand-offs and logs in dashboard
#
# #### 📎 Grounding + RAG
# - [ ] Build embedding store from documents (strategy decks, OKRs, feedback)
# - [ ] Use similarity search in prompt context for better grounding
# - [ ] Log source attribution in agent outputs
#
# #### 📊 Evaluation
# - [ ] Track Human vs LLM Scores by prompt type
# - [ ] Score agent outputs per section using custom rubric
# - [ ] Visualize improvement per strategy in the dashboard
#
# ---
#
#
# ### 🔁 Prompt Evolution Flow
#
# Zero-Shot
#    ↓
# Few-Shot (targeted)
#    ↓
# Chain-of-Thought (CoT)
#    ↓
# Tree-of-Thought (ToT)
#    ↓
# ReAct Prompting (planning + action)
#    ↓
# Multi-Agent System
#    ↓
#  Embeddings & Retrieval (RAG)
#
# ---
#
# ### 🔗 Live Dashboard
#
# 👉 [Open the Live Nextify Dashboard](https://nextify-dashboard-100.streamlit.app/)

# %% [markdown]
# #### 🧠 One-Shot Prompting – Give one example to guide the model
# Now apply to OKR

# %% [markdown]
# ## 🧩 **Few-Shot Prompting** – Give the LLM model few examples

# %% [markdown]
# From here I decided to add each prompting technique for enhancement to the section that needed that the most, at the end we can combine different prompting techniques on different sections and how they are improved then we use the strategy when breaking each section into an agent

# %%
# === 🧩 1. Few-Shot Prompt Block for SMART OKRs ===
SMART_OKRS_FEW_SHOT_PROMPT = """
### SMART OKRs

---
For the OKR Use the following examples as good and bad examples and learn from them generate your recommended OKR learning from the examples

🟢 GOOD EXAMPLE 1 — Strong OKR: AI Recommendations
markdown
### OKR 1 (Q1): Increase engagement with personalized recommendations

**Objective:** Enhance user experience through AI-driven music discovery.

| Key Result | Target | Estimate Rationale |
|------------|--------|---------------------|
| KR1.1 | +15% increase in DAU interacting with Daily Mix & Discover Weekly | Based on existing 40% base usage, nudging and new placements can lift this meaningfully. |
| KR1.2 | +10% increase in time spent listening to recommended tracks | Median session = ~35 mins; 10% = ~3.5 min lift via stickier content. |
| KR1.3 | Improve satisfaction score from 4.0 → 4.3 (out of 5) | Feasible from historical tuning and GenAI personalization rollouts. |

**Why it’s good:**
- Clear business objective (personalization = retention)
- Uses real user metrics (DAU, listening time, satisfaction)
- Realistic yet ambitious target values

---
🟢 GOOD EXAMPLE 2 - Strong OKR: Podcast Growth
### OKR 2 (Q2): Boost podcast reach and completion

**Objective:** Drive more users to discover and complete podcasts.

| Key Result | Target | Estimate Rationale |
|------------|--------|---------------------|
| KR2.1 | +20% increase in unique monthly podcast listeners | Based on typical baseline and homepage placement campaigns. |
| KR2.2 | +10% increase in average listen-through rate | Autoplay, intro-skip, and shorter episodes improve completion. |
| KR2.3 | Launch 2 podcast-specific discovery features | Use personalization + trending visibility per market. |

**Why it’s good:**
- Balanced across growth, retention, and product velocity
- Direct link to known friction in podcast UX
- Specific features + reasonable metrics included

---
🔴 Bad example 1 — Too Vague / No Metrics
**Objective:** Improve overall user happiness.

| Key Result | Target | Estimate Rationale |
|------------|--------|---------------------|
| KR1 | Add cool animations to loading screen | None provided |
| KR2 | Let users share more | No baseline or goal |
| KR3 | Make UI feel better | No measurable outcome |

**Why it’s bad:**
- Lacks measurable outcomes
- No time bounds, no KPIs
- KR1 is cosmetic-only and unrelated to business goals

---
🔴 Bad example 2 —  Unrealistic & Unaligned
### OKR: Dominate the entire audio industry in Q2

**Objective:** Become the #1 platform in the world in 3 months.

| Key Result | Target | Estimate Rationale |
|------------|--------|---------------------|
| KR1 | Convert 100% of free users to Premium | Unrealistic and never observed historically |
| KR2 | Increase MAU by 300% | No strategy or budget match |
| KR3 | Acquire all regional podcast networks | M&A-level move, not Q2 roadmap

**Why it’s bad:**
- Overly ambitious and not time-feasible
- no number mentioned
- No execution path
- Not based on current metrics or product reality
---
Now for **Spotify**, based on the following:

- ✅ Company Mission and Vision
- ✅ Product Snapshot (target users, pain points)
- ✅ Strategic Roadmap and Prioritized Features

Use these as context to generate your OKRs.

You may refer to the previously improved sections stored in the LLM Output Table under `LLM Output Section` for those parts.

Now generate **2 OKRs**, each with:
- Objective
- 2–3 Key Results (with targets + rationale)
- Total alignment with company strategy and roadmap.

"""

# %%
# === 🧠 2. Prompt Builder (single section only) ===
def build_single_section_prompt(company, section_title, prompt_block, strategy="Few_Shot", prompt_tag="Few_Shot_OKR_improvement"):
    return f"""
# 🎯 {strategy} | {prompt_tag} | {section_title}

You are Nextify — an AI-powered product strategy assistant.

The product to analyze is: **{company}**

---

## Section: {section_title}

{prompt_block}
""".strip()

# %%
# === 🧾 3. Evaluation Log (single section only) ===
def log_single_section_with_scores(
    company,
    strategy,
    prompt_tag,
    section,
    llm_output,
    llm_score,
    human_score,
    feedback,
    lesson,
    metric="OKR Quality",  
    table_path="all_experiment_view.csv"
):

    # Define expected schema
    columns = [
        "Run", "Company", "Strategy", "Prompt Tag", "Section", "Metric",
        "LLM Score", "Human Score", "Feedback", "Lesson", "LLM Output Section"
    ]

    # Load or initialize
    if os.path.exists(table_path):
        all_experiment_view = pd.read_csv(table_path)
    else:
        all_experiment_view = pd.DataFrame(columns=columns)

    # Ensure all required columns are present and properly typed
    for col in columns:
        if col not in all_experiment_view.columns:
            all_experiment_view[col] = ""
    if "Run" in all_experiment_view.columns:
        all_experiment_view["Run"] = pd.to_numeric(all_experiment_view["Run"], errors="coerce")

    # Determine next run ID by same company-strategy-prompt combo
    same_combo = all_experiment_view[
        (all_experiment_view["Company"].str.lower().fillna("") == company.lower()) &
        (all_experiment_view["Strategy"].str.lower().fillna("") == strategy.lower()) &
        (all_experiment_view["Prompt Tag"].str.lower().fillna("") == prompt_tag.lower())
    ]
    if not same_combo.empty:
        next_run = same_combo["Run"].max() + 1
    else:
        next_run = 1
    print(f"🧮 Run number for {company} ({strategy}): {int(next_run)}")

    # Define uniqueness condition
    condition = (
        (all_experiment_view["Company"] == company) &
        (all_experiment_view["Strategy"] == strategy) &
        (all_experiment_view["Prompt Tag"] == prompt_tag) &
        (all_experiment_view["Section"] == section)
    )

    # Check if it already exists → skip
    if condition.any():
        print(f"⚠️ Already logged: {company} | {section} | {prompt_tag} — skipping.")
        return

    # Build row
    row = {
        "Run": int(next_run),
        "Company": company,
        "Strategy": strategy,
        "Prompt Tag": prompt_tag,
        "Section": section,
        "Metric": metric,
        "LLM Score": float(llm_score) if llm_score is not None else "",
        "Human Score": float(human_score) if human_score is not None else "",
        "Feedback": feedback,
        "Lesson": lesson,
        "LLM Output Section": llm_output
    }

    # Append
    all_experiment_view.loc[len(all_experiment_view)] = row
    all_experiment_view.to_csv(table_path, index=False)
    print(f"✅ Logged Run {next_run} — {company} | {section} | {prompt_tag}")

# %%
section = "SMART OKRs"
strategy = "Few_Shot"
prompt_tag = "Few_Shot_OKR_improvement"

okr_prompt = build_single_section_prompt(company_name, section, SMART_OKRS_FEW_SHOT_PROMPT, strategy, prompt_tag)

okr_output = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=okr_prompt
).text

# Display result
print("📋 Improved SMART OKRs Output:\n")
Markdown(okr_output)
# Out:
# 📋 Improved SMART OKRs Output:
# Okay, I understand. Based on the provided examples and the context around Spotify, I will generate two SMART OKRs for them.
#
# **OKRs for Spotify**
#
# ### OKR 1 (Q3): Drive Premium Subscriber Growth through Enhanced Music Discovery
#
# **Objective:** Increase premium subscriptions by improving user engagement with personalized music discovery and exclusive content.
#
# | Key Result | Target | Estimate Rationale |
# |------------|--------|---------------------|
# | KR1.1 | Increase Premium subscriber conversion rate from personalized playlists (Daily Mix, Discover Weekly, Release Radar) by 10% | Leveraging improved AI models for personalized recommendations can demonstrably drive conversions. Current conversion rate is X%, a 10% increase is achievable with better curation. |
# | KR1.2 | Increase the number of premium users listening to exclusive content (e.g., Spotify Singles, Live Sessions) by 15% |  Promoting exclusive content more effectively through personalized recommendations and in-app placements will drive consumption amongst premium users. |
# | KR1.3 | Improve Premium user retention rate by 2% by offering personalized music recommendation  | Better recommendations leads to higher user satisfaction, reducing churn. A 2% improvement is a reasonable target based on historical data. |
#
# **Why it’s good:**
#
# *   Directly supports the core business goal of growing premium subscriptions.
# *   Focuses on enhancing existing features (personalized playlists) and content (exclusive tracks).
# *   Metrics are measurable and realistic based on historical data and planned improvements.
#
# ---
#
# ### OKR 2 (Q3): Enhance User Engagement Through Improved Podcast Experience
#
# **Objective:** Increase user engagement with podcasts by improving discoverability, playback experience, and exclusive content offerings.
#
# | Key Result | Target | Estimate Rationale |
# |------------|--------|---------------------|
# | KR2.1 | Increase monthly active users (MAU) engaging with podcasts by 12% |  Improved discoverability features (e.g., personalized podcast recommendations, curated podcast playlists) will attract more users to podcasts. |
# | KR2.2 | Increase average podcast listen-through rate by 8% | Implementing features like variable playback speed, chapter markers, and smarter recommendations of related content will improve completion rates.  |
# | KR2.3 | Launch 3 new exclusive Spotify Original podcast series |  Exclusive content is a key driver of engagement and can attract new users to the platform and encourage deeper engagement with podcasts. |
#
# **Why it’s good:**
#
# *   Focuses on improving a key area of growth for Spotify (podcasts).
# *   Addresses specific aspects of the podcast experience (discoverability, playback, content).
# *   Balanced approach with a focus on user acquisition, engagement, and content creation.

# %%
# --- Display the generated OKR in markdown first ---
display(Markdown("### 📄 Few-Shot OKRs Output"))
display(Markdown(okr_output))
4
# --- Ask the model to evaluate its own response ---
eval_prompt = f"""
You are an evaluator AI. Analyze the following OKRs for {company_name}.

Score them as a full set, using these criteria:
- Are both OKRs aligned with the company’s roadmap and strategy?
- Do the Key Results have realistic, quantified targets?
- Are they time-bound and feasible to deliver in one quarter each?

Respond in this format:

LLM Score (1–5): [score for overall OKR set]
Reason: [explanation of the score]

OKRs to evaluate:
{okr_output}
"""

llm_eval = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=eval_prompt
).text

# Show LLM evaluation
display(Markdown("### 🤖 LLM Self-Evaluation of Combined OKRs"))
print(llm_eval)

# Extract the score from LLM evaluation
match = re.search(r"LLM Score.*?(\d)", llm_eval)
llm_score = int(match.group(1)) if match else None

# --- Check if human has already evaluated this section ---
already_scored = all_experiment_view[
    (all_experiment_view["Company"] == company_name) &
    (all_experiment_view["Strategy"] == strategy) &
    (all_experiment_view["Prompt Tag"] == prompt_tag) &
    (all_experiment_view["Section"] == section) &
    (all_experiment_view["Human Score"].notnull())
]

if already_scored.empty:
    display(Markdown("### 👤 Human Evaluation (Your Turn)"))
    human_score = input("🧠 Your score (1–5): ").strip()
    feedback = input("💬 Your feedback: ")
    lesson = input("📘 Lesson learned: ")
else:
    print("✅ Human evaluation already exists — skipping input.")
    row = already_scored.iloc[0]
    human_score = row["Human Score"]
    feedback = row["Feedback"]
    lesson = row["Lesson"]
# Out:
# ### 📄 Few-Shot OKRs Output
# Okay, I understand. Based on the provided examples and the context around Spotify, I will generate two SMART OKRs for them.
#
# **OKRs for Spotify**
#
# ### OKR 1 (Q3): Drive Premium Subscriber Growth through Enhanced Music Discovery
#
# **Objective:** Increase premium subscriptions by improving user engagement with personalized music discovery and exclusive content.
#
# | Key Result | Target | Estimate Rationale |
# |------------|--------|---------------------|
# | KR1.1 | Increase Premium subscriber conversion rate from personalized playlists (Daily Mix, Discover Weekly, Release Radar) by 10% | Leveraging improved AI models for personalized recommendations can demonstrably drive conversions. Current conversion rate is X%, a 10% increase is achievable with better curation. |
# | KR1.2 | Increase the number of premium users listening to exclusive content (e.g., Spotify Singles, Live Sessions) by 15% |  Promoting exclusive content more effectively through personalized recommendations and in-app placements will drive consumption amongst premium users. |
# | KR1.3 | Improve Premium user retention rate by 2% by offering personalized music recommendation  | Better recommendations leads to higher user satisfaction, reducing churn. A 2% improvement is a reasonable target based on historical data. |
#
# **Why it’s good:**
#
# *   Directly supports the core business goal of growing premium subscriptions.
# *   Focuses on enhancing existing features (personalized playlists) and content (exclusive tracks).
# *   Metrics are measurable and realistic based on historical data and planned improvements.
#
# ---
#
# ### OKR 2 (Q3): Enhance User Engagement Through Improved Podcast Experience
#
# **Objective:** Increase user engagement with podcasts by improving discoverability, playback experience, and exclusive content offerings.
#
# | Key Result | Target | Estimate Rationale |
# |------------|--------|---------------------|
# | KR2.1 | Increase monthly active users (MAU) engaging with podcasts by 12% |  Improved discoverability features (e.g., personalized podcast recommendations, curated podcast playlists) will attract more users to podcasts. |
# | KR2.2 | Increase average podcast listen-through rate by 8% | Implementing features like variable playback speed, chapter markers, and smarter recommendations of related content will improve completion rates.  |
# | KR2.3 | Launch 3 new exclusive Spotify Original podcast series |  Exclusive content is a key driver of engagement and can attract new users to the platform and encourage deeper engagement with podcasts. |
#
# **Why it’s good:**
#
# *   Focuses on improving a key area of growth for Spotify (podcasts).
# *   Addresses specific aspects of the podcast experience (discoverability, playback, content).
# *   Balanced approach with a focus on user acquisition, engagement, and content creation.
# ### 🤖 LLM Self-Evaluation of Combined OKRs
# LLM Score (4/5):
# Reason: The OKRs are generally well-structured and aligned with Spotify's likely strategy of increasing premium subscriptions and enhancing the podcast experience. The Key Results are mostly quantifiable and time-bound, and the rationales provided offer plausible explanations for the targets.
#
# However, there's room for improvement:
#
# *   **KR1.3:** While "offering personalized music recommendation" ties to the Objective, the KR itself is about *retention rate*. More directly connecting the offering to the measurement would strengthen the OKR. It also feels a bit vague, what specific action leads to this retention.
# *   **KR2.3:** is less quantifiable than the others. While launching podcast series is concrete, the *impact* of these series isn't directly measured within this OKR. It's assumed they will contribute to MAU and listen-through rate but isolating that impact would be valuable (perhaps a target number of downloads/listens for these new exclusives).
# *   **Feasibility:** While the rationales explain the targets, external knowledge of Spotify's resources and current performance would be needed to fully assess feasibility. Are the AI improvements for playlist recommendations already in progress, or are they a new initiative? Do they have the bandwidth to launch 3 new exclusive podcast series?
# *   **Alignment:** The objectives are quite distinct. There is a potential strategy where improving music discovery could *also* drive podcast listening, or vice versa. Cross-pollination is something that could make the OKRs a bit more strongly aligned.
#
# Overall, the set is good, but with some refinements around measurability and a stronger connection between actions and results, it could be excellent.
#
# ✅ Human evaluation already exists — skipping input.

# %%
all_experiment_view
# Out:
#     Run  Company         Strategy                        Prompt Tag  \
# 0     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 1     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 2     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 3     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 4     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 5     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 6     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 7     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 8     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 9     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 10    1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 11    1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 12    1  Spotify         Few_Shot          Few_Shot_OKR_improvement
# 13    1  Spotify              CoT           cot-Product-Snapshot-v1
# 14    1  Spotify  Tree-of-Thought               tree-thought-ice-v1
#
#                                    Section                  Metric  LLM Score  \
# 0                         Mission & Vision  Mission/Vision Insight        5.0
# 1                         Product Snapshot         Strategic Depth        3.0
# 2                        Strategic Roadmap       Roadmap Relevance        5.0
# 3     Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 4                               SMART OKRs             OKR Quality        5.0
# 5   Next-Level Innovation & Product Vision      Visionary Thinking        4.0
# 6                         Mission & Vision  Mission/Vision Insight        5.0
# 7                         Product Snapshot         Strategic Depth        4.0
# 8                        Strategic Roadmap       Roadmap Relevance        5.0
# 9     Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 10                              SMART OKRs             OKR Quality        4.0
# 11  Next-Level Innovation & Product Vision      Visionary Thinking        4.0
# 12                              SMART OKRs             OKR Quality        4.0
# 13                        Product Snapshot         Strategic Depth        4.0
# 14    Feature Prioritization (ICE Scoring)  Prioritization Clarity        4.0
#
#     Human Score  \
# 0           4.0
# 1           4.0
# 2           5.0
# 3           4.0
# 4           3.0
# 5           3.0
# 6           5.0
# 7           4.0
# 8           5.0
# 9           4.0
# 10          4.0
# 11          4.0
# 12          4.5
# 13          4.0
# 14          4.5
#
#                                                                                                                                                                                                                               Feedback  \
# 0                                                                                                                                                                                                       It is well-crafted and concise
# 1                                                                                                                                                                                                 A good start, but could go deeper...
# 2                                                                                                                                                                                                      Very creative and grouped well.
# 3                                                                                                                                                                                             Logical reasoning, but room for clarity.
# 4                                                                                                                                                                                                     Unclear how numbers are derived.
# 5                                                                                                                                                                                             Ideas are decent but not out-of-the-box.
# 6                                                                                                                                                                                                            great vision and mission.
# 7                                                                                     it can be more precise and in depth, it should list all of the current features, and relate all of them together with more depth and integration
# 8                                                                                                                                                                             comprehensive roadmap adjusted as injected in the prompt
# 9                                                                                                                   i need to see why it chose those scores. also this prioritization should be aligned with all the previous insights
# 10                                          where did those numbers come from. what is the source, is it a guesstimate or hallucination or real number from an authentic source. Also OKR should take into account the previous inputs
# 11                                                                                              although the ideas are impressive but they are not out of the box. it can be improved by pushing further out of the known comfort zone
# 12  the structure improved with the reason behind the numbers explained but the model needs to be exposed to mroe data on market trend and analysis to be able to set a solid logic behind the numbers and give more realistic numbers
# 13                               it becomes so much better than before, but still needs more depth. by embedding strategic documents and reference sites it would be way more better. I think the prompting reaches its maximum output
# 14                                  It improves tremendously from the last instance. It is well argumented. However still we should input data and give it memory, embeddings and logic to be able to connect the dots based on data.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Lesson  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Could be more visionary.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Use Porter's 5 forces.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Add prioritization matrix.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Explain ICE criteria.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Include baseline KPIs.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Target underserved segments.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      the vision improved significantly from the first run
# 7   it should itnegrate all of the sections together to give a product snappshot. also**Quantifying the impact of each force:** Instead of just stating "Moderate" or "High," providing data or estimates to support the assessment would add more depth. For example, for Bargaining Power of Suppliers, including information about the percentage of revenue paid out as royalties. *   **Prioritization:** The recommendations are all valid, but it would be helpful to see a prioritization of which strategies are most critical or have the highest potential impact. *   **Consideration of emerging trends:** Discussing how emerging trends like Web3 or AI might impact Spotify's strategy could also increase the depth. it should be like a story considering various aspects of the proudct.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                             the source of that numbers should be clear. ideally it should be calculated based on guestimate or directly extracted from a source mention the source so we make sure it is not hallucination. with more context it can be justified. also all of them should be aligned with the roadmap and feature and snapshot and vison
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              take into account the previous sections as well as the financial aspect of the feature, what is the potential gain from each
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Give the exact source of the numbers whether guestimate (give the formula) exact number (mention the source) or just a random generation from your imagination. also take into account all the previous outputs from mission, vision, product snapshot, roadmap
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   should push further and give more groundbreaking features.the response demonstrates strong visionary thinking, but it could be pushed further to achieve true game-changing potential.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      we need to add market analysis and trend datset to this section in order to get an improved version
# 13                                                                                                                                                                                                                                                                                                                                                                                                                       The analysis could benefit from demonstrating the connection between user needs/pain points identified earlier in the document, and how addressing these can strategically mitigate specific competitive forces. For example, investing in lossless/hifi audio is in line with the preferences of some of the premium users and could help attract customers from Tidal or Deezer.
# 14                                                                                                                                                                                                                                                                                                                                                                                                 However, the evaluation could be improved by explicitly referencing a specific, hypothetical mission, roadmap, or user research (e.g. 'our mission is to improve user engagement', 'this aligns with the Q3 roadmap to improve on-boarding'). Right now it gestures vaguely at the "company goals" or "overall goals and product roadmap". It's *implied*, but not *grounded* in those earlier contexts.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# ...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 13  Okay, let's analyze Spotify and identify key opportunities for improvement and growth. I'll focus on user personas, pain points, UX friction, market position, competitive landscape, and a Porter's Five Forces analysis to inform strategic recommendations. I'll pay close attention to industry trends and competitor actions to provide actionable insights for Spotify's product strategy. I will also focus on justifying the ICE scores I give at the end.\n\n### 1. 🎯 Target User Personas\n\nLet’s think through this...\n\nSpotify's user base is diverse, spanning age groups, geographic locations, and musical tastes. Understanding these different user personas is crucial for tailoring the experience and driving engagement. We can broadly categorize users into Free and Premium tiers, with further segmentation within each tier.\n\n*   **Free Users:** This group represents a significant portion of Spotify's user base, often younger and more price-sensitive.\n    *   *Generation Z (13-25):* Discovers new music through social media, prioritizes cost-effectiveness, and values personalized playlists. Located globally, with high penetration in emerging markets. Psychographically, they are adventurous, trend-conscious, and digitally native.\n    *   *Millennial Casual Listeners (26-40):* Listens to music during commutes, workouts, or social gatherings. Less concerned with audio quality, but values convenience and breadth of content. Geographically diverse, with a mix of urban and suburban residents. Psychographically, they are practical, value-driven, and convenience-oriented.\n*   **Premium Users:** This group is willing to pay for an ad-free experience, offline listening, and higher audio quality.\n    *   *Gen X Audiophiles (41-55):* Values high-fidelity audio and curated playlists. Often uses Spotify on multiple devices, including home audio systems. Primarily located in developed countries. Psychographically, they are discerning, quality-focused, and tech-savvy.\n    *   *Millennial Music Enthusiasts (26-40):* Actively seeks out new music, follows artists, and creates personalized playlists. Uses Spotify daily and across various devices. Globally present, with a strong presence in urban centers. Psychographically, they are passionate, engaged, and culturally aware.\n    *   *Creator-Facing: Artists & Podcasters:* Use Spotify for Artists/Spotify for Podcasters to manage their presence, track performance, and connect with fans. Geographically diverse, from bedroom artists to established professionals. Psychographically, they are driven, creative, and entrepreneurial.\n\n**Summary Insight:** Spotify needs to balance the needs of its diverse user base, offering a compelling free tier while providing enough value to convert users to Premium. Targeting specific generational and psychographic segments with tailored content and features will be key to growth. The creator-facing personas are crucial to maintain and attract more content to the platform, indirectly attracting their audiences.\n\n### 2. 🧩 Key User Pain Points\n\nLet’s think through this...\n\nUser pain points can significantly impact engagement and conversion rates. Identifying and addressing these issues is crucial for improving user satisfaction and driving growth. Analysis of app store reviews, social media feedback, and user surveys reveals several key pain points:\n\n*   **Free Tier Limitations:** Frequent ads, limited offline downloads, and shuffle-only playback on mobile devices are major frustrations for free users. This directly impacts their willingness to convert to Premium.\n*   **Discovery Challenges:** While Spotify's algorithm is generally effective, users sometimes struggle to find new music outside their usual genres or artists. The sheer volume of content can be overwhelming.\n*   **Podcast Experience:** Podcast discovery and organization can be improved. Users often struggle to find relevant podcasts and manage their subscriptions effectively.\n*   **Audio Quality: ...
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...

# %%
log_single_section_with_scores(
    company=company_name,
    strategy=strategy,
    prompt_tag=prompt_tag,
    section=section,
    llm_output=okr_output,
    llm_score=llm_score,
    human_score=human_score,
    feedback=feedback,
    lesson=lesson
)
# Out:
# 🧮 Run number for Spotify (Few_Shot): 2
# ⚠️ Already logged: Spotify | SMART OKRs | Few_Shot_OKR_improvement — skipping.

# %%
all_experiment_view
# Out:
#     Run  Company         Strategy                        Prompt Tag  \
# 0     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 1     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 2     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 3     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 4     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 5     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 6     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 7     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 8     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 9     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 10    1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 11    1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 12    1  Spotify         Few_Shot          Few_Shot_OKR_improvement
# 13    1  Spotify              CoT           cot-Product-Snapshot-v1
# 14    1  Spotify  Tree-of-Thought               tree-thought-ice-v1
#
#                                    Section                  Metric  LLM Score  \
# 0                         Mission & Vision  Mission/Vision Insight        5.0
# 1                         Product Snapshot         Strategic Depth        3.0
# 2                        Strategic Roadmap       Roadmap Relevance        5.0
# 3     Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 4                               SMART OKRs             OKR Quality        5.0
# 5   Next-Level Innovation & Product Vision      Visionary Thinking        4.0
# 6                         Mission & Vision  Mission/Vision Insight        5.0
# 7                         Product Snapshot         Strategic Depth        4.0
# 8                        Strategic Roadmap       Roadmap Relevance        5.0
# 9     Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 10                              SMART OKRs             OKR Quality        4.0
# 11  Next-Level Innovation & Product Vision      Visionary Thinking        4.0
# 12                              SMART OKRs             OKR Quality        4.0
# 13                        Product Snapshot         Strategic Depth        4.0
# 14    Feature Prioritization (ICE Scoring)  Prioritization Clarity        4.0
#
#     Human Score  \
# 0           4.0
# 1           4.0
# 2           5.0
# 3           4.0
# 4           3.0
# 5           3.0
# 6           5.0
# 7           4.0
# 8           5.0
# 9           4.0
# 10          4.0
# 11          4.0
# 12          4.5
# 13          4.0
# 14          4.5
#
#                                                                                                                                                                                                                               Feedback  \
# 0                                                                                                                                                                                                       It is well-crafted and concise
# 1                                                                                                                                                                                                 A good start, but could go deeper...
# 2                                                                                                                                                                                                      Very creative and grouped well.
# 3                                                                                                                                                                                             Logical reasoning, but room for clarity.
# 4                                                                                                                                                                                                     Unclear how numbers are derived.
# 5                                                                                                                                                                                             Ideas are decent but not out-of-the-box.
# 6                                                                                                                                                                                                            great vision and mission.
# 7                                                                                     it can be more precise and in depth, it should list all of the current features, and relate all of them together with more depth and integration
# 8                                                                                                                                                                             comprehensive roadmap adjusted as injected in the prompt
# 9                                                                                                                   i need to see why it chose those scores. also this prioritization should be aligned with all the previous insights
# 10                                          where did those numbers come from. what is the source, is it a guesstimate or hallucination or real number from an authentic source. Also OKR should take into account the previous inputs
# 11                                                                                              although the ideas are impressive but they are not out of the box. it can be improved by pushing further out of the known comfort zone
# 12  the structure improved with the reason behind the numbers explained but the model needs to be exposed to mroe data on market trend and analysis to be able to set a solid logic behind the numbers and give more realistic numbers
# 13                               it becomes so much better than before, but still needs more depth. by embedding strategic documents and reference sites it would be way more better. I think the prompting reaches its maximum output
# 14                                  It improves tremendously from the last instance. It is well argumented. However still we should input data and give it memory, embeddings and logic to be able to connect the dots based on data.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Lesson  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Could be more visionary.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Use Porter's 5 forces.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Add prioritization matrix.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Explain ICE criteria.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Include baseline KPIs.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Target underserved segments.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      the vision improved significantly from the first run
# 7   it should itnegrate all of the sections together to give a product snappshot. also**Quantifying the impact of each force:** Instead of just stating "Moderate" or "High," providing data or estimates to support the assessment would add more depth. For example, for Bargaining Power of Suppliers, including information about the percentage of revenue paid out as royalties. *   **Prioritization:** The recommendations are all valid, but it would be helpful to see a prioritization of which strategies are most critical or have the highest potential impact. *   **Consideration of emerging trends:** Discussing how emerging trends like Web3 or AI might impact Spotify's strategy could also increase the depth. it should be like a story considering various aspects of the proudct.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                             the source of that numbers should be clear. ideally it should be calculated based on guestimate or directly extracted from a source mention the source so we make sure it is not hallucination. with more context it can be justified. also all of them should be aligned with the roadmap and feature and snapshot and vison
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              take into account the previous sections as well as the financial aspect of the feature, what is the potential gain from each
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Give the exact source of the numbers whether guestimate (give the formula) exact number (mention the source) or just a random generation from your imagination. also take into account all the previous outputs from mission, vision, product snapshot, roadmap
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   should push further and give more groundbreaking features.the response demonstrates strong visionary thinking, but it could be pushed further to achieve true game-changing potential.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      we need to add market analysis and trend datset to this section in order to get an improved version
# 13                                                                                                                                                                                                                                                                                                                                                                                                                       The analysis could benefit from demonstrating the connection between user needs/pain points identified earlier in the document, and how addressing these can strategically mitigate specific competitive forces. For example, investing in lossless/hifi audio is in line with the preferences of some of the premium users and could help attract customers from Tidal or Deezer.
# 14                                                                                                                                                                                                                                                                                                                                                                                                 However, the evaluation could be improved by explicitly referencing a specific, hypothetical mission, roadmap, or user research (e.g. 'our mission is to improve user engagement', 'this aligns with the Q3 roadmap to improve on-boarding'). Right now it gestures vaguely at the "company goals" or "overall goals and product roadmap". It's *implied*, but not *grounded* in those earlier contexts.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# ...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 13  Okay, let's analyze Spotify and identify key opportunities for improvement and growth. I'll focus on user personas, pain points, UX friction, market position, competitive landscape, and a Porter's Five Forces analysis to inform strategic recommendations. I'll pay close attention to industry trends and competitor actions to provide actionable insights for Spotify's product strategy. I will also focus on justifying the ICE scores I give at the end.\n\n### 1. 🎯 Target User Personas\n\nLet’s think through this...\n\nSpotify's user base is diverse, spanning age groups, geographic locations, and musical tastes. Understanding these different user personas is crucial for tailoring the experience and driving engagement. We can broadly categorize users into Free and Premium tiers, with further segmentation within each tier.\n\n*   **Free Users:** This group represents a significant portion of Spotify's user base, often younger and more price-sensitive.\n    *   *Generation Z (13-25):* Discovers new music through social media, prioritizes cost-effectiveness, and values personalized playlists. Located globally, with high penetration in emerging markets. Psychographically, they are adventurous, trend-conscious, and digitally native.\n    *   *Millennial Casual Listeners (26-40):* Listens to music during commutes, workouts, or social gatherings. Less concerned with audio quality, but values convenience and breadth of content. Geographically diverse, with a mix of urban and suburban residents. Psychographically, they are practical, value-driven, and convenience-oriented.\n*   **Premium Users:** This group is willing to pay for an ad-free experience, offline listening, and higher audio quality.\n    *   *Gen X Audiophiles (41-55):* Values high-fidelity audio and curated playlists. Often uses Spotify on multiple devices, including home audio systems. Primarily located in developed countries. Psychographically, they are discerning, quality-focused, and tech-savvy.\n    *   *Millennial Music Enthusiasts (26-40):* Actively seeks out new music, follows artists, and creates personalized playlists. Uses Spotify daily and across various devices. Globally present, with a strong presence in urban centers. Psychographically, they are passionate, engaged, and culturally aware.\n    *   *Creator-Facing: Artists & Podcasters:* Use Spotify for Artists/Spotify for Podcasters to manage their presence, track performance, and connect with fans. Geographically diverse, from bedroom artists to established professionals. Psychographically, they are driven, creative, and entrepreneurial.\n\n**Summary Insight:** Spotify needs to balance the needs of its diverse user base, offering a compelling free tier while providing enough value to convert users to Premium. Targeting specific generational and psychographic segments with tailored content and features will be key to growth. The creator-facing personas are crucial to maintain and attract more content to the platform, indirectly attracting their audiences.\n\n### 2. 🧩 Key User Pain Points\n\nLet’s think through this...\n\nUser pain points can significantly impact engagement and conversion rates. Identifying and addressing these issues is crucial for improving user satisfaction and driving growth. Analysis of app store reviews, social media feedback, and user surveys reveals several key pain points:\n\n*   **Free Tier Limitations:** Frequent ads, limited offline downloads, and shuffle-only playback on mobile devices are major frustrations for free users. This directly impacts their willingness to convert to Premium.\n*   **Discovery Challenges:** While Spotify's algorithm is generally effective, users sometimes struggle to find new music outside their usual genres or artists. The sheer volume of content can be overwhelming.\n*   **Podcast Experience:** Podcast discovery and organization can be improved. Users often struggle to find relevant podcasts and manage their subscriptions effectively.\n*   **Audio Quality: ...
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...

# %%
# Load your evaluation log
EVAL_FILE = "all_experiment_view.csv"
all_experiment_view = pd.read_csv(EVAL_FILE)

# Fix 'Run' and any other numeric columns
all_experiment_view["Run"] = pd.to_numeric(all_experiment_view["Run"], errors="coerce").fillna(1).astype(int)

# Optional: Also fix scores to be clean floats (or blank if missing)
all_experiment_view["LLM Score"] = pd.to_numeric(all_experiment_view["LLM Score"], errors="coerce")
all_experiment_view["Human Score"] = pd.to_numeric(all_experiment_view["Human Score"], errors="coerce")

# Save it back clean
all_experiment_view.to_csv(EVAL_FILE, index=False)
print("✅ Repaired Run and score columns.")
# Out:
# ✅ Repaired Run and score columns.

# %%
# Filter for SMART OKRs
okr_data = all_experiment_view[all_experiment_view["Section"] == "SMART OKRs"].copy()
okr_data["LLM Score"] = pd.to_numeric(okr_data["LLM Score"], errors="coerce")
okr_data["Human Score"] = pd.to_numeric(okr_data["Human Score"], errors="coerce")
okr_data["Run"] = pd.to_numeric(okr_data["Run"], errors="coerce")
okr_data = okr_data.sort_values(by="Run")

# === 📊 TABLE: Score + Prompt Summary ===
# Define all three prompt tags to include improved zero-shot as well
zero_shot_tag = "zero-shot-v1-baseline-1"
improved_zero_shot_tag = "improved-zero-shot-v1-baseline-1"
few_shot_tag = "Few_Shot_OKR_improvement"
section = "SMART OKRs"
company_name = all_experiment_view["Company"].dropna().iloc[-1]

# Filter for each entry
zero_shot = all_experiment_view[
    (all_experiment_view["Prompt Tag"] == zero_shot_tag) &
    (all_experiment_view["Company"] == company_name) &
    (all_experiment_view["Section"] == section)
]

improved_zero_shot = all_experiment_view[
    (all_experiment_view["Prompt Tag"] == improved_zero_shot_tag) &
    (all_experiment_view["Company"] == company_name) &
    (all_experiment_view["Section"] == section)
]

few_shot = all_experiment_view[
    (all_experiment_view["Prompt Tag"] == few_shot_tag) &
    (all_experiment_view["Company"] == company_name) &
    (all_experiment_view["Section"] == section)
]

# Merge into single comparison DataFrame
comparison = zero_shot.merge(improved_zero_shot, on="Section", suffixes=("_ZeroShot", "_ImprovedZeroShot"))
comparison = comparison.merge(few_shot, on="Section")

# Rename final merged columns
comparison.rename(columns={
    "LLM Score": "LLM Score_FewShot",
    "Human Score": "Human Score_FewShot"
}, inplace=True)

# Display the extended markdown table
table_md = "### 🔍 OKR Comparison Table: Zero-Shot vs Improved Zero-Shot vs Few-Shot\n\n"
table_md += "| Section | 🤖 Zero-Shot | 👤 Zero-Shot | 🤖 Improved Zero-Shot | 👤 Improved Zero-Shot | 🤖 Few-Shot | 👤 Few-Shot |\n"
table_md += "|---------|---------------|----------------|-------------------------|--------------------------|-------------|---------------|\n"

for _, row in comparison.iterrows():
    table_md += f"| {row['Section']} | {row['LLM Score_ZeroShot']} | {row['Human Score_ZeroShot']} | {row['LLM Score_ImprovedZeroShot']} | {row['Human Score_ImprovedZeroShot']} | {row['LLM Score_FewShot']} | {row['Human Score_FewShot']} |\n"

display(Markdown(table_md))
# === 📈 BAR CHART: Pastel Colors ===
plt.figure(figsize=(12, 6))
bar_width = 0.35
index = range(len(okr_data))

plt.bar(index, okr_data["LLM Score"], bar_width, label="LLM Score", color='#AEC6CF')  # pastel blue
plt.bar([i + bar_width for i in index], okr_data["Human Score"], bar_width, label="Human Score", color='#FFD1DC')  # pastel pink

plt.xlabel("Prompt Strategy")
plt.ylabel("Score (1–5)")
plt.title("SMART OKRs – LLM vs Human Scores (Pastel)")
plt.xticks([i + bar_width / 2 for i in index], okr_data["Prompt Tag"], rotation=45, ha="right")
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# ### 🔍 OKR Comparison Table: Zero-Shot vs Improved Zero-Shot vs Few-Shot
#
# | Section | 🤖 Zero-Shot | 👤 Zero-Shot | 🤖 Improved Zero-Shot | 👤 Improved Zero-Shot | 🤖 Few-Shot | 👤 Few-Shot |
# |---------|---------------|----------------|-------------------------|--------------------------|-------------|---------------|
# | SMART OKRs | 5.0 | 3.0 | 4.0 | 4.0 | 4.0 | 4.5 |

# %%
all_experiment_view
# Out:
#     Run  Company         Strategy                        Prompt Tag  \
# 0     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 1     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 2     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 3     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 4     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 5     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 6     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 7     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 8     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 9     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 10    1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 11    1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 12    1  Spotify         Few_Shot          Few_Shot_OKR_improvement
# 13    1  Spotify              CoT           cot-Product-Snapshot-v1
# 14    1  Spotify  Tree-of-Thought               tree-thought-ice-v1
#
#                                    Section                  Metric  LLM Score  \
# 0                         Mission & Vision  Mission/Vision Insight        5.0
# 1                         Product Snapshot         Strategic Depth        3.0
# 2                        Strategic Roadmap       Roadmap Relevance        5.0
# 3     Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 4                               SMART OKRs             OKR Quality        5.0
# 5   Next-Level Innovation & Product Vision      Visionary Thinking        4.0
# 6                         Mission & Vision  Mission/Vision Insight        5.0
# 7                         Product Snapshot         Strategic Depth        4.0
# 8                        Strategic Roadmap       Roadmap Relevance        5.0
# 9     Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 10                              SMART OKRs             OKR Quality        4.0
# 11  Next-Level Innovation & Product Vision      Visionary Thinking        4.0
# 12                              SMART OKRs             OKR Quality        4.0
# 13                        Product Snapshot         Strategic Depth        4.0
# 14    Feature Prioritization (ICE Scoring)  Prioritization Clarity        4.0
#
#     Human Score  \
# 0           4.0
# 1           4.0
# 2           5.0
# 3           4.0
# 4           3.0
# 5           3.0
# 6           5.0
# 7           4.0
# 8           5.0
# 9           4.0
# 10          4.0
# 11          4.0
# 12          4.5
# 13          4.0
# 14          4.5
#
#                                                                                                                                                                                                                               Feedback  \
# 0                                                                                                                                                                                                       It is well-crafted and concise
# 1                                                                                                                                                                                                 A good start, but could go deeper...
# 2                                                                                                                                                                                                      Very creative and grouped well.
# 3                                                                                                                                                                                             Logical reasoning, but room for clarity.
# 4                                                                                                                                                                                                     Unclear how numbers are derived.
# 5                                                                                                                                                                                             Ideas are decent but not out-of-the-box.
# 6                                                                                                                                                                                                            great vision and mission.
# 7                                                                                     it can be more precise and in depth, it should list all of the current features, and relate all of them together with more depth and integration
# 8                                                                                                                                                                             comprehensive roadmap adjusted as injected in the prompt
# 9                                                                                                                   i need to see why it chose those scores. also this prioritization should be aligned with all the previous insights
# 10                                          where did those numbers come from. what is the source, is it a guesstimate or hallucination or real number from an authentic source. Also OKR should take into account the previous inputs
# 11                                                                                              although the ideas are impressive but they are not out of the box. it can be improved by pushing further out of the known comfort zone
# 12  the structure improved with the reason behind the numbers explained but the model needs to be exposed to mroe data on market trend and analysis to be able to set a solid logic behind the numbers and give more realistic numbers
# 13                               it becomes so much better than before, but still needs more depth. by embedding strategic documents and reference sites it would be way more better. I think the prompting reaches its maximum output
# 14                                  It improves tremendously from the last instance. It is well argumented. However still we should input data and give it memory, embeddings and logic to be able to connect the dots based on data.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Lesson  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Could be more visionary.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Use Porter's 5 forces.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Add prioritization matrix.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Explain ICE criteria.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Include baseline KPIs.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Target underserved segments.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      the vision improved significantly from the first run
# 7   it should itnegrate all of the sections together to give a product snappshot. also**Quantifying the impact of each force:** Instead of just stating "Moderate" or "High," providing data or estimates to support the assessment would add more depth. For example, for Bargaining Power of Suppliers, including information about the percentage of revenue paid out as royalties. *   **Prioritization:** The recommendations are all valid, but it would be helpful to see a prioritization of which strategies are most critical or have the highest potential impact. *   **Consideration of emerging trends:** Discussing how emerging trends like Web3 or AI might impact Spotify's strategy could also increase the depth. it should be like a story considering various aspects of the proudct.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                             the source of that numbers should be clear. ideally it should be calculated based on guestimate or directly extracted from a source mention the source so we make sure it is not hallucination. with more context it can be justified. also all of them should be aligned with the roadmap and feature and snapshot and vison
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              take into account the previous sections as well as the financial aspect of the feature, what is the potential gain from each
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Give the exact source of the numbers whether guestimate (give the formula) exact number (mention the source) or just a random generation from your imagination. also take into account all the previous outputs from mission, vision, product snapshot, roadmap
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   should push further and give more groundbreaking features.the response demonstrates strong visionary thinking, but it could be pushed further to achieve true game-changing potential.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      we need to add market analysis and trend datset to this section in order to get an improved version
# 13                                                                                                                                                                                                                                                                                                                                                                                                                       The analysis could benefit from demonstrating the connection between user needs/pain points identified earlier in the document, and how addressing these can strategically mitigate specific competitive forces. For example, investing in lossless/hifi audio is in line with the preferences of some of the premium users and could help attract customers from Tidal or Deezer.
# 14                                                                                                                                                                                                                                                                                                                                                                                                 However, the evaluation could be improved by explicitly referencing a specific, hypothetical mission, roadmap, or user research (e.g. 'our mission is to improve user engagement', 'this aligns with the Q3 roadmap to improve on-boarding'). Right now it gestures vaguely at the "company goals" or "overall goals and product roadmap". It's *implied*, but not *grounded* in those earlier contexts.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# ...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 13  Okay, let's analyze Spotify and identify key opportunities for improvement and growth. I'll focus on user personas, pain points, UX friction, market position, competitive landscape, and a Porter's Five Forces analysis to inform strategic recommendations. I'll pay close attention to industry trends and competitor actions to provide actionable insights for Spotify's product strategy. I will also focus on justifying the ICE scores I give at the end.\n\n### 1. 🎯 Target User Personas\n\nLet’s think through this...\n\nSpotify's user base is diverse, spanning age groups, geographic locations, and musical tastes. Understanding these different user personas is crucial for tailoring the experience and driving engagement. We can broadly categorize users into Free and Premium tiers, with further segmentation within each tier.\n\n*   **Free Users:** This group represents a significant portion of Spotify's user base, often younger and more price-sensitive.\n    *   *Generation Z (13-25):* Discovers new music through social media, prioritizes cost-effectiveness, and values personalized playlists. Located globally, with high penetration in emerging markets. Psychographically, they are adventurous, trend-conscious, and digitally native.\n    *   *Millennial Casual Listeners (26-40):* Listens to music during commutes, workouts, or social gatherings. Less concerned with audio quality, but values convenience and breadth of content. Geographically diverse, with a mix of urban and suburban residents. Psychographically, they are practical, value-driven, and convenience-oriented.\n*   **Premium Users:** This group is willing to pay for an ad-free experience, offline listening, and higher audio quality.\n    *   *Gen X Audiophiles (41-55):* Values high-fidelity audio and curated playlists. Often uses Spotify on multiple devices, including home audio systems. Primarily located in developed countries. Psychographically, they are discerning, quality-focused, and tech-savvy.\n    *   *Millennial Music Enthusiasts (26-40):* Actively seeks out new music, follows artists, and creates personalized playlists. Uses Spotify daily and across various devices. Globally present, with a strong presence in urban centers. Psychographically, they are passionate, engaged, and culturally aware.\n    *   *Creator-Facing: Artists & Podcasters:* Use Spotify for Artists/Spotify for Podcasters to manage their presence, track performance, and connect with fans. Geographically diverse, from bedroom artists to established professionals. Psychographically, they are driven, creative, and entrepreneurial.\n\n**Summary Insight:** Spotify needs to balance the needs of its diverse user base, offering a compelling free tier while providing enough value to convert users to Premium. Targeting specific generational and psychographic segments with tailored content and features will be key to growth. The creator-facing personas are crucial to maintain and attract more content to the platform, indirectly attracting their audiences.\n\n### 2. 🧩 Key User Pain Points\n\nLet’s think through this...\n\nUser pain points can significantly impact engagement and conversion rates. Identifying and addressing these issues is crucial for improving user satisfaction and driving growth. Analysis of app store reviews, social media feedback, and user surveys reveals several key pain points:\n\n*   **Free Tier Limitations:** Frequent ads, limited offline downloads, and shuffle-only playback on mobile devices are major frustrations for free users. This directly impacts their willingness to convert to Premium.\n*   **Discovery Challenges:** While Spotify's algorithm is generally effective, users sometimes struggle to find new music outside their usual genres or artists. The sheer volume of content can be overwhelming.\n*   **Podcast Experience:** Podcast discovery and organization can be improved. Users often struggle to find relevant podcasts and manage their subscriptions effectively.\n*   **Audio Quality: ...
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...

# %%
# Save the DataFrame
all_experiment_view.to_csv(EVAL_FILE, index=False)

# OPTIONAL: Show confirmation
print(f"✅ File saved as {EVAL_FILE}. You can now download it from the 'Notebook Output' section.")
# Out:
# ✅ File saved as all_experiment_view.csv. You can now download it from the 'Notebook Output' section.

# %% [markdown]
# ## 🚀 Nextify Interactive Dashboard
#
# You can explore the full prompt evaluation, LLM comparison, and multi-agent prototype here:
#
# 🔗 [[Open the Live Nextify Dashboard](http://nextify-dashboard-100.streamlit.app/))
#
# > 💡 This dashboard is fully interactive and displays all runs, scores, feedback, and upcoming agents for Nextify.
#
#
# As we can see from the table,how each prompting technique improved the result of the llm. With just adding two good examples and two bad examples the result was improved by half a score. However, there is a limit in prompting tecniques and they can improve the reult to a limit.
#
# ➡️ Takeaway: When I want the model to stay in a structured lane, I’ll definitely consider guiding it with examples first.For strategic OKR generation more dataset needed on market trenad, competitor analysis and company current situation. so to improve the performance embedding docuements will be the next step.
#
# Now that I’ve improved structured outputs with Few-Shot, it’s time to help the model reason step-by-step, especially in areas like Feature Prioritization using ICE.I am going to apply Chain Of Thoughts to the feature prioritization section as it needs more structured thinking and reasoning. Here, instead of jumping straight to scores, I am going to ask the model to walk through each part: Impact, Confidence, and Effort — and only then calculate the final ICE score.

# %% [markdown]
# ## 🧵 **Chain-of-Thought (CoT)** – Ask my model to reason step-by-step

# %%
# COT Prompting
def build_product_snapshot_prompt(company_name="Spotify") -> str:
    return  f"""
You are Nextify — a GenAI-powered product strategy assistant for product managers.

The product to analyze is: **Spotify**

---
### Chain-of-Thought Thinking Guide

Before continuing, review this feedback from the last evaluation and apply improvements:

Please take into account a thorough insight of the product including users, features, audience, competitive edge, as well as Porter's Five Forces and competitor analysis. Your analysis should identify the forces and offer concrete strategic recommendations for Spotify to leverage these insights. For example, for Spotify this might include the high bargaining power of record labels and strategies to mitigate it — such as developing original content, fostering direct artist relationships, or exploring alternative licensing models.

Delve into the nuances of Spotify's specific situation or recent industry trends. More in-depth research and tailored arguments will increase the evaluation score. Do not treat each force in isolation; instead, explore how they interact and influence each other within Spotify's competitive landscape.

For each section:
1. Start with: “Let’s think through this...”
2. Walk through user context, strategic implications, and comparison to competitors.
3. End with a summary insight that links to the upcoming feature prioritization.
Recommendation: Strengthen the connection between prioritized features and the specific user pain points they address. Ensure ICE scores are well-justified using clear reasoning backed by product context, user data, or competitive benchmarks—avoid arbitrary scoring.

---

Please use the following structure for your analysis:

### 1. 🎯 Target User Personas
- Who uses Spotify, and what are their primary use cases?
- Differentiate Free vs Premium users
- Include generational, geographic, and psychographic traits
- Consider creator-facing personas (if applicable)

### 2. 🧩 Key User Pain Points
- Based on UX reviews, complaints, and feedback trends, what blocks engagement or conversion?
- Include platform-specific issues (mobile, smart devices)
- Integrate user feedback, app reviews, or survey data
- Reference public NPS or satisfaction trends if available

### 3. 🔄 UX Bottlenecks or Friction Areas
- Where are the drop-offs or decision fatigue?
- How intuitive is onboarding, discovery, sharing, and playlisting?
- Include UX comparisons vs Apple Music / YouTube Music / Amazon Music

### 4. 🌍 Current Market Position
- Where does Spotify sit in the market: leader, disruptor, niche?
- How is it perceived by users vs competitors?
- What metrics or reviews support this?

### 5. 🧠 Competitive Threats & Opportunities
- Map out competitive pressures: bundling (Amazon), ecosystems (Apple), social+UGC (YouTube), niche (Deezer)
- Where can Spotify win?
- Mention AI personalization, creator monetization, or bundling strategies

### 6. 🔍 Porter's Five Forces Summary
Please structure this section as a table with the following columns:
| Force | Analysis | Strategic Recommendation |
|-------|----------|--------------------------|
| Threat of New Entrants | ... | ... |
| Bargaining Power of Suppliers | ... | ... |
| Bargaining Power of Buyers | ... | ... |
| Threat of Substitutes | ... | ... |
| Industry Rivalry | ... | ... |

---

✅ Return exactly 6 sections with headings
✅ Use markdown formatting for clarity and tables where applicable
✅ Think aloud before scoring. Be strategic and data-informed.
""".strip()

# %%
cot_product_snapshot_prompt =build_product_snapshot_prompt()

# %%
cot_product_snapshot_output = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=cot_product_snapshot_prompt
).text

Markdown(cot_product_snapshot_output)
# Out:
# Okay, let's get started. I will analyze Spotify using the provided structure, incorporating more in-depth research, tailored arguments, and a stronger connection between feature prioritization and user pain points.
#
# ### 1. 🎯 Target User Personas
#
# Let's think through this... Spotify has a very broad user base, so we need to segment by usage patterns, demographics, and whether they are free or premium subscribers.
#
# *   **The Commuter (Premium):** 25-45 years old, urban/suburban, professional. Listens during commutes (car, public transport), workouts, and while working. Values ad-free listening, offline downloads, and high-quality audio. Geographically diverse, concentrated in developed countries with good infrastructure. Psychographically, they value convenience and efficiency, willing to pay for a seamless experience.
#
# *   **The Student/Young Adult (Free/Premium):** 18-24 years old, students or early career. Uses Spotify for music discovery, sharing playlists with friends, and background music for studying or socializing. Price-sensitive but may upgrade for ad-free listening and mobile control. Globally present, with high adoption rates in both developed and developing countries. Psychographically, they are social, trend-conscious, and digitally native.
#
# *   **The Casual Listener (Free):** 35-65 years old, diverse backgrounds. Listens occasionally, often through smart speakers or connected devices at home. Tolerates ads and doesn't require offline downloads. Geographically dispersed, with varying levels of tech savviness. Psychographically, they are less invested in music trends and prefer familiar artists and genres.
#
# *   **The Music Enthusiast (Premium):** 20-50 years old, passionate about music. Actively seeks out new artists and genres, curates playlists, and follows music blogs/social media. Demands high-quality audio and exclusive content. Geographically diverse, often found in urban centers with vibrant music scenes. Psychographically, they are curious, open-minded, and value artistic expression.
#
# *   **The Creator (Artist/Podcaster):** All ages. Uses Spotify to distribute their music or podcasts, connect with fans, and track performance. Relies on Spotify for Artists/Spotify for Podcasters tools. Global audience. Psychographically, they are entrepreneurial, creative, and data-driven.
#
# **Strategic Implications:** Understanding these personas allows Spotify to tailor its marketing, content recommendations, and feature development. For example, the Commuter might be targeted with promotions for premium subscriptions highlighting offline listening, while the Student might be offered discounted bundles with other services.
#
# **Comparison to Competitors:** Competitors like Apple Music and YouTube Music also target similar personas. Apple Music benefits from its integration with the Apple ecosystem, appealing to users already invested in Apple products. YouTube Music leverages its vast library of user-generated content and video integration, attracting a different segment of music lovers. Amazon Music is increasingly appealing to those within the Amazon ecosystem.
#
# **Summary Insight:** Spotify's diverse user base requires a multi-faceted approach to product development. Focusing on pain points specific to each persona will be crucial for retaining existing users and attracting new ones. This understanding will inform our feature prioritization by addressing diverse user needs.
#
# ### 2. 🧩 Key User Pain Points
#
# Let's think through this... A thorough review of app store reviews, social media, and online forums reveals recurring pain points for Spotify users.
#
# *   **Ad Interruptions (Free Users):** Frequent and intrusive ads are a major source of frustration for free users, leading to app abandonment.
# *   **Limited Offline Downloads (Free Users):** The inability to download music for offline listening on mobile devices severely restricts the utility of the free tier.
# *   **Algorithm Inaccuracy:** Users complain about the music recommendation algorithm not accurately reflecting their tastes, leading to irrelevant suggestions.
# *   **Podcast Discoverability:** Difficulty in finding and discovering new podcasts within the platform.
# *   **Lack of HiFi Audio:** The absence of a lossless audio option puts Spotify at a disadvantage compared to competitors like Apple Music and Tidal.
# *   **Artist Compensation Concerns:** Ongoing controversy surrounding Spotify's royalty rates and artist compensation models.
# *   **Social Features Limited:** The social features are not as integrated as other music platforms, making it hard to discover what friends are listening to.
#
# **Strategic Implications:** Addressing these pain points is critical for improving user satisfaction, reducing churn, and attracting new subscribers. Ignoring these pain points will drive users to competitors who offer a better experience.
#
# **User Feedback & Data:** Numerous app store reviews mention the annoyance of ads. Data on user listening habits could reveal patterns of abandonment during ad breaks. A/B testing different ad formats and frequencies could help optimize the ad experience without alienating free users. NPS scores, if available, can provide an overall measure of user satisfaction and highlight areas for improvement.
#
# **Comparison to Competitors:** Apple Music offers ad-free listening and lossless audio as standard features, directly addressing two of Spotify's key pain points. YouTube Music leverages its recommendation algorithm and content library, giving Spotify a run for its money.
#
# **Summary Insight:** Addressing ad interruptions, improving algorithm accuracy, and launching HiFi audio are key areas for improvement. Understanding these pain points will directly inform the features we prioritize and their impact on user satisfaction.
#
# ### 3. 🔄 UX Bottlenecks or Friction Areas
#
# Let's think through this... Identifying UX bottlenecks and friction areas is crucial for optimizing the user journey and improving engagement.
#
# *   **Onboarding:** The initial onboarding process can be overwhelming for new users, with too many options and unclear instructions.
# *   **Music Discovery:** While Spotify offers various discovery features, the interface can be cluttered, making it difficult to find relevant content quickly.
# *   **Playlist Creation:** Creating and managing playlists can be cumbersome, especially on mobile devices. Drag-and-drop functionality is missing in some areas.
# *   **Sharing:** Sharing music with friends on other platforms can be clunky, requiring multiple steps.
# *   **Podcast Navigation:** Navigating the podcast section can be confusing, with a lack of clear organization and categorization.
# *   **Offline Download Management:** Managing offline downloads can be difficult, especially when storage space is limited. It's not always clear which songs/playlists are downloaded.
# *   **Search Functionality:** Search results can be inconsistent, sometimes failing to return relevant results even when the search term is accurate.
#
# **Strategic Implications:** Streamlining the user interface, improving search accuracy, and simplifying playlist management are essential for enhancing user experience and driving engagement.
#
# **UX Comparisons:** Apple Music boasts a cleaner, more intuitive interface, particularly for users already familiar with the Apple ecosystem. YouTube Music leverages its visual interface.
#
# **Summary Insight:** Addressing these UX bottlenecks will create a smoother, more enjoyable experience for users, leading to increased engagement and retention. This will inform our feature prioritization by focusing on UX improvements and usability enhancements.
#
# ### 4. 🌍 Current Market Position
#
# Let's think through this... Spotify is currently the dominant player in the music streaming market, but its position is increasingly challenged by competitors.
#
# *   **Market Leader:** Spotify holds the largest market share in the music streaming industry, with a significant lead over Apple Music, Amazon Music, and YouTube Music.
# *   **Brand Recognition:** Spotify enjoys strong brand recognition and a reputation for being the go-to platform for music streaming.
# *   **User Perception:** While generally positive, user perception is increasingly influenced by concerns about artist compensation and the absence of HiFi audio.
# *   **Financial Performance:** Spotify's revenue is growing, but profitability remains a challenge due to high content costs and competition.
# *   **Metrics & Reviews:** Reports from companies like Statista and MIDiA Research confirm Spotify's market leadership. User reviews on app stores and social media reflect the mix of satisfaction and frustration mentioned earlier.
#
# **Strategic Implications:** Spotify needs to defend its market share by addressing user pain points, differentiating its offerings, and innovating in new areas.
#
# **Comparison to Competitors:** Apple Music benefits from its integration with the Apple ecosystem, while YouTube Music leverages its video content and UGC. Amazon Music is aggressively bundling its music service with Prime memberships, posing a significant threat to Spotify's subscription base.
#
# **Summary Insight:** Spotify's market leadership is not guaranteed. Proactive measures are needed to maintain its competitive edge and address emerging threats. This understanding will inform our feature prioritization by focusing on strategic initiatives that strengthen Spotify's market position.
#
# ### 5. 🧠 Competitive Threats & Opportunities
#
# Let's think through this... Spotify faces numerous competitive threats, but also possesses opportunities to differentiate itself and capitalize on emerging trends.
#
# *   **Bundling (Amazon):** Amazon's bundling of Music with Prime poses a significant threat, particularly to casual listeners who may not be willing to pay for a standalone music subscription.
# *   **Ecosystems (Apple):** Apple Music benefits from its seamless integration with the Apple ecosystem, attracting users who are already invested in Apple products.
# *   **Social + UGC (YouTube):** YouTube Music leverages its vast library of user-generated content and video integration, appealing to a different segment of music lovers.
# *   **Niche (Deezer, Tidal):** Niche players like Deezer and Tidal cater to specific audiences, such as audiophiles and music enthusiasts, offering features like HiFi audio and exclusive content.
# *   **AI Personalization:** Opportunity to leverage AI to create more personalized music experiences, including tailored playlists, artist recommendations, and interactive content.
# *   **Creator Monetization:** Opportunity to develop new tools and features that empower artists and podcasters to monetize their content directly on the platform.
# *   **Bundling Strategies:** Opportunity to explore new bundling strategies with other services, such as mobile carriers or streaming platforms, to attract new subscribers.
#
# **Strategic Implications:** Spotify needs to develop strategies to counter these threats and capitalize on these opportunities.
#
# **Areas to Win:** Spotify can win by focusing on superior personalization, creator empowerment, and innovative bundling strategies.
#
# **Summary Insight:** By proactively addressing competitive threats and capitalizing on emerging opportunities, Spotify can solidify its market position and drive future growth. This will inform our feature prioritization by focusing on strategic initiatives that differentiate Spotify from its competitors.
#
# ### 6. 🔍 Porter's Five Forces Summary
#
# | Force | Analysis | Strategic Recommendation |
# |-------|----------|--------------------------|
# | **Threat of New Entrants** | High capital expenditure and licensing agreements make entry difficult, but tech giants could still enter. | Focus on innovation and differentiation to build strong brand loyalty and increase switching costs. Explore partnerships with complementary businesses to create barriers to entry. |
# | **Bargaining Power of Suppliers (Record Labels)** | Very high. The music industry is highly concentrated, with a few major labels controlling a large share of the content.  | Develop original content (Spotify Originals podcasts), foster direct artist relationships through Spotify for Artists, explore alternative licensing models (e.g., usage-based pricing, direct licensing with independent artists).  This could also be done by continuing to invest in Spotify for Artists. |
# | **Bargaining Power of Buyers (Consumers)** | High. Consumers have many choices for music streaming, including free options like YouTube. Switching costs are low. | Enhance user experience through personalized recommendations, exclusive content, HiFi audio (to reduce substitutability), and competitive pricing. Focus on user retention strategies to reduce churn. Consider targeted promotions and bundles based on user preferences. |
# | **Threat of Substitutes** | High. Alternatives include radio, owning music, YouTube, and other streaming services. | Differentiate through unique content (e.g., podcasts, live sessions), superior user experience, and strong community features. Invest in exclusive partnerships and content deals to make Spotify a must-have service for music lovers. |
# | **Industry Rivalry** | Very High. Intense competition between Spotify, Apple Music, Amazon Music, YouTube Music, and others. | Focus on differentiation through superior personalization, exclusive content, innovative features (e.g., AI-powered music discovery, interactive experiences), and targeted marketing. Emphasize Spotify's strengths in data-driven insights and personalized recommendations. |

# %%
# === Define Metadata & Log the Results ===
prompt_strategy = "Tree-of-Thought"
prompt_tag = "tree-thought-ice-v1"
section = "Feature Prioritization (ICE Scoring)"
metric = "Prioritization Clarity"
company_name = "Spotify"

# %%
print(all_experiment_view.columns.tolist())
# Out:
# ['Run', 'Company', 'Strategy', 'Prompt Tag', 'Section', 'Metric', 'LLM Score', 'Human Score', 'Feedback', 'Lesson', 'LLM Output Section']

# %%
all_experiment_view
# Out:
#     Run  Company         Strategy                        Prompt Tag  \
# 0     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 1     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 2     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 3     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 4     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 5     1  Spotify        Zero-Shot           zero-shot-v1-baseline-1
# 6     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 7     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 8     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 9     1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 10    1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 11    1  Spotify        Zero-Shot  improved-zero-shot-v1-baseline-1
# 12    1  Spotify         Few_Shot          Few_Shot_OKR_improvement
# 13    1  Spotify              CoT           cot-Product-Snapshot-v1
# 14    1  Spotify  Tree-of-Thought               tree-thought-ice-v1
#
#                                    Section                  Metric  LLM Score  \
# 0                         Mission & Vision  Mission/Vision Insight        5.0
# 1                         Product Snapshot         Strategic Depth        3.0
# 2                        Strategic Roadmap       Roadmap Relevance        5.0
# 3     Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 4                               SMART OKRs             OKR Quality        5.0
# 5   Next-Level Innovation & Product Vision      Visionary Thinking        4.0
# 6                         Mission & Vision  Mission/Vision Insight        5.0
# 7                         Product Snapshot         Strategic Depth        4.0
# 8                        Strategic Roadmap       Roadmap Relevance        5.0
# 9     Feature Prioritization (ICE Scoring)  Prioritization Clarity        5.0
# 10                              SMART OKRs             OKR Quality        4.0
# 11  Next-Level Innovation & Product Vision      Visionary Thinking        4.0
# 12                              SMART OKRs             OKR Quality        4.0
# 13                        Product Snapshot         Strategic Depth        4.0
# 14    Feature Prioritization (ICE Scoring)  Prioritization Clarity        4.0
#
#     Human Score  \
# 0           4.0
# 1           4.0
# 2           5.0
# 3           4.0
# 4           3.0
# 5           3.0
# 6           5.0
# 7           4.0
# 8           5.0
# 9           4.0
# 10          4.0
# 11          4.0
# 12          4.5
# 13          4.0
# 14          4.5
#
#                                                                                                                                                                                                                               Feedback  \
# 0                                                                                                                                                                                                       It is well-crafted and concise
# 1                                                                                                                                                                                                 A good start, but could go deeper...
# 2                                                                                                                                                                                                      Very creative and grouped well.
# 3                                                                                                                                                                                             Logical reasoning, but room for clarity.
# 4                                                                                                                                                                                                     Unclear how numbers are derived.
# 5                                                                                                                                                                                             Ideas are decent but not out-of-the-box.
# 6                                                                                                                                                                                                            great vision and mission.
# 7                                                                                     it can be more precise and in depth, it should list all of the current features, and relate all of them together with more depth and integration
# 8                                                                                                                                                                             comprehensive roadmap adjusted as injected in the prompt
# 9                                                                                                                   i need to see why it chose those scores. also this prioritization should be aligned with all the previous insights
# 10                                          where did those numbers come from. what is the source, is it a guesstimate or hallucination or real number from an authentic source. Also OKR should take into account the previous inputs
# 11                                                                                              although the ideas are impressive but they are not out of the box. it can be improved by pushing further out of the known comfort zone
# 12  the structure improved with the reason behind the numbers explained but the model needs to be exposed to mroe data on market trend and analysis to be able to set a solid logic behind the numbers and give more realistic numbers
# 13                               it becomes so much better than before, but still needs more depth. by embedding strategic documents and reference sites it would be way more better. I think the prompting reaches its maximum output
# 14                                  It improves tremendously from the last instance. It is well argumented. However still we should input data and give it memory, embeddings and logic to be able to connect the dots based on data.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Lesson  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Could be more visionary.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Use Porter's 5 forces.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Add prioritization matrix.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Explain ICE criteria.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Include baseline KPIs.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Target underserved segments.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      the vision improved significantly from the first run
# 7   it should itnegrate all of the sections together to give a product snappshot. also**Quantifying the impact of each force:** Instead of just stating "Moderate" or "High," providing data or estimates to support the assessment would add more depth. For example, for Bargaining Power of Suppliers, including information about the percentage of revenue paid out as royalties. *   **Prioritization:** The recommendations are all valid, but it would be helpful to see a prioritization of which strategies are most critical or have the highest potential impact. *   **Consideration of emerging trends:** Discussing how emerging trends like Web3 or AI might impact Spotify's strategy could also increase the depth. it should be like a story considering various aspects of the proudct.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                             the source of that numbers should be clear. ideally it should be calculated based on guestimate or directly extracted from a source mention the source so we make sure it is not hallucination. with more context it can be justified. also all of them should be aligned with the roadmap and feature and snapshot and vison
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              take into account the previous sections as well as the financial aspect of the feature, what is the potential gain from each
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Give the exact source of the numbers whether guestimate (give the formula) exact number (mention the source) or just a random generation from your imagination. also take into account all the previous outputs from mission, vision, product snapshot, roadmap
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   should push further and give more groundbreaking features.the response demonstrates strong visionary thinking, but it could be pushed further to achieve true game-changing potential.
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      we need to add market analysis and trend datset to this section in order to get an improved version
# 13                                                                                                                                                                                                                                                                                                                                                                                                                       The analysis could benefit from demonstrating the connection between user needs/pain points identified earlier in the document, and how addressing these can strategically mitigate specific competitive forces. For example, investing in lossless/hifi audio is in line with the preferences of some of the premium users and could help attract customers from Tidal or Deezer.
# 14                                                                                                                                                                                                                                                                                                                                                                                                 However, the evaluation could be improved by explicitly referencing a specific, hypothetical mission, roadmap, or user research (e.g. 'our mission is to improve user engagement', 'this aligns with the Q3 roadmap to improve on-boarding'). Right now it gestures vaguely at the "company goals" or "overall goals and product roadmap". It's *implied*, but not *grounded* in those earlier contexts.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# ...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 13  Okay, let's analyze Spotify and identify key opportunities for improvement and growth. I'll focus on user personas, pain points, UX friction, market position, competitive landscape, and a Porter's Five Forces analysis to inform strategic recommendations. I'll pay close attention to industry trends and competitor actions to provide actionable insights for Spotify's product strategy. I will also focus on justifying the ICE scores I give at the end.\n\n### 1. 🎯 Target User Personas\n\nLet’s think through this...\n\nSpotify's user base is diverse, spanning age groups, geographic locations, and musical tastes. Understanding these different user personas is crucial for tailoring the experience and driving engagement. We can broadly categorize users into Free and Premium tiers, with further segmentation within each tier.\n\n*   **Free Users:** This group represents a significant portion of Spotify's user base, often younger and more price-sensitive.\n    *   *Generation Z (13-25):* Discovers new music through social media, prioritizes cost-effectiveness, and values personalized playlists. Located globally, with high penetration in emerging markets. Psychographically, they are adventurous, trend-conscious, and digitally native.\n    *   *Millennial Casual Listeners (26-40):* Listens to music during commutes, workouts, or social gatherings. Less concerned with audio quality, but values convenience and breadth of content. Geographically diverse, with a mix of urban and suburban residents. Psychographically, they are practical, value-driven, and convenience-oriented.\n*   **Premium Users:** This group is willing to pay for an ad-free experience, offline listening, and higher audio quality.\n    *   *Gen X Audiophiles (41-55):* Values high-fidelity audio and curated playlists. Often uses Spotify on multiple devices, including home audio systems. Primarily located in developed countries. Psychographically, they are discerning, quality-focused, and tech-savvy.\n    *   *Millennial Music Enthusiasts (26-40):* Actively seeks out new music, follows artists, and creates personalized playlists. Uses Spotify daily and across various devices. Globally present, with a strong presence in urban centers. Psychographically, they are passionate, engaged, and culturally aware.\n    *   *Creator-Facing: Artists & Podcasters:* Use Spotify for Artists/Spotify for Podcasters to manage their presence, track performance, and connect with fans. Geographically diverse, from bedroom artists to established professionals. Psychographically, they are driven, creative, and entrepreneurial.\n\n**Summary Insight:** Spotify needs to balance the needs of its diverse user base, offering a compelling free tier while providing enough value to convert users to Premium. Targeting specific generational and psychographic segments with tailored content and features will be key to growth. The creator-facing personas are crucial to maintain and attract more content to the platform, indirectly attracting their audiences.\n\n### 2. 🧩 Key User Pain Points\n\nLet’s think through this...\n\nUser pain points can significantly impact engagement and conversion rates. Identifying and addressing these issues is crucial for improving user satisfaction and driving growth. Analysis of app store reviews, social media feedback, and user surveys reveals several key pain points:\n\n*   **Free Tier Limitations:** Frequent ads, limited offline downloads, and shuffle-only playback on mobile devices are major frustrations for free users. This directly impacts their willingness to convert to Premium.\n*   **Discovery Challenges:** While Spotify's algorithm is generally effective, users sometimes struggle to find new music outside their usual genres or artists. The sheer volume of content can be overwhelming.\n*   **Podcast Experience:** Podcast discovery and organization can be improved. Users often struggle to find relevant podcasts and manage their subscriptions effectively.\n*   **Audio Quality: ...
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...

# %%
# === Step: Set context for evaluation
strategy = "CoT"
prompt_tag = "cot-Product-Snapshot-v1"
section = "Product Snapshot"
metric = "Strategic Depth"  # Optional but helps organize views

display(strategy)
display(prompt_tag)
display(section)

eval_prompt = f"""
You are an evaluator AI. Analyze the following **Product Snapshot** section for {company_name}.

Evaluate it using these criteria:
- Are user personas and pain points clearly defined and data-informed?
- Are the insights well grounded in competitor and market analysis?
- Are Porter's Five Forces discussed with strategic depth?
- Do the strategic recommendations clearly reflect the dynamics of each force?
- Does the reasoning tie forces to user personas, pain points, or opportunities across the analysis?

Respond in this format:

LLM Score (1–5): [score]
Reason: [brief explanation including both strengths and areas for improvement]

Section to evaluate:
{cot_product_snapshot_output}
"""

llm_eval = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=eval_prompt
).text

display(Markdown("### 🤖 LLM Self-Evaluation"))
print(llm_eval)

match = re.search(r"LLM Score.*?([1-5])", llm_eval)
llm_score = int(match.group(1)) if match else None
match_mask = (
    (all_experiment_view["Strategy"] == strategy) &
    (all_experiment_view["Prompt Tag"] == prompt_tag) &
    (all_experiment_view["Section"] == section)
)

existing_rows = all_experiment_view[match_mask]
skip_log = False

if not existing_rows.empty:
    for _, row in existing_rows.iterrows():
        if (
            pd.notna(row.get("LLM Score")) and str(row["LLM Score"]).strip() != "" and
            pd.notna(row.get("Human Score")) and str(row["Human Score"]).strip() != "" and
            pd.notna(row.get("Feedback")) and str(row["Feedback"]).strip() != "" and
            pd.notna(row.get("Lesson")) and str(row["Lesson"]).strip() != ""
        ):
            skip_log = True
            print("✅ Already logged with full evaluation. Skipping.")
            break

if not skip_log:
    print("📥 Logging new entry with LLM evaluation only.")
    log_single_section_with_scores(
        company=company_name,
        strategy=strategy,
        prompt_tag=prompt_tag,
        section=section,
        llm_output=cot_product_snapshot_output,
        metric=metric,
        llm_score=llm_score,
        human_score="",
        feedback="",
        lesson=""
    )
# Out:
# 'CoT'
# 'cot-Product-Snapshot-v1'
# 'Product Snapshot'
# ### 🤖 LLM Self-Evaluation
# LLM Score (4):
# Reason: The analysis demonstrates a good understanding of Spotify's market position, user personas, and pain points. The strategic recommendations are generally well-aligned with the identified challenges and opportunities. However, the connection between Porter's Five Forces and specific user personas or pain points could be stronger. For instance, explicitly linking the bargaining power of suppliers to the artist compensation pain point would enhance the analysis. More data points would make the document stronger. Also, more creative and original recommendations would be good.
#
# ✅ Already logged with full evaluation. Skipping.

# %%
display(Markdown("### 📄 CoT Product Snapshot Output"))
display(Markdown(cot_product_snapshot_output))
# Out:
# ### 📄 CoT Product Snapshot Output
# Okay, let's get started. I will analyze Spotify using the provided structure, incorporating more in-depth research, tailored arguments, and a stronger connection between feature prioritization and user pain points.
#
# ### 1. 🎯 Target User Personas
#
# Let's think through this... Spotify has a very broad user base, so we need to segment by usage patterns, demographics, and whether they are free or premium subscribers.
#
# *   **The Commuter (Premium):** 25-45 years old, urban/suburban, professional. Listens during commutes (car, public transport), workouts, and while working. Values ad-free listening, offline downloads, and high-quality audio. Geographically diverse, concentrated in developed countries with good infrastructure. Psychographically, they value convenience and efficiency, willing to pay for a seamless experience.
#
# *   **The Student/Young Adult (Free/Premium):** 18-24 years old, students or early career. Uses Spotify for music discovery, sharing playlists with friends, and background music for studying or socializing. Price-sensitive but may upgrade for ad-free listening and mobile control. Globally present, with high adoption rates in both developed and developing countries. Psychographically, they are social, trend-conscious, and digitally native.
#
# *   **The Casual Listener (Free):** 35-65 years old, diverse backgrounds. Listens occasionally, often through smart speakers or connected devices at home. Tolerates ads and doesn't require offline downloads. Geographically dispersed, with varying levels of tech savviness. Psychographically, they are less invested in music trends and prefer familiar artists and genres.
#
# *   **The Music Enthusiast (Premium):** 20-50 years old, passionate about music. Actively seeks out new artists and genres, curates playlists, and follows music blogs/social media. Demands high-quality audio and exclusive content. Geographically diverse, often found in urban centers with vibrant music scenes. Psychographically, they are curious, open-minded, and value artistic expression.
#
# *   **The Creator (Artist/Podcaster):** All ages. Uses Spotify to distribute their music or podcasts, connect with fans, and track performance. Relies on Spotify for Artists/Spotify for Podcasters tools. Global audience. Psychographically, they are entrepreneurial, creative, and data-driven.
#
# **Strategic Implications:** Understanding these personas allows Spotify to tailor its marketing, content recommendations, and feature development. For example, the Commuter might be targeted with promotions for premium subscriptions highlighting offline listening, while the Student might be offered discounted bundles with other services.
#
# **Comparison to Competitors:** Competitors like Apple Music and YouTube Music also target similar personas. Apple Music benefits from its integration with the Apple ecosystem, appealing to users already invested in Apple products. YouTube Music leverages its vast library of user-generated content and video integration, attracting a different segment of music lovers. Amazon Music is increasingly appealing to those within the Amazon ecosystem.
#
# **Summary Insight:** Spotify's diverse user base requires a multi-faceted approach to product development. Focusing on pain points specific to each persona will be crucial for retaining existing users and attracting new ones. This understanding will inform our feature prioritization by addressing diverse user needs.
#
# ### 2. 🧩 Key User Pain Points
#
# Let's think through this... A thorough review of app store reviews, social media, and online forums reveals recurring pain points for Spotify users.
#
# *   **Ad Interruptions (Free Users):** Frequent and intrusive ads are a major source of frustration for free users, leading to app abandonment.
# *   **Limited Offline Downloads (Free Users):** The inability to download music for offline listening on mobile devices severely restricts the utility of the free tier.
# *   **Algorithm Inaccuracy:** Users complain about the music recommendation algorithm not accurately reflecting their tastes, leading to irrelevant suggestions.
# *   **Podcast Discoverability:** Difficulty in finding and discovering new podcasts within the platform.
# *   **Lack of HiFi Audio:** The absence of a lossless audio option puts Spotify at a disadvantage compared to competitors like Apple Music and Tidal.
# *   **Artist Compensation Concerns:** Ongoing controversy surrounding Spotify's royalty rates and artist compensation models.
# *   **Social Features Limited:** The social features are not as integrated as other music platforms, making it hard to discover what friends are listening to.
#
# **Strategic Implications:** Addressing these pain points is critical for improving user satisfaction, reducing churn, and attracting new subscribers. Ignoring these pain points will drive users to competitors who offer a better experience.
#
# **User Feedback & Data:** Numerous app store reviews mention the annoyance of ads. Data on user listening habits could reveal patterns of abandonment during ad breaks. A/B testing different ad formats and frequencies could help optimize the ad experience without alienating free users. NPS scores, if available, can provide an overall measure of user satisfaction and highlight areas for improvement.
#
# **Comparison to Competitors:** Apple Music offers ad-free listening and lossless audio as standard features, directly addressing two of Spotify's key pain points. YouTube Music leverages its recommendation algorithm and content library, giving Spotify a run for its money.
#
# **Summary Insight:** Addressing ad interruptions, improving algorithm accuracy, and launching HiFi audio are key areas for improvement. Understanding these pain points will directly inform the features we prioritize and their impact on user satisfaction.
#
# ### 3. 🔄 UX Bottlenecks or Friction Areas
#
# Let's think through this... Identifying UX bottlenecks and friction areas is crucial for optimizing the user journey and improving engagement.
#
# *   **Onboarding:** The initial onboarding process can be overwhelming for new users, with too many options and unclear instructions.
# *   **Music Discovery:** While Spotify offers various discovery features, the interface can be cluttered, making it difficult to find relevant content quickly.
# *   **Playlist Creation:** Creating and managing playlists can be cumbersome, especially on mobile devices. Drag-and-drop functionality is missing in some areas.
# *   **Sharing:** Sharing music with friends on other platforms can be clunky, requiring multiple steps.
# *   **Podcast Navigation:** Navigating the podcast section can be confusing, with a lack of clear organization and categorization.
# *   **Offline Download Management:** Managing offline downloads can be difficult, especially when storage space is limited. It's not always clear which songs/playlists are downloaded.
# *   **Search Functionality:** Search results can be inconsistent, sometimes failing to return relevant results even when the search term is accurate.
#
# **Strategic Implications:** Streamlining the user interface, improving search accuracy, and simplifying playlist management are essential for enhancing user experience and driving engagement.
#
# **UX Comparisons:** Apple Music boasts a cleaner, more intuitive interface, particularly for users already familiar with the Apple ecosystem. YouTube Music leverages its visual interface.
#
# **Summary Insight:** Addressing these UX bottlenecks will create a smoother, more enjoyable experience for users, leading to increased engagement and retention. This will inform our feature prioritization by focusing on UX improvements and usability enhancements.
#
# ### 4. 🌍 Current Market Position
#
# Let's think through this... Spotify is currently the dominant player in the music streaming market, but its position is increasingly challenged by competitors.
#
# *   **Market Leader:** Spotify holds the largest market share in the music streaming industry, with a significant lead over Apple Music, Amazon Music, and YouTube Music.
# *   **Brand Recognition:** Spotify enjoys strong brand recognition and a reputation for being the go-to platform for music streaming.
# *   **User Perception:** While generally positive, user perception is increasingly influenced by concerns about artist compensation and the absence of HiFi audio.
# *   **Financial Performance:** Spotify's revenue is growing, but profitability remains a challenge due to high content costs and competition.
# *   **Metrics & Reviews:** Reports from companies like Statista and MIDiA Research confirm Spotify's market leadership. User reviews on app stores and social media reflect the mix of satisfaction and frustration mentioned earlier.
#
# **Strategic Implications:** Spotify needs to defend its market share by addressing user pain points, differentiating its offerings, and innovating in new areas.
#
# **Comparison to Competitors:** Apple Music benefits from its integration with the Apple ecosystem, while YouTube Music leverages its video content and UGC. Amazon Music is aggressively bundling its music service with Prime memberships, posing a significant threat to Spotify's subscription base.
#
# **Summary Insight:** Spotify's market leadership is not guaranteed. Proactive measures are needed to maintain its competitive edge and address emerging threats. This understanding will inform our feature prioritization by focusing on strategic initiatives that strengthen Spotify's market position.
#
# ### 5. 🧠 Competitive Threats & Opportunities
#
# Let's think through this... Spotify faces numerous competitive threats, but also possesses opportunities to differentiate itself and capitalize on emerging trends.
#
# *   **Bundling (Amazon):** Amazon's bundling of Music with Prime poses a significant threat, particularly to casual listeners who may not be willing to pay for a standalone music subscription.
# *   **Ecosystems (Apple):** Apple Music benefits from its seamless integration with the Apple ecosystem, attracting users who are already invested in Apple products.
# *   **Social + UGC (YouTube):** YouTube Music leverages its vast library of user-generated content and video integration, appealing to a different segment of music lovers.
# *   **Niche (Deezer, Tidal):** Niche players like Deezer and Tidal cater to specific audiences, such as audiophiles and music enthusiasts, offering features like HiFi audio and exclusive content.
# *   **AI Personalization:** Opportunity to leverage AI to create more personalized music experiences, including tailored playlists, artist recommendations, and interactive content.
# *   **Creator Monetization:** Opportunity to develop new tools and features that empower artists and podcasters to monetize their content directly on the platform.
# *   **Bundling Strategies:** Opportunity to explore new bundling strategies with other services, such as mobile carriers or streaming platforms, to attract new subscribers.
#
# **Strategic Implications:** Spotify needs to develop strategies to counter these threats and capitalize on these opportunities.
#
# **Areas to Win:** Spotify can win by focusing on superior personalization, creator empowerment, and innovative bundling strategies.
#
# **Summary Insight:** By proactively addressing competitive threats and capitalizing on emerging opportunities, Spotify can solidify its market position and drive future growth. This will inform our feature prioritization by focusing on strategic initiatives that differentiate Spotify from its competitors.
#
# ### 6. 🔍 Porter's Five Forces Summary
#
# | Force | Analysis | Strategic Recommendation |
# |-------|----------|--------------------------|
# | **Threat of New Entrants** | High capital expenditure and licensing agreements make entry difficult, but tech giants could still enter. | Focus on innovation and differentiation to build strong brand loyalty and increase switching costs. Explore partnerships with complementary businesses to create barriers to entry. |
# | **Bargaining Power of Suppliers (Record Labels)** | Very high. The music industry is highly concentrated, with a few major labels controlling a large share of the content.  | Develop original content (Spotify Originals podcasts), foster direct artist relationships through Spotify for Artists, explore alternative licensing models (e.g., usage-based pricing, direct licensing with independent artists).  This could also be done by continuing to invest in Spotify for Artists. |
# | **Bargaining Power of Buyers (Consumers)** | High. Consumers have many choices for music streaming, including free options like YouTube. Switching costs are low. | Enhance user experience through personalized recommendations, exclusive content, HiFi audio (to reduce substitutability), and competitive pricing. Focus on user retention strategies to reduce churn. Consider targeted promotions and bundles based on user preferences. |
# | **Threat of Substitutes** | High. Alternatives include radio, owning music, YouTube, and other streaming services. | Differentiate through unique content (e.g., podcasts, live sessions), superior user experience, and strong community features. Invest in exclusive partnerships and content deals to make Spotify a must-have service for music lovers. |
# | **Industry Rivalry** | Very High. Intense competition between Spotify, Apple Music, Amazon Music, YouTube Music, and others. | Focus on differentiation through superior personalization, exclusive content, innovative features (e.g., AI-powered music discovery, interactive experiences), and targeted marketing. Emphasize Spotify's strengths in data-driven insights and personalized recommendations. |

# %%
eval_df = pd.read_csv("all_experiment_view.csv")
eval_df.tail(3)
# Out:
#     Run  Company         Strategy                Prompt Tag  \
# 12    1  Spotify         Few_Shot  Few_Shot_OKR_improvement
# 13    1  Spotify              CoT   cot-Product-Snapshot-v1
# 14    1  Spotify  Tree-of-Thought       tree-thought-ice-v1
#
#                                  Section                  Metric  LLM Score  \
# 12                            SMART OKRs             OKR Quality        4.0
# 13                      Product Snapshot         Strategic Depth        4.0
# 14  Feature Prioritization (ICE Scoring)  Prioritization Clarity        4.0
#
#     Human Score  \
# 12          4.5
# 13          4.0
# 14          4.5
#
#                                                                                                                                                                                                                               Feedback  \
# 12  the structure improved with the reason behind the numbers explained but the model needs to be exposed to mroe data on market trend and analysis to be able to set a solid logic behind the numbers and give more realistic numbers
# 13                               it becomes so much better than before, but still needs more depth. by embedding strategic documents and reference sites it would be way more better. I think the prompting reaches its maximum output
# 14                                  It improves tremendously from the last instance. It is well argumented. However still we should input data and give it memory, embeddings and logic to be able to connect the dots based on data.
#
#                                                                                                                                                                                                                                                                                                                                                                                                       Lesson  \
# 12                                                                                                                                                                                                                                                                                                       we need to add market analysis and trend datset to this section in order to get an improved version
# 13                        The analysis could benefit from demonstrating the connection between user needs/pain points identified earlier in the document, and how addressing these can strategically mitigate specific competitive forces. For example, investing in lossless/hifi audio is in line with the preferences of some of the premium users and could help attract customers from Tidal or Deezer.
# 14  However, the evaluation could be improved by explicitly referencing a specific, hypothetical mission, roadmap, or user research (e.g. 'our mission is to improve user engagement', 'this aligns with the Q3 roadmap to improve on-boarding'). Right now it gestures vaguely at the "company goals" or "overall goals and product roadmap". It's *implied*, but not *grounded* in those earlier contexts.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 13  Okay, let's analyze Spotify and identify key opportunities for improvement and growth. I'll focus on user personas, pain points, UX friction, market position, competitive landscape, and a Porter's Five Forces analysis to inform strategic recommendations. I'll pay close attention to industry trends and competitor actions to provide actionable insights for Spotify's product strategy. I will also focus on justifying the ICE scores I give at the end.\n\n### 1. 🎯 Target User Personas\n\nLet’s think through this...\n\nSpotify's user base is diverse, spanning age groups, geographic locations, and musical tastes. Understanding these different user personas is crucial for tailoring the experience and driving engagement. We can broadly categorize users into Free and Premium tiers, with further segmentation within each tier.\n\n*   **Free Users:** This group represents a significant portion of Spotify's user base, often younger and more price-sensitive.\n    *   *Generation Z (13-25):* Discovers new music through social media, prioritizes cost-effectiveness, and values personalized playlists. Located globally, with high penetration in emerging markets. Psychographically, they are adventurous, trend-conscious, and digitally native.\n    *   *Millennial Casual Listeners (26-40):* Listens to music during commutes, workouts, or social gatherings. Less concerned with audio quality, but values convenience and breadth of content. Geographically diverse, with a mix of urban and suburban residents. Psychographically, they are practical, value-driven, and convenience-oriented.\n*   **Premium Users:** This group is willing to pay for an ad-free experience, offline listening, and higher audio quality.\n    *   *Gen X Audiophiles (41-55):* Values high-fidelity audio and curated playlists. Often uses Spotify on multiple devices, including home audio systems. Primarily located in developed countries. Psychographically, they are discerning, quality-focused, and tech-savvy.\n    *   *Millennial Music Enthusiasts (26-40):* Actively seeks out new music, follows artists, and creates personalized playlists. Uses Spotify daily and across various devices. Globally present, with a strong presence in urban centers. Psychographically, they are passionate, engaged, and culturally aware.\n    *   *Creator-Facing: Artists & Podcasters:* Use Spotify for Artists/Spotify for Podcasters to manage their presence, track performance, and connect with fans. Geographically diverse, from bedroom artists to established professionals. Psychographically, they are driven, creative, and entrepreneurial.\n\n**Summary Insight:** Spotify needs to balance the needs of its diverse user base, offering a compelling free tier while providing enough value to convert users to Premium. Targeting specific generational and psychographic segments with tailored content and features will be key to growth. The creator-facing personas are crucial to maintain and attract more content to the platform, indirectly attracting their audiences.\n\n### 2. 🧩 Key User Pain Points\n\nLet’s think through this...\n\nUser pain points can significantly impact engagement and conversion rates. Identifying and addressing these issues is crucial for improving user satisfaction and driving growth. Analysis of app store reviews, social media feedback, and user surveys reveals several key pain points:\n\n*   **Free Tier Limitations:** Frequent ads, limited offline downloads, and shuffle-only playback on mobile devices are major frustrations for free users. This directly impacts their willingness to convert to Premium.\n*   **Discovery Challenges:** While Spotify's algorithm is generally effective, users sometimes struggle to find new music outside their usual genres or artists. The sheer volume of content can be overwhelming.\n*   **Podcast Experience:** Podcast discovery and organization can be improved. Users often struggle to find relevant podcasts and manage their subscriptions effectively.\n*   **Audio Quality: ...
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...

# %%
df = eval_df[eval_df["Section"] == "Product Snapshot"]

# %%
# Save filtered section
df = eval_df[eval_df["Section"] == "Product Snapshot"]

# Plot bar chart
plt.figure(figsize=(12, 6))
bar_width = 0.35
x_labels = df["Prompt Tag"].astype(str)
index = range(len(x_labels))

plt.bar(index, df["LLM Score"], bar_width, label="LLM Score", color='#AEC6CF')
plt.bar([i + bar_width for i in index], df["Human Score"], bar_width, label="Human Score", color='#FFD1DC')

plt.xlabel("Prompt Tag")
plt.ylabel("Score (1–5)")
plt.title("LLM vs Human Scores — Product Snapshot")
plt.xticks([i + bar_width / 2 for i in index], x_labels, rotation=45, ha="right")
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# 🧠 Key Insights:
#
# The zero-shot baseline prompt underperformed in LLM self-evaluation, scoring 3, compared to a more generous human score of 4 — indicating that while the basic structure was present, the depth of reasoning and strategic linkage may have been insufficient from the model’s perspective.
#
# The improved zero-shot prompt aligned better with expectations, scoring 4 by both LLM and human raters. This suggests enhanced coherence and strategic framing based on lessons from the initial run.
#
# The Chain-of-Thought (CoT) strategy achieved parity with the improved prompt (4/5 from both LLM and human), validating its effectiveness in structuring product insights with deeper causal reasoning. However, it did not yet show a leap in score, indicating room for even sharper differentiation in future iterations (e.g., better feature linkage or more granular market context).
#
# 📌 Conclusion:
# All methods improved upon the baseline, with Chain-of-Thought (CoT) matching the improved zero-shot prompt. While CoT introduces more structured reasoning, further enhancements — such as deeper competitive mapping, integration of NPS data, and clearer linkage between features and user pain points — are needed to reach a perfect score of 5.
#
# This analysis highlights a natural ceiling in prompting strategies: at some point, we’re asking a generalist model to act like a domain specialist in product management. Prompt engineering can only go so far. To truly achieve expert-level output, we must combine smarter model behavior with granular architectural guidance, supported by domain-specific embeddings, real-world grounding, and specialized multi-agent systems trained on expert reasoning patterns.

# %% [markdown]
# ## 🚀 Nextify Interactive Dashboard
#
# You can explore the full prompt evaluation, LLM comparison, and multi-agent prototype here:
#
# 🔗 [[Open the Live Nextify Dashboard](http://nextify-dashboard-100.streamlit.app/))

# %% [markdown]
# ## 🌳 **Tree-of-Thought (ToT)** – Let the model branch, explore, and decide
# In this section, we’ll push our prompting strategy beyond linear reasoning.
#
# Instead of a step-by-step thought chain like in CoT, we’ll invite the model to **branch into multiple paths of reasoning** for each decision — like a tree with many limbs. 🌲
#
# For the task of **Feature Prioritization (ICE Scoring)**, we’ll use ToT prompting to help the model:
# - List candidate features 🌟
# - Branch into Impact, Confidence, and Effort for each one 🧠
# - Score each branch individually using ICE logic 📈
# - Justify decisions using prior context like roadmap and vision 🎯
# - Rank features at the end — not just choose blindly 👑
#
# The goal?
# Simulate how a great PM thinks when facing multiple tradeoffs and unclear inputs.
#
# Let’s grow some thought trees. 🌱

# %%
# === METADATA ===
prompt_strategy = "Tree-of-Thought"
prompt_tag = "tree-thought-ice-v1"
section = "Feature Prioritization (ICE Scoring)"
metric = "Prioritization Clarity"
company_name = "Spotify"

# %%
# === PROMPT ===
model_input = f"""
You are a strategic AI assistant helping prioritize features using ICE scoring for {company_name}.

Start by listing **3 candidate features**.

For each feature, branch your reasoning into 3 paths:
- 🚀 **Impact**: What is the user or business value this will create?
- ⚙️ **Confidence**: How sure are we this feature will succeed?
- 🚰 **Ease**: How difficult is it to build?

In each path, **justify the score numerically (1–10)** and explain your thinking.

Then synthesize the scores into a table using the formula:

> **Total Score = (Impact × Confidence) ÷ Effort**

Please output the result in **markdown table format** inside a code block:

````markdown
| Feature | Impact | Confidence | Ease | Total |
|---------|--------|------------|------|-------|
| ...     | ...    | ...        | ...  | ...   |
````

Finally, rank the features in order and explain **why the top feature is most worth building**, based on context like:
- Company goals
- Roadmap
- Prior user needs

Think like a product leader who’s trying to align effort with impact. Branch before you build. 🌲
"""

# %%
# === RUN LLM ===
llm_output = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=model_input
).text

display(Markdown("### 🌳 Tree-of-Thought Output"))
display(Markdown(llm_output))
# Out:
# ### 🌳 Tree-of-Thought Output
# Okay, I'm ready to analyze potential Spotify features using the ICE scoring method. Here are three candidate features:
#
# 1.  **Collaborative Playlists with Real-time Listening:** Users can see what song their friends are currently listening to in a shared playlist.
# 2.  **AI-Powered Personalized Radio Stations Based on Mood:** Users can select a mood (e.g., "Relaxing," "Energetic," "Focused"), and Spotify generates a radio station tailored to that mood, drawing from their listening history and broader Spotify catalog.
# 3.  **Expanded Offline Download Options (Podcast Chapters/Specific Playlist Sections):** Users can download specific sections of playlists or individual podcast chapters for offline listening.
#
# Now, let's break down each feature using the ICE framework.
#
# **Feature 1: Collaborative Playlists with Real-time Listening**
#
# *   🚀 **Impact**:
#     *   *Justification:* Enhanced social experience, increased engagement, potential for viral sharing of playlists. Creates a feeling of connection, especially for geographically separated friends.
#     *   *Score:* 8. Strong positive impact on user engagement and platform stickiness.
#
# *   ⚙️ **Confidence**:
#     *   *Justification:* Collaborative playlists already exist, so the foundation is there. Real-time listening is technically feasible. User demand for social features is generally high, based on trends in other social media. However, potential privacy concerns need consideration.
#     *   *Score:* 7. Solid confidence based on existing features and general user trends.
#
# *   ⚙️ **Ease**:
#     *   *Justification:* Moderate complexity. Requires real-time data streaming and updates within the playlist interface. Needs robust backend infrastructure to handle concurrent users. Security and privacy implications must be carefully addressed.
#     *   *Score:* 5. Mid-range difficulty due to real-time requirements and potential privacy considerations.
#
# **Feature 2: AI-Powered Personalized Radio Stations Based on Mood**
#
# *   🚀 **Impact**:
#     *   *Justification:* Provides a highly personalized and relevant music discovery experience. Addresses specific user needs based on their mood, making Spotify a more versatile and integrated part of their daily life. Could significantly increase listening time and reduce user churn.
#     *   *Score:* 9. High impact due to personalization and addressing specific user needs.
#
# *   ⚙️ **Confidence**:
#     *   *Justification:* Spotify already has advanced AI capabilities (e.g., Discover Weekly). Adapting this technology to mood-based radio stations is a logical extension. However, accurately identifying songs that match a specific mood can be challenging.
#     *   *Score:* 8. Relatively high confidence given Spotify's existing AI infrastructure.
#
# *   ⚙️ **Ease**:
#     *   *Justification:* Moderate to high complexity. Requires training AI models to accurately identify songs based on mood. Requires integration with existing recommendation algorithms and UI design for mood selection.
#     *   *Score:* 6. Moderate difficulty as core AI technology is present, but refinement and mood-based classification add complexity.
#
# **Feature 3: Expanded Offline Download Options (Podcast Chapters/Specific Playlist Sections)**
#
# *   🚀 **Impact**:
#     *   *Justification:* Improves user convenience, particularly for podcast listeners who may only want to listen to specific segments. Addresses a common user request and improves the overall user experience, especially in situations with limited connectivity. Improves accessibility and utility of Spotify.
#     *   *Score:* 7. Good impact, primarily on user convenience and utility.
#
# *   ⚙️ **Confidence**:
#     *   *Justification:* Technically feasible, building upon existing download functionality. Clear user demand for more granular offline control. Minimal risk of failure as it extends a core feature.
#     *   *Score:* 9. High confidence as it builds on existing functionality and addresses a clear user need.
#
# *   ⚙️ **Ease**:
#     *   *Justification:* Relatively easy to implement. Primarily involves modifying existing download logic to allow for chapter or section selection. UI changes would be relatively straightforward.
#     *   *Score:* 8. Relatively easy to implement compared to the other features.
#
# Now, let's put these scores into a table:
#
# ````markdown
# | Feature | Impact | Confidence | Ease | Total |
# |---------------------------------------------------------|--------|------------|------|-------|
# | Collaborative Playlists with Real-time Listening | 8     | 7         | 5    | 11.2 |
# | AI-Powered Personalized Radio Stations Based on Mood | 9     | 8         | 6    | 12  |
# | Expanded Offline Download Options (Podcast Chapters/Specific Playlist Sections) | 7     | 9         | 8    | 7.875  |
# ````
#
# Based on the ICE scores, the ranking is:
#
# 1.  **AI-Powered Personalized Radio Stations Based on Mood (Total: 12)**
# 2.  **Collaborative Playlists with Real-time Listening (Total: 11.2)**
# 3.  **Expanded Offline Download Options (Podcast Chapters/Specific Playlist Sections) (Total: 7.875)**
#
# **Why the AI-Powered Personalized Radio Stations Feature Is Most Worth Building:**
#
# Given Spotify's likely company goals of increasing user engagement, reducing churn, and differentiating itself through personalization, the AI-Powered Personalized Radio Stations feature emerges as the most strategic choice.
#
# *   **Alignment with Company Goals:** This feature directly addresses these goals by providing a highly personalized music discovery experience. It taps into users' emotional needs, making Spotify more integrated into their daily lives.
# *   **Roadmap Considerations:** Spotify likely has existing AI infrastructure and a roadmap focused on enhancing personalization. This feature leverages those investments and aligns with that trajectory.
# *   **User Needs:** Users are increasingly expecting personalized experiences. Addressing a user's specific mood with tailored music recommendations offers a significant advantage over generic playlists or radio stations. It creates a more sticky and enjoyable user experience.
# *   **Impact vs. Effort:** While the implementation requires moderate effort, the potential impact on user engagement and satisfaction is substantial, making it a high-return investment. While collaborative playlists are appealing and relatively easy to build, the core benefits of AI-powered radio align directly with Spotify's priorities. The offline downloads are a good quality of life enhancement, but aren't in the same league as the other two features.
#
# Therefore, even though the confidence score for expanded offline downloads is high, the AI-Powered Radio Stations have the highest combination of impact, confidence, and reasonable effort, making it the most valuable feature to prioritize for Spotify.

# %% [markdown]
# I am impressed by How much the result improved from the last time. the evaluation have a logical proof behind it. Let's see how it is evaluated.

# %%
# === LLM SELF-EVALUATION ===
eval_prompt = f"""
You are an evaluator AI. Analyze the following ICE Scoring output for {company_name}.

Evaluate it using:
- Does it explain ICE scores?
- Are all 3 branches (Impact, Confidence, Effort) explored?
- Is reasoning grounded in earlier context (mission, roadmap, etc)?
- Are final rankings justified?

Respond like:

LLM Score (1–5): [score]
Reason: [strengths + suggestions]

Section to evaluate:
{llm_output}
"""

llm_eval = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=eval_prompt
).text

display(Markdown("### 🤖 LLM Self-Evaluation"))
print(llm_eval)

# === Extract score ===
match = re.search(r"LLM Score.*?([1-5])", llm_eval)
llm_score = int(match.group(1)) if match else None

# === DEDUPLICATION CHECK ===
match_mask = (
    (all_experiment_view["Strategy"] == prompt_strategy) &
    (all_experiment_view["Prompt Tag"] == prompt_tag) &
    (all_experiment_view["Section"] == section)
)
existing_rows = all_experiment_view[match_mask]

skip_log = False
if not existing_rows.empty:
    for _, row in existing_rows.iterrows():
        if all([
            str(row.get("LLM Score", "")).strip(),
            str(row.get("Human Score", "")).strip(),
            str(row.get("Feedback", "")).strip(),
            str(row.get("Lesson", "")).strip()
        ]):
            skip_log = True
            existing_entry = row
            break

# === HUMAN EVALUATION ===
if skip_log:
    print("✅ Found existing fully-evaluated match — skipping input and reusing values.")
    human_score = existing_entry["Human Score"]
    feedback = existing_entry["Feedback"]
    lesson = existing_entry["Lesson"]
    llm_score = existing_entry["LLM Score"]
else:
    display(Markdown("### 👤 Human Evaluation (Your Turn)"))
    human_score = input("🧠 Your score (1–5): ").strip()
    feedback = input("💬 Your feedback: ")
    lesson = input("📘 Lesson learned: ")
# Out:
# ### 🤖 LLM Self-Evaluation
# LLM Score (4/5)
# Reason:
# * Strengths:
#     * ICE Explained: While it doesn't explicitly define ICE scoring, the breakdown of Impact, Confidence, and Ease effectively communicates the core concepts.
#     * All Branches Explored: Yes, Impact, Confidence, and Effort are all thoroughly examined for each feature.
#     * Justification: The reasoning is generally well-justified, explaining why each feature receives a particular score in each category.
#     * Final Rankings Justified: The final rankings are clearly stated and supported with arguments that refer back to the individual ICE scores. The explanation of why the AI-Powered Radio Stations feature is the top priority is particularly strong.
#
# * Suggestions:
#     * Grounding in Context: The response would be stronger if it explicitly referenced a hypothetical or real Spotify mission statement or strategic roadmap *before* diving into the feature analysis. This would provide a clearer framework for evaluating the "Impact" component. The final justification *does* this, but the initial feature evaluation would benefit from this context.
#     * ICE Score Calculation: The formula being used to calculate total is not presented, and not a standard ICE calculation.
#
# ✅ Found existing fully-evaluated match — skipping input and reusing values.

# %%
# === LOG TO CSV ===
log_single_section_with_scores(
    company=company_name,
    strategy=prompt_strategy,
    prompt_tag=prompt_tag,
    section=section,
    llm_output=llm_output,
    metric=metric,
    llm_score=llm_score,
    human_score=human_score,
    feedback=feedback,
    lesson=lesson
)
# Out:
# 🧮 Run number for Spotify (Tree-of-Thought): 2
# ⚠️ Already logged: Spotify | Feature Prioritization (ICE Scoring) | tree-thought-ice-v1 — skipping.

# %%
# === REFRESH AND SAVE UPDATED CSV ===
all_experiment_view = pd.read_csv("all_experiment_view.csv")
all_experiment_view.to_csv("all_experiment_view.csv", index=False)

# %%
all_experiment_view.tail(1)
# Out:
#     Run  Company         Strategy           Prompt Tag  \
# 14    1  Spotify  Tree-of-Thought  tree-thought-ice-v1
#
#                                  Section                  Metric  LLM Score  \
# 14  Feature Prioritization (ICE Scoring)  Prioritization Clarity        4.0
#
#     Human Score  \
# 14          4.5
#
#                                                                                                                                                                                               Feedback  \
# 14  It improves tremendously from the last instance. It is well argumented. However still we should input data and give it memory, embeddings and logic to be able to connect the dots based on data.
#
#                                                                                                                                                                                                                                                                                                                                                                                                       Lesson  \
# 14  However, the evaluation could be improved by explicitly referencing a specific, hypothetical mission, roadmap, or user research (e.g. 'our mission is to improve user engagement', 'this aligns with the Q3 roadmap to improve on-boarding'). Right now it gestures vaguely at the "company goals" or "overall goals and product roadmap". It's *implied*, but not *grounded* in those earlier contexts.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 14  Okay, I'm ready to analyze these features. Here are three candidate features we could potentially build:\n\n1.  **Personalized Recommendation Engine:** Tailors content recommendations to individual user preferences based on their past behavior.\n2.  **Enhanced Search Filters:** Adds advanced filtering options to our search functionality, allowing users to narrow down results by more specific criteria.\n3.  **Integration with Third-Party Communication Tools:** Connects our platform with popular communication tools like Slack or Microsoft Teams, allowing users to share information and collaborate more easily.\n\nLet's break down each feature using the ICE scoring framework:\n\n**1. Personalized Recommendation Engine**\n\n*   🚀 **Impact**: This feature has the potential to significantly increase user engagement and retention by providing more relevant and valuable content. It could also lead to increased conversion rates and revenue. **Score: 9**. *Justification: Personalized recommendations directly address user needs and improve their overall experience, leading to measurable business outcomes.*\n*   ⚙️ **Confidence**: We have some data on user behavior, but the algorithms required are complex and require tuning. There is a chance personalization efforts might not be on target initially. **Score: 6**. *Justification: While personalization is generally effective, specific implementation challenges and data limitations lower confidence.*\n*   ⚙️ **Ease**: Implementing a robust recommendation engine requires significant development effort, including algorithm design, data integration, and infrastructure scaling. **Score: 3**. *Justification: This is a complex project with potentially high engineering costs and longer development timelines.*\n\n**2. Enhanced Search Filters**\n\n*   🚀 **Impact**: Improved search functionality will empower users to find what they need more quickly and easily, leading to increased satisfaction and potentially higher conversion rates. It addresses a common user pain point reported in feedback. **Score: 7**. *Justification: Addresses a well-documented user need, but the impact is likely less dramatic than a personalized recommendation engine.*\n*   ⚙️ **Confidence**: We have a good understanding of the data we need to filter and the types of filters users would find most useful. Implementing the filters is fairly straightforward. **Score: 8**. *Justification: Based on user feedback and technical feasibility, we're fairly certain this will work as expected.*\n*   ⚙️ **Ease**: Implementing enhanced search filters is relatively straightforward and can be done with existing resources. **Score: 7**. *Justification: The technical complexity is moderate, and we have experience building similar features.*\n\n**3. Integration with Third-Party Communication Tools**\n\n*   🚀 **Impact**: This feature could improve collaboration and communication among users, especially in team settings, leading to increased productivity and engagement. **Score: 6**. *Justification: While valuable, the impact is somewhat limited to users who actively collaborate with others within the platform.*\n*   ⚙️ **Confidence**: We can leverage existing APIs and integrations to connect with popular communication tools. We can prototype and test this easily. **Score: 7**. *Justification: Integrating via well-documented APIs reduces the risk of major technical hurdles.*\n*   ⚙️ **Ease**: Integrating with third-party APIs requires some effort, but the process is well-defined and doesn't involve significant architectural changes. **Score: 5**. *Justification: While relatively straightforward, managing API integrations and handling potential compatibility issues adds some complexity.*\n\nNow, let's calculate the ICE scores and present them in a table:\n\n```markdown\n| Feature                                      | Impact | Confidence | Ease | Total |\n|----------------------------------------------|--------|------------|------|-------|\n| Per ...

# %%
# === VISUALIZATION: BAR CHART FOR FEATURE PRIORITIZATION ===
df = all_experiment_view[all_experiment_view["Section"] == section]

plt.figure(figsize=(12, 6))
bar_width = 0.35
x_labels = df["Prompt Tag"].astype(str)
index = range(len(x_labels))

plt.bar(index, df["LLM Score"], bar_width, label="LLM Score", color='#AEC6CF')
plt.bar([i + bar_width for i in index], df["Human Score"], bar_width, label="Human Score", color='#FFD1DC')

plt.xlabel("Prompt Tag")
plt.ylabel("Score (1–5)")
plt.title("LLM vs Human Scores — Feature Prioritization (ICE Scoring)")
plt.xticks([i + bar_width / 2 for i in index], x_labels, rotation=45, ha="right")
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ✨ Reflection on Feature Prioritization Evaluation Chart
# “It seems the model is becoming self-aware… and might soon need therapy. 🤖🛋️”
#
# What this chart reveals is fascinating. Despite changes in the prompting strategy — from zero-shot to improved zero-shot, and eventually to tree-of-thought — the LLM self-evaluation score stays flat, hovering around 5 (its ceiling). Meanwhile, human evaluation scores evolve more meaningfully, showing an appreciation for ToT reasoning with a noticeable uptick for the tree-thought-ice-v1 prompt.
#
# This raises an important question:
# Is it truly useful to have the same model generate, reason, and evaluate itself?
# The answer, at least partially, is no — because it introduces evaluation bias based on how well the model can reflect on its own outputs, which is limited by the same training and architecture that generated the content in the first place.
#
# 🧠 Prompting as Craft, But With Limits
# This experiment shows that prompting is an art, but one with diminishing returns if used in isolation. To squeeze out better outcomes, we put in more structure, more thought — yet, we hit a kind of ceiling where small tasks start demanding disproportionately large prompting effort.
#
# For me, this is one of the most tangible and practical domains of LLM alignment. That’s why I’m excited to bring these techniques into my multi-agent system, where models don’t have to do everything alone. They think together. Strategize together. Judge each other. And maybe… go to therapy together? 😂

# %% [markdown]
# ## 🚀 Nextify Interactive Dashboard
#
# You can explore the full prompt evaluation, LLM comparison, and multi-agent prototype here:
#
# 🔗 [[Open the Live Nextify Dashboard](http://nextify-dashboard-100.streamlit.app/))

# %% [markdown]
# ## ✨ Reflection on Prompting & Why I Built a Multi-Agent System
#
# > “It seems the model is becoming self-aware… and might soon need therapy. 🤖🛋️”
#
# One of the most surprising discoveries during this GenAI course came from evaluating different prompting strategies for feature prioritization. While I tested Zero-Shot, Improved-Zero-Shot, and Tree-of-Thought (ToT) variants, **LLM self-evaluation scores remained flat — consistently rating itself a perfect '5'**, regardless of actual improvement.
#
# In contrast, **human evaluation showed clear preference shifts**, especially favoring ToT + ICE-style prompts like `tree-thought-ice-v1`.
#
# This revealed a critical insight:
#
# > ❓ Is it really valid to let the same model generate, reason, and then evaluate its own work?
#
# Only to a point. Models tend to **reinforce their own logic**, which introduces feedback bias. They reflect on their outputs within the same paradigm that produced them — which is both clever and limiting.
#
# ### 🧠 Prompting as Craft — With Diminishing Returns
#
# This exercise showed me that **prompting alone hits a ceiling**. Even with more structured, thoughtful instructions, the performance eventually plateaus. Especially in tasks requiring synthesis or judgment, prompting can feel like squeezing juice from a rock.
#
# ---
#
# ## 🧙‍♀️ Why Multi-Agent?
#
# This is where the **magic of multi-agent orchestration** begins.
#
# In my project, I designed a cast of autonomous LLM agents — each with its own role, prompting style, temperature, and self-evaluation rubric. Instead of asking one model to do everything, **they collaborate, critique, and converge** on product strategy decisions.
#
# These agents **think together**.
# They **strategize together**.
# They even **evaluate each other’s work** — like a team of brilliant but weird coworkers in a product war room... or a magical academy.
#
# ---
#
# ## 🧠 Meet Nextive’s Hogwarts of Product Agents
#
# Think of them as the wizarding faculty of product thinking:
#
# | Agent | 🪄 Wizarding Name | 📖 Description | What It Does | Prompt Style | Temp | Toolchain |
# |-------|------------------|----------------|--------------|--------------|------|-----------|
# | 🧱 **Issue Agent** | **The Marauder** | Maps unseen product problems from feedback chaos. | CoT for bug/blocker detection | CoT | `0.3` | Gemini + LangGraph |
# | 💬 **Feedback Agent** | **Howler Whisperer** | Tames angry reviews and extracts core insights. | Few-Shot Prompting | `0.4` | Gemini + Matching Engine |
# | 😊 **Sentiment Agent** | **The Legilimens** | Detects emotional subtext in user responses. | One-Shot Classification | `0.2` | Google NLP |
# | 🔍 **Competitor Agent** | **The Seer** | Forecasts competitors' positioning and changes. | ReAct + Search Grounding | `0.7` | Gemini + Google Search |
# | 💡 **Ideation Agent** | **Room of Requirement** | Generates feature ideas using structured thinking. | Tree-of-Thought | `0.8` | Gemini + RAG + Docs |
# | 🎯 **Prioritization Agent** | **The Sorting Hat** | Scores features and assigns roadmap slots. | CoT + ICE Prompting | `0.5` | Gemini |
# | ✅ **OKR Agent** | **The Headmaster** | Converts validated features into SMART OKRs. | Few-Shot + OKR format | `0.4` | Gemini |
# | 🧭 **Decision Support** | **The Wizengamot** | Synthesizes everyone’s opinions to decide what to build next. | Agent Aggregation | — | Orchestrator |
#
# ---
#
# This is not just a prompt playground — it’s a fully modular **LLM ecosystem**, where agents **critique**, **prioritize**, and even **“veto”** one another's decisions.
#
# It’s not about crafting a single perfect prompt.
# It’s about designing an intelligent conversation between prompts.

# %%
import google.generativeai as genai
from kaggle_secrets import UserSecretsClient

# Secure API Key retrieval
GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
client = genai.GenerativeModel("gemini-2.0-flash")

# %%
# Initialize Gemini

# === Retry Logic for Robust Calls ===
is_retriable = lambda e: (isinstance(e, genai.errors.APIError) and e.code in {429, 503})

# %%
is_retriable
# Out:
# <function __main__.<lambda>(e)>

# %% [markdown]
# ### 🔍 BaseAgent Class: Modular LLM Wrapper
#
# Each `BaseAgent` instance represents a single functional agent (like summarizer, competitor analyzer, ideator).
# - `run()` generates content from the Gemini model using a pre-defined prompt.
# - `evaluate()` performs self-reflection using a meta-prompt to assess quality, structure, or relevance.
# - Temperatures are agent-specific, allowing flexibility between creative vs. stable outputs.
#
# This class abstracts the LLM handling so that the rest of the orchestration can treat each agent as a black box with defined inputs and outputs.

# %%
# === Agent Evolution Format ===
# Each agent now includes:
# 1. Unique personality (wizard archetype)
# 2. Tailored prompting technique (Few-Shot, CoT, ToT, etc.)
# 3. Temperature tuning for creativity vs. consistency
# 4. Self-evaluation for quality control
# 5. User-provided prompt templates with high evaluation results
# === Step 1: Base Agent Class ===
class BaseAgent:
    # Initialize the agent with its name, prompting style, and temperature
    def __init__(self, name: str, prompt_style: str, temperature: float = 0.3):
        self.name = name  # Identifier for the agent (e.g., "feedback", "ideation")
        self.prompt_style = prompt_style  # Prompting method used (Few-Shot, CoT, etc.)
        self.temperature = temperature  # Controls response creativity vs. consistency

    # Run the LLM with the provided prompt and configured temperature
    def run(self, prompt: str) -> str:
        response = client.generate_content(  # Use Gemini client to generate output
            prompt,
            generation_config={"temperature": self.temperature}  # Dynamic temperature control
        )
        return response.text  # Return only the text output (not metadata)

    # Self-evaluate the output by asking Gemini to reflect on it
    def evaluate(self, output: str, criteria: str) -> str:
        # Construct a self-evaluation prompt to assess the output
        eval_prompt = f"""
        === Self-Evaluation: {self.name} ===
        Output:
        {output}

        Evaluation Criteria:
        {criteria}

        Provide a score from 1–5 and a short justification.
        """
        # Run evaluation at a lower temperature for stability
        response = client.generate_content(
            eval_prompt,
            generation_config={"temperature": 0.3}
        )
        return response.text  # Return the evaluation score and rationale

# %% [markdown]
# ### ✨ Step 2: Prompt Templates per Agent
#
# This section defines the prompt structures and agent configurations used in the multi-agent system.
# Each agent is crafted based on my **best-performing prompt strategies** from previous evaluations and includes:
#
# - 🧠 A clear prompting method (Few-Shot, CoT, ToT, ReAct, etc.)
# - 🪄 A wizard-inspired persona name for storytelling impact
# - 🔥 A specific temperature for balancing creativity and reliability
# - 🧪 Real prompt formats that were proven effective during prompt testing
#
# The metadata for each agent includes:
# - `description`: What the agent does
# - `wizard`: The fun wizarding alias (e.g., "The Sorting Hat")
# - `style`: Prompting strategy (e.g., Few-Shot)
# - `prompt`: Jinja-style string with context injection
# - `temperature`: Tuned creativity level for LLM response generation

# %%
# === Step 2: Prompt Templates per Agent ===
# These are based on the user's best-performing prompt designs from previous evaluations.
# Each includes:
# - A clear prompting strategy (Few-Shot, CoT, ToT, etc.)
# - A wizard-themed persona for storytelling/presentation impact
# - Tuned temperature for appropriate creativity vs stability
# - Prompts derived from actual high-scoring examples used in prompting evaluations
# Define prompt templates and agent metadata including:
# - Description of the agent’s purpose
# - Wizarding persona (fun identifier)
# - Prompting style (Few-Shot, CoT, ToT, etc.)
# - Prompt template itself (Jinja-style)
# - Agent temperature for creativity vs consistency

prompt_templates = {

    # ======================= 💬 FEEDBACK AGENT =======================
    # 🎭 Name: Howler Whisperer (Feedback Summarizer)
    # 📚 Purpose: Condense noisy user feedback into clear, actionable summaries
    # 🌐 Grounded in: Trustpilot, Google Play, Apple Store reviews
    # 🧠 Output Structure:
    #     - Condensed summary (1–2 lines)
    #     - Neutral, informative tone
    #     - Preserves problem and sentiment
    # 🔥 Temperature: 0.4 – Moderate creativity for abstraction without hallucination
    "feedback": {
        "description": "Summarizes raw user reviews and NPS comments into concise insights.",
        "wizard": "Howler Whisperer (Feedback Summarizer)",
        "style": "Few-Shot",
        "grounding": [
            "https://www.trustpilot.com/review/app.com",
            "https://play.google.com/store",
            "https://apps.apple.com"
        ],
        "prompt": """
        Here are examples of how to summarize feedback:

        Input: \"App crashes after login. Very frustrating!\"
        Output: \"Users report login-related crashes causing frustration.\"

        Input: \"Interface looks nice but the app is slow on older phones.\"
        Output: \"Slow performance on older devices despite good UI.\"

        Input: \"Too many notifications. I'm overwhelmed every time I open it.\"
        Output: \"Overwhelming number of notifications affects user comfort.\"

        Input: \"Great potential but missing offline mode.\"
        Output: \"Desire for offline functionality among users with good feature outlook.\"

        Input: {input}
        Output:
        """,
        "temperature": 0.4  # Moderate creativity for summarization while maintaining structure
    },

    # ======================= 🔍 ISSUE AGENT =======================
    # 🎭 Name: The Marauder (Blocker Finder)
    # 📚 Purpose: Detects product blockers using Chain-of-Thought reasoning
    # 🌐 Grounded in: Trustpilot, Google Play, Apple Store reviews
    # 🧠 Output Structure:
    #     - Thought Process: Step-by-step logic
    #     - Final Issue Summary
    #     - Optional Root Cause Hypothesis
    #     - Category Type
    #     - Potential Solution Suggestions
    # 🔥 Temperature: 0.3 – Stable, consistent analysis for deterministic logic
    "issue":{
        "description": "Detects product blockers using Chain-of-Thought reasoning",
        "wizard": "The Marauder (Blocker Finder)",
        "style": "CoT",
        "grounding": [
            "https://www.trustpilot.com/review/app.com",
            "https://play.google.com/store",
            "https://apps.apple.com"
        ],
        "prompt": """
        You are a product analyst assistant. Your job is to extract potential blockers from customer feedback by analyzing complaints,
        inferring root causes, and proposing clear descriptions of the underlying product issues.

        Company: {company_name}
        This feedback comes from a public app store or review platform.

        Feedback:
        {input}

        ### Thought Process:
        1. Identify key pain points in the feedback.
        2. Map them to possible technical or UX problems.
        3. Determine whether it's a recurring or severe blocker.

        ### Final Issue (summary in one sentence):

        ### Optional Root Cause Hypothesis:

        ### Suggested Categories (e.g., Bug, UX Flaw, Performance, Feature Gap):

        ### Optional: Brainstorm Potential Solutions (bullet list)
        """,
        "temperature": 0.3 # Lower temperature ensures consistency and precision for step-by-step issue analysis,
        },  
  # ======================= 😊 SENTIMENT AGENT =======================
    # 🎭 Name: The Legilimens (Sentiment Classifier)
    # 📚 Purpose: Detects emotional tone in user feedback
    # 🌐 No grounding (pure classification task)
    # 🧠 Output Structure:
    #     - Single word: Positive, Neutral, or Negative
    # 🔥 Temperature: 0.2 – Deterministic, consistent output for classification
    "sentiment": {
        "description": "Classifies sentiment in user feedback using one-shot style.",
        "wizard": "The Legilimens (Sentiment Classifier)",
        "style": "One-Shot",
        "prompt": """
        Classify the emotional tone of the feedback below.

        Feedback: \"{input}\"
        
        Sentiment (Positive, Neutral, Negative):
        """,
        "temperature": 0.2  # Low temperature for deterministic sentiment classification
    },  
     
     # ======================= 🔍 COMPETITOR AGENT =======================
    # 🎭 Name: The Seer (Competitor Analyst)
    # 📚 Purpose: Analyzes and contrasts product strategies from competitors using ReAct prompting
    # 🌐 Grounded in: Product Hunt, TechCrunch, Wikipedia
    # 🧠 Output Structure:
    #     - Thought: Initial reasoning
    #     - Action: Search (simulated)
    #     - Observation: Context summary
    #     - Answer: Final comparative insight
    # 🔥 Temperature: 0.7 – Allows exploratory, search-guided reasoning
    "competitor": {
        "description": "Explores competitive insights using ReAct prompting and grounded search logic.",
        "wizard": "The Seer (Competitor Analyst)",
        "style": "ReAct",
        "grounding": [
            "https://www.producthunt.com",
            "https://techcrunch.com",
            "https://en.wikipedia.org/wiki/List_of_music_streaming_services"
        ],"prompt":"""
    
        ### Output Format:
        - Competitive Positioning Summary
        - Strengths & Differentiators
        - Weaknesses or Gaps
        - Strategy Type (choose one): Cost Leadership, Differentiation, Focused Strategy, Innovation Strategy, Platform Strategy
        - Optional: Commentary using Porter’s Five Forces (Threat of new entrants, Bargaining power of buyers, Bargaining power of suppliers, Threat of substitutes, Industry rivalry)

        Answer:
        Summarize competitive positioning with supporting logic.
        """,
        "temperature": 0.7  # High creativity and exploration needed for competitive analysis
    }, 
         # ======================= 💡 IDEATION AGENT =======================
    # 📤 Output Format:
    # - Option A/B/C with Title + Description
    # - Score table (Originality, Feasibility, Impact)
    # - Final Pick with rationale
    # 🎭 Name: Room of Requirement (Feature Ideator)
    # 📚 Purpose: Generates breakthrough product feature ideas
    # 🌐 No external grounding (creative zero-shot ideation)
    # 🧠 Output Structure:
    #     - Option A, B, C: Unique, bold, or visionary features
    #     - Scores per option (originality, feasibility, impact)
    #     - Final Pick with justification
    # 🔥 Temperature: 0.8 – Max creativity for divergence and innovation
    "ideation": {
        "description": "Generates breakthrough product feature ideas using Tree-of-Thought prompting.",
        "wizard": "Room of Requirement (Feature Ideator)",
        "style": "ToT",
        "prompt":"""

        Output Format:
        - Three feature ideas labeled A, B, C (Title + Description)
        - A score section evaluating each idea (Originality, Feasibility, Impact)
        - A final selection with a short justification

        Context:
        {input}

        ### Option A:
        Feature Title:
        Description:

        ### Option B:
        Feature Title:
        Description:

        ### Option C:
        Feature Title:
        Description:

        ### Score Each Option:
        - Originality (1–10):
        - Feasibility (1–10):
        - Impact (1–10):

        ### Final Picks & Why:
        """,
        "temperature": 0.8   # Maximize divergent thinking for ideation and ToT exploration
    },  
    
    # ======================= 🎯 PRIORITIZATION AGENT =======================
    # 🎭 Name: The Sorting Hat (Prioritization Engine)
    # 📚 Purpose: Ranks feature ideas using ICE scoring (Impact, Confidence, Effort)
    # 🌐 No grounding – input comes from previous agents
    # 🧠 Output Structure:
    #     - Markdown-style table
    #     - Columns: Feature, Impact, Confidence, Effort, ICE Score
    #     - Ordered by ICE Score (descending)
    # 🔥 Temperature: 0.5 – Balanced creativity and structure
    "prioritization": {
        "description": "Scores features using ICE framework with structured logic.",
        "wizard": "The Sorting Hat (Prioritization Engine)",
        "style": "CoT + Scoring",
        "prompt": """ Evaluate the following product features using the ICE scoring model:

        Impact = How much the feature will affect the user or business (1–10)
        Confidence = Certainty in your estimates (1–10)
        Effort = Level of complexity, time, and resources needed (1–10)

        Compute the ICE Score as: (Impact * Confidence) / Effort

        Features:
        {input}

        Output Format:
        | Feature | Impact | Confidence | Effort | ICE Score |
        |---------|--------|------------|--------|------------|
        | Example Feature | 8 | 7 | 4 | 14.0 |

        Sort the table by ICE Score descending and summarize your decision-making rationale below.
        """,
        "temperature": 0.5  # Balanced reasoning for ICE scoring (some creativity, some structure)
    },   # ======================= ✅ OKR AGENT =======================
    # 🎭 Name: The Headmaster (OKR Generator)
    # 📚 Purpose: Converts features into actionable SMART Objectives and Key Results
    # 🌐 No external grounding – relies on structured inputs from prior agents
    # 🧠 Output Structure:
    #     - Objective: 1 sentence summary
    #     - Key Results: 2–3 measurable outcomes
    # 🔥 Temperature: 0.4 – Requires clean structure with slight creativity
    "okr": {
        "description": "Converts validated features into SMART OKRs.",
        "wizard": "The Headmaster (OKR Generator)",
        "style": "Few-Shot",
        "prompt":"""

        Turn the following feature into a SMART OKR:

        Feature: {input}

        Objective:
        - Key Result 1:
        - Key Result 2:
        - (Optional) Key Result 3:
        These are some examples for your reference to good and bad examples.
        ### Few-Shot Examples:

#================ BAD EXAMPLES: What NOT to Do ===
# These OKRs may include numbers but lack context, clarity, or actionable structure.

        Input: Make app better
        Objective: Make the app better
        - Key Result 1: Users should like the app more
        - Key Result 2: Have fewer bugs maybe

        Input: Improve product
        Objective: Improve product
        - Key Result 1: Increase sessions by 40%  # No baseline or reason
        - Key Result 2: Add 5 new features  # No context or alignment

        Input: Be more AI-powered
        Objective: Be more AI-powered
        - Key Result 1: Add AI stuff
        - Key Result 2: Do a demo
                  
# =========== GOOD EXAMPLES: Recommended Patterns ===
        Input: Improve onboarding experience
        Objective: Improve onboarding for new mobile users
        - Key Result 1: Increase completion rate from 62% to 85% (based on historical A/B test performance)
        - Key Result 2: Reduce average onboarding time from 4 min to under 2 min (benchmarked against top apps)
        - Key Result 3: Achieve 90% satisfaction in post-onboarding survey (currently at 75%)

        Input: Launch AI-powered feature recommendation
        Objective: Deploy smart feature recommendation engine for premium users
        - Key Result 1: Roll out to 100% of premium users by Q2 (controlled population)
        - Key Result 2: Increase feature engagement by 25% within 30 days (baseline = 3 features/week)
        - Key Result 3: Collect 1,000 qualitative feedback submissions (targeting 10% response rate)

Output Format:
        Objective:
        - Key Result 1:
        - Key Result 2:
        - (Optional) Key Result 3:
        """,
        "temperature": 0.4  # Requires clean structure with slight creativity
    }
}

# %%
### === Step 3: Agent Runner ===
## Dynamically selects and runs an agent from prompt_templates.
## It fills in the prompt with input + company name, creates the agent, and returns its output.
def run_agent(agent_key: str, input_text: str, company_name="YourCompany") -> str:
        # ✅ Safety check for Gemini client
    if "client" not in globals():
        raise RuntimeError("❌ Gemini model not initialized. Please run the setup cell first.")
    
    agent_meta = prompt_templates[agent_key]  # Get agent's metadata
    if "prompt" not in agent_meta:
        return f"[ERROR] Agent '{agent_key}' is missing a prompt."

    filled_prompt = agent_meta["prompt"].format(input=input_text, company_name=company_name)  # Fill prompt
    agent = BaseAgent(agent_key, agent_meta["style"], agent_meta["temperature"])  # Initialize agent
    return agent.run(filled_prompt)  # Run and return output

# %%
# let's test
output = run_agent("feedback", "The app keeps crashing when I open messages.", "Spotify")
print(output)
# Out:
# "App crashes when opening messages."

# %%
# let's test
output = run_agent("ideation", "The app keeps crashing when I open messages.", "Spotify")
print(output)
# Out:
# Okay, here are three feature ideas to address the app crashing issue, along with scoring and a final pick.
#
# ### Option A:
# Feature Title: **Message Database Optimization**
# Description: Implement a background process to regularly optimize the message database. This includes defragmentation, indexing, and removal of orphaned data. This will improve data access speed and reduce the likelihood of memory overload when opening messages.
#
# ### Option B:
# Feature Title: **Crash Report & Auto-Restart with Limited Messages**
# Description: Implement robust crash reporting that sends detailed logs to developers. Upon crash detection, the app automatically restarts and initially loads only a limited number of the most recent messages, allowing the user to access the app while background loading the remaining messages.
#
# ### Option C:
# Feature Title: **Image & Video Compression on Message Load**
# Description: When opening a conversation, aggressively compress images and videos before rendering them on the screen. This reduces memory consumption and improves loading speed, preventing crashes caused by large media files within messages.
#
# ### Score Each Option:
# **Option A: Message Database Optimization**
# - Originality (1–10): 6 (Database optimization is a common practice, but the context is key)
# - Feasibility (1–10): 8 (Relatively straightforward to implement)
# - Impact (1–10): 7 (Could significantly reduce crashes, but might not eliminate them entirely)
#
# **Option B: Crash Report & Auto-Restart with Limited Messages**
# - Originality (1–10): 7 (Good combination of diagnostic and immediate usability)
# - Feasibility (1–10): 7 (Crash reporting requires careful implementation, but auto-restart is feasible)
# - Impact (1–10): 9 (Provides immediate relief and valuable data for debugging)
#
# **Option C: Image & Video Compression on Message Load**
# - Originality (1–10): 5 (Common optimization technique)
# - Feasibility (1–10): 6 (Requires careful balancing act between compression and visual quality)
# - Impact (1–10): 6 (Useful if the crash is caused by large media, but less effective for other causes)
#
# ### Final Picks & Why:
#
# My top pick is **Option B: Crash Report & Auto-Restart with Limited Messages.** While database optimization (Option A) and media compression (Option C) are valuable, Option B provides both immediate relief to the user (auto-restart with limited messages) and valuable information for developers to fix the underlying cause of the crashes (crash reporting). This combination of usability and debugging makes it the most effective solution in the short and long term.  The other options should be considered as complementary solutions to implement alongside Option B.

# %% [markdown]
# It seems working so let's see whether we can connect agents together. Start with the simple then move to creating pipeline.

# %%
user_input = "how many users having issues with log in "
summary = run_agent("feedback", user_input, "Spotify")
print(summary)
# Out:
# "Unspecified number of users experiencing login issues."

# %% [markdown]
# Now let's have fun with these agents. I want to write a fictional scenario and test all of the agents to see how they help in context.
#
# ## **🧪 Magical Agent Test Script**
# We’ll simulate a real-world product scenario for a fictional company ("Beatify") and run all 7 agents on a creative, messy, user feedback input.

# %% [markdown]
# **🎧 Test Case: Customer Feedback**

# %%
user_input = """
I've used Beatify for 3 months and it’s mostly okay, but lately it freezes when switching playlists. 
Also, the search takes forever, and why can't I find podcasts anymore? Feels like it got worse. 
Still love the personalized mixes though. But if this doesn’t get fixed, I’ll cancel.
"""
company_name = "Beatify"

# %%
# === Run all agents independently
individual_agent_outputs = {}

for agent_name in prompt_templates.keys():
    print(f"\n🔮 {agent_name.upper()} Agent Output ({prompt_templates[agent_name]['wizard']})")
    output = run_agent(agent_name, user_input, company_name)
    print(f"📤 Output:\n{output}")
    print("=" * 80)
    individual_agent_outputs[agent_name] = output

# === Final export package
flat_multiagent_export = {
    "metadata": {
        "strategy": "multi-agent",
        "type": "flat",
        "company": company_name,
        "input": user_input.strip(),
        "description": "Each agent runs independently on the same user input without passing results sequentially.",
        "timestamp": datetime.now().isoformat()
    },
    "results": individual_agent_outputs
}

# === Save to JSON file
with open("nextive_individual_agents_flat.json", "w", encoding="utf-8") as f:
    json.dump(flat_multiagent_export, f, indent=2, ensure_ascii=False)

print("✅ Saved: nextive_individual_agents_flat.json (check Output tab to download)")
# Out:
# 🔮 FEEDBACK Agent Output (Howler Whisperer (Feedback Summarizer))
# 📤 Output:
# "Recent updates have introduced freezing during playlist switching and slow search functionality. Users also report the removal of podcasts. Personalized mixes remain a valued feature, but continued issues may lead to cancellation."
#
# ================================================================================
#
# 🔮 ISSUE Agent Output (The Marauder (Blocker Finder))
# 📤 Output:
# ### Thought Process:
# 1.  **Key Pain Points:**
#     *   Freezing when switching playlists.
#     *   Slow search functionality.
#     *   Missing podcasts.
#     *   Threat to cancel subscription.
# 2.  **Possible Problems:**
#     *   Freezing: Bug in playlist management, memory leak, or performance issue with large playlists.
#     *   Slow Search: Inefficient search algorithm, server-side issue, or database indexing problem.
#     *   Missing Podcasts: Feature removal, bug in content delivery, or change in content licensing.
# 3.  **Blocker Assessment:**
#     *   Recurring: "Lately" suggests the freezing issue is recent.
#     *   Severe: The user threatens to cancel their subscription, indicating high dissatisfaction.
#
# ### Final Issue (summary in one sentence):
# Beatify is experiencing performance issues with playlist switching and search functionality, and podcasts are no longer accessible, leading to user dissatisfaction and potential churn.
#
# ### Optional Root Cause Hypothesis:
# A recent update introduced a bug that affects playlist management and search performance. Additionally, a change in content licensing or a bug in content delivery may be responsible for the missing podcasts.
#
# ### Suggested Categories:
# *   Bug
# *   Performance
# *   Feature Gap (or Regression)
#
# ### Optional: Brainstorm Potential Solutions (bullet list)
# *   Investigate and fix the playlist switching freeze (profile performance, check memory usage).
# *   Optimize the search algorithm and database indexing.
# *   Determine the cause of the missing podcasts (licensing, bug, intentional removal) and restore the feature or communicate the change to users.
# *   Monitor user feedback closely after implementing fixes.
#
# ================================================================================
#
# 🔮 SENTIMENT Agent Output (The Legilimens (Sentiment Classifier))
# 📤 Output:
# Sentiment: **Negative**
#
# **Explanation:**
#
# While the feedback mentions a positive aspect ("Still love the personalized mixes"), the overall tone is negative due to the following:
#
# *   **Problems Highlighted:** The user explicitly mentions freezing issues, slow search, and missing features (podcasts).
# *   **Frustration:** Phrases like "takes forever" and "Feels like it got worse" indicate frustration.
# *   **Threat of Cancellation:** The user states they will cancel if the issues aren't fixed, which is a strong negative indicator.
#
# Therefore, despite the one positive point, the negative aspects and the threat of cancellation outweigh it, making the overall sentiment negative.
#
# ================================================================================
#
# 🔮 COMPETITOR Agent Output (The Seer (Competitor Analyst))
# 📤 Output:
# Okay, I need more information to give you a good answer. I need to know *what* company or product/service we're talking about.  Please provide me with details about the company, its industry, its main competitors, and its target market.
#
# **Example:**
#
# Let's say we're talking about **Tesla (the electric vehicle manufacturer)**.
#
# Then, I could provide an answer like this:
#
# **### Output Format: Tesla**
#
# *   **Competitive Positioning Summary:** Tesla positions itself as a premium electric vehicle manufacturer with a focus on innovation, performance, and sustainability. It aims to be a leader in the transition to electric transportation and renewable energy solutions. They command a significant market share in the EV market, largely due to brand recognition and advanced technology.
#
# *   **Strengths & Differentiators:**
#     *   **Brand Recognition & Image:** Strong brand associated with innovation, luxury, and environmental consciousness.
#     *   **Technology Leadership:** Advanced battery technology, autonomous driving capabilities (Autopilot/Full Self-Driving), and over-the-air software updates.
#     *   **Supercharger Network:** Extensive and proprietary charging infrastructure provides a significant advantage for long-distance travel.
#     *   **Performance:** EVs often outperform Internal Combustion Engine vehicles in acceleration and handling.
#     *   **Vertical Integration:** Control over key components like batteries and software allows for greater innovation and cost control.
#     *   **Direct Sales Model:** Bypasses traditional dealerships, allowing for greater control over the customer experience and pricing.
#
# *   **Weaknesses or Gaps:**
#     *   **Price Point:** Higher price compared to many traditional gasoline vehicles and some other EVs.
#     *   **Production Capacity:** Historically faced challenges in scaling production to meet demand.
#     *   **Service & Repair:** Service network, while expanding, can be a bottleneck in certain areas.
#     *   **Autopilot/FSD Concerns:** Safety concerns and regulatory scrutiny surrounding autonomous driving features.
#     *   **Dependence on Elon Musk:** The company's success is closely tied to its CEO, which poses a risk.
#
# *   **Strategy Type:** **Differentiation Strategy** - Tesla differentiates itself through superior technology, performance, brand image, and charging infrastructure. While they aim to reduce costs over time, their primary focus is on offering a premium and innovative product. They also exhibit elements of an **Innovation Strategy** due to their constant pursuit of technological advancements in battery technology, autonomous driving, and manufacturing processes.
#
# *   **Optional: Commentary using Porter’s Five Forces:**
#     *   **Threat of new entrants:** Moderate to High. The barriers to entry in the automotive industry are high (capital investment, regulatory hurdles, established brands). However, the shift to EVs has lowered the barrier somewhat, allowing for new entrants like Rivian, Lucid, and various Chinese manufacturers.
#     *   **Bargaining power of buyers:** Moderate. Buyers have increasing choice in the EV market, putting pressure on Tesla to maintain competitive pricing and features.
#     *   **Bargaining power of suppliers:** Moderate. Tesla has some leverage due to its size and demand for batteries and other components. However, suppliers of specialized EV components (e.g., battery materials) may have significant bargaining power. Tesla mitigates this through vertical integration efforts.
#     *   **Threat of substitutes:** Moderate to High.  Substitutes include traditional gasoline vehicles, hybrid vehicles, public transportation, and ride-sharing services. The attractiveness of these substitutes depends on factors like price, convenience, and environmental concerns.
#     *   **Industry rivalry:** High. The EV market is becoming increasingly competitive, with established automakers and new entrants vying for market share. Competition is based on price, performance, range, charging infrastructure, and features.
#
# **To give you a relevant answer, please provide the company/product details.** I need to know what you want me to analyze!
#
# ================================================================================
#
# 🔮 IDEATION Agent Output (Room of Requirement (Feature Ideator))
# 📤 Output:
# Okay, here are three feature ideas addressing the user's Beatify concerns, along with scoring and final selection:
#
# ### Option A:
# Feature Title: **Playlist Performance Enhancement**
# Description: Optimize playlist handling to eliminate freezing when switching between playlists. This includes code refactoring, caching strategies, and potentially pre-loading playlist data in the background. This addresses the user's core complaint about freezing.
#
# ### Option B:
# Feature Title: **Revamped Search & Podcast Integration**
# Description: Implement a new search algorithm for faster and more accurate results. Reintroduce podcast discovery and integration, possibly with a dedicated podcast section and improved search filtering. This directly tackles the user's search speed and podcast concerns.
#
# ### Option C:
# Feature Title: **Background Task Manager & Resource Monitor**
# Description: Introduce a background task manager accessible within the app settings. This allows users to see what Beatify is doing in the background (e.g., downloading, analyzing music) and potentially pause or prioritize tasks. Include a resource monitor to show CPU and memory usage, helping users understand performance issues.
#
# ### Score Each Option:
# **Option A: Playlist Performance Enhancement**
# *   Originality (1–10): 4 (Performance optimization is common, but crucial)
# *   Feasibility (1–10): 7 (Relatively straightforward engineering task)
# *   Impact (1–10): 9 (Addresses the most pressing user pain point directly)
#
# **Option B: Revamped Search & Podcast Integration**
# *   Originality (1–10): 6 (Combines search improvement with podcast re-integration)
# *   Feasibility (1–10): 6 (Search algorithms can be complex; podcast integration requires content partnerships or APIs)
# *   Impact (1–10): 8 (Addresses search slowness and missing feature, improving overall usability)
#
# **Option C: Background Task Manager & Resource Monitor**
# *   Originality (1–10): 7 (More advanced feature for tech-savvy users)
# *   Feasibility (1–10): 5 (Requires significant engineering and monitoring capabilities)
# *   Impact (1–10): 6 (Helpful for diagnosing issues, but less directly impactful for most users)
#
# ### Final Picks & Why:
#
# My primary recommendation is to implement **Option A: Playlist Performance Enhancement**. While Option B addresses important concerns and Option C offers more advanced insights, the user explicitly stated the freezing issue could lead to cancellation. Addressing the most critical, immediate pain point is crucial for retention. After addressing Option A, Option B should be prioritized to improve overall satisfaction. Option C is less essential and can be considered for a later release.
#
# ================================================================================
#
# 🔮 PRIORITIZATION Agent Output (The Sorting Hat (Prioritization Engine))
# 📤 Output:
# Okay, let's break down the user feedback, identify the features, score them using the ICE model, and then provide a rationale.
#
# **Features Identified:**
#
# 1.  **Playlist Freezing:** The app freezes when switching playlists.
# 2.  **Slow Search:** The search function is slow.
# 3.  **Missing Podcasts:** Podcasts are no longer findable.
#
# **ICE Scoring:**
#
# Here's the ICE scoring for each feature, along with explanations for the scores:
#
# | Feature | Impact | Confidence | Effort | ICE Score |
# |---------|--------|------------|--------|------------|
# | Playlist Freezing | 9 | 8 | 5 | 14.4 |
# | Missing Podcasts | 8 | 7 | 4 | 14.0 |
# | Slow Search | 7 | 8 | 6 | 9.3 |
#
# **Rationale for Scores:**
#
# *   **Playlist Freezing:**
#     *   **Impact (9):** Freezing is a major usability issue. It directly prevents users from enjoying the core functionality of the app (listening to music). A user even threatened to cancel their subscription. This has a high impact on user experience and retention.
#     *   **Confidence (8):** The user explicitly stated they are experiencing this issue. It's a direct quote, making us relatively confident.
#     *   **Effort (5):** Debugging freezing issues can be tricky, but switching playlists is a relatively contained action. We'll assume a moderate level of effort to investigate and fix.
#
# *   **Missing Podcasts:**
#     *   **Impact (8):** Users expect to be able to access all content types. Removing podcasts could alienate users who enjoy them. If podcasts are a key part of the app's offering, this could lead to churn.
#     *   **Confidence (7):** The user explicitly stated they can't find podcasts anymore.
#     *   **Effort (4):** This could be a simple configuration issue, a problem with the podcast feed, or a change in the app's UI. We'll assume a moderate level of effort to investigate and fix.
#
# *   **Slow Search:**
#     *   **Impact (7):** A slow search function is frustrating and inefficient. It impacts the user's ability to find the content they want quickly.
#     *   **Confidence (8):** The user directly stated the search takes forever.
#     *   **Effort (6):** Optimizing search performance can be complex, involving database queries, indexing, and potentially server-side changes. We'll assume a moderate to high level of effort.
#
# **Decision-Making Rationale:**
#
# Based on the ICE scores, the features should be prioritized as follows:
#
# 1.  **Playlist Freezing (ICE Score: 14.4):** This is the highest priority due to its high impact and relatively manageable effort. Freezing issues directly impact the core user experience and can lead to subscription cancellations. Addressing this should be the immediate focus.
# 2.  **Missing Podcasts (ICE Score: 14.0):** This is the second-highest priority. It has a high impact and relatively manageable effort.
# 3.  **Slow Search (ICE Score: 9.3):** While important, the slow search has the lowest ICE score. It should be addressed after the freezing and podcast issues are resolved. Optimizing search can be a more complex and time-consuming task.
#
# ================================================================================
#
# 🔮 OKR Agent Output (The Headmaster (OKR Generator))
# 📤 Output:
# Okay, I will translate the user feedback into a SMART OKR. Here's the breakdown:
#
# **Objective:** Improve Beatify's core functionality and stability to prevent user churn.
#
# **Key Results:**
#
# - Key Result 1: Reduce playlist switching freeze occurrences from an average of 3 times per week to less than 1 per week (measured via user crash reports and telemetry).
# - Key Result 2: Decrease average search time from 8 seconds to under 3 seconds (measured via internal performance monitoring).
# - Key Result 3: Re-integrate podcast search functionality and achieve a 4.5-star average rating for podcast search results (measured via in-app user feedback) within the next quarter.
#
# ================================================================================
# ✅ Saved: nextive_individual_agents_flat.json (check Output tab to download)

# %% [markdown]
# I think this is the most exciting part of this assignment so far! how dope is that the isolated llm outputs now are connected and make sense and give a bit of confidence and trust on the output. no evaluation needed! :))

# %%
evaluator = BaseAgent(name="MultiAgentEvaluator", prompt_style="Few-Shot", temperature=0.3)

# %%
with open("/kaggle/input/nextive-individual-agent-flat/nextive_individual_agents_flat.json", "r", encoding="utf-8") as f:
     flat_results = json.load(f)["results"]

# Save to working directory
shutil.copy(
    "/kaggle/input/nextive-individual-agent-flat/nextive_individual_agents_flat.json",
    "/kaggle/working/nextive_individual_agents_flat.json"
)

print("✅ Flat agent results loaded and copied to /kaggle/working/")
# Out:
# ✅ Flat agent results loaded and copied to /kaggle/working/

# %%
flat_results
# Out:
# {'feedback': '"TaskBuddy praised for its concept, but suffers from bugs (tasks disappearing, late reminders) and lacks desired features like dark mode, leading to concerns about user feedback implementation."\n',
#  'issue': '### Thought Process:\n1. **Key Pain Points:**\n    *   Tasks disappearing after completion.\n    *   Reminders not delivered on time.\n    *   Lack of dark mode.\n\n2.  **Possible Technical or UX Problems:**\n    *   Tasks disappearing: Data synchronization issue, bug in task status update logic, UI refresh problem.\n    *   Reminders not on time: Bug in the reminder scheduling system, OS-level notification issues, time zone handling error.\n    *   Lack of dark mode: Feature not implemented, potentially due to prioritization or technical difficulties.\n\n3.  **Blocker Assessment:**\n    *   Disappearing tasks and delayed reminders are severe blockers as they directly impact the core functionality and reliability of the app.\n    *   Lack of dark mode is a UX issue and a feature gap, potentially impacting user experience and accessibility, but less critical than the other two.\n\n### Final Issue (summary in one sentence):\nTaskBuddy suffers from critical bugs causing data loss and unreliable reminders, alongside a missing dark mode feature requested by users.\n\n### Optional Root Cause Hypothesis:\nInconsistent data synchronization between the app and the backend, coupled with a flawed reminder scheduling mechanism, are causing the core functionality issues; the lack of dark mode may be due to resource constraints or prioritization of other features.\n\n### Suggested Categories:\n*   Bug\n*   Performance\n*   Feature Gap\n*   UX Flaw\n\n### Optional: Brainstorm Potential Solutions\n*   **Disappearing Tasks:**\n    *   Implement robust data synchronization with conflict resolution.\n    *   Add data integrity checks and logging to track task status changes.\n    *   Improve UI refresh mechanisms to reflect the correct task status.\n*   **Delayed Reminders:**\n    *   Revamp the reminder scheduling system, ensuring accurate time zone handling.\n    *   Investigate potential OS-level notification issues and optimize for different platforms.\n    *   Implement a fallback mechanism for reminders in case of scheduling failures.\n*   **Lack of Dark Mode:**\n    *   Prioritize the implementation of dark mode based on user demand and accessibility considerations.\n    *   Allocate development resources for designing and implementing a user-friendly dark mode.\n    *   Gather user feedback on preferred dark mode aesthetics and functionality.\n',
#  'sentiment': 'Here\'s the breakdown of the emotional tone:\n\n*   **Sentiment:** Negative\n\n**Explanation:**\n\nWhile the feedback starts with a positive sentiment ("I love the idea of TaskBuddy"), the overall tone quickly shifts to negative due to the issues raised:\n\n*   **Bugs:** "really buggy," "tasks disappear," "reminders never come on time" - These indicate frustration and dissatisfaction.\n*   **Missing Feature:** "why is there still no dark mode?" - This expresses disappointment and implies a lack of responsiveness from the developers.\n*   **Accusation:** "Feels like you\'re not listening to users" - This is a direct criticism and adds to the negative sentiment.\n\nThe negative aspects outweigh the initial positive statement, making the overall sentiment negative.',
#  'competitor': 'Okay, I need more information to provide a meaningful competitive positioning summary. To give you a useful answer, please tell me:\n\n*   **What company or product are you analyzing?** (e.g., Tesla, a local coffee shop, a specific software application)\n*   **Who are its main competitors?** (Name at least 2-3)\n*   **What industry is it in?** (Be specific - e.g., Electric Vehicle Manufacturing, Specialty Coffee Retail, Project Management Software)\n*   **What is the *general* value proposition of the company/product?** (e.g., "Provides high-performance electric vehicles," "Offers premium coffee in a cozy environment," "Helps teams collaborate effectively on projects.")\n\nOnce I have this information, I can analyze the competitive positioning and provide you with the output format you requested.\n\n**Example of the type of information I need:**\n\n*   **Company:** Tesla\n*   **Competitors:** Ford (Electric Vehicle Division), General Motors (Electric Vehicle Division), Rivian, Lucid\n*   **Industry:** Electric Vehicle Manufacturing\n*   **Value Proposition:** High-performance electric vehicles with advanced technology and a focus on sustainability.\n\n**Then, I could provide an answer like this (this is a *hypothetical* based on the above example):**\n\n**### Output Format:**\n\n**- Competitive Positioning Summary:** Tesla aims to be the leading provider of high-performance, technologically advanced electric vehicles, primarily targeting affluent consumers and early adopters.  It distinguishes itself through its brand image, Supercharger network, and software capabilities.\n\n**- Strengths & Differentiators:**\n\n*   **Brand Recognition & Image:**  Strong brand associated with innovation and luxury.\n*   **Technology Leadership:**  Advanced battery technology, autonomous driving features (Autopilot/Full Self-Driving), and over-the-air software updates.\n*   **Supercharger Network:**  Extensive proprietary charging network providing convenient and reliable charging.\n*   **Vertical Integration:**  Control over battery production and some manufacturing processes.\n*   **Performance:**  Vehicles known for rapid acceleration and handling.\n\n**- Weaknesses or Gaps:**\n\n*   **Production Capacity:**  Historically struggled to meet production targets and manage supply chain bottlenecks.\n*   **Price Point:**  Vehicles are generally more expensive than comparable internal combustion engine vehicles and some competing EVs.\n*   **Customer Service:**  Some customers report issues with service and support.\n*   **Reliability:**  Some reliability ratings are lower than competitors.\n\n**- Strategy Type:** Differentiation Strategy\n\n**- Optional: Commentary using Porter’s Five Forces:**\n\n*   **Threat of New Entrants:** Medium. High capital requirements and technological barriers to entry, but established automakers are investing heavily in EVs.\n*   **Bargaining Power of Buyers:** Medium.  Buyers have choices among EV brands and traditional automakers.  Price sensitivity varies by segment.\n*   **Bargaining Power of Suppliers:** Medium. Tesla has some vertical integration, reducing dependence on some suppliers.  However, battery material suppliers have significant leverage.\n*   **Threat of Substitutes:** Low in the core EV market.  However, traditional internal combustion engine vehicles remain a substitute for some buyers.  Other transportation options are also substitutes.\n*   **Industry Rivalry:** High.  Intense competition from established automakers, new EV startups (Rivian, Lucid), and Chinese EV manufacturers.  Competition is based on price, performance, technology, and brand.\n\n**Please provide the information so I can give you a useful answer.**\n',
#  'ideation': 'Okay, here are three feature ideas for TaskBuddy, addressing the user\'s concerns about bugs, reminders, and lack of dark mode, along with a scoring section and final selection.\n\n### Option A:\nFeature Title: **Task Persistence & Sync Assurance**\nDescription: Implement a robust data persistence layer with automatic cloud syncing and conflict resolution. This feature ensures that tasks marked as complete are permanently saved and synced across all devices, preventing data loss due to bugs or network issues.  Includes a local data backup and restore function.\n\n### Option B:\nFeature Title: **Intelligent & Reliable Reminders**\nDescription: Redesign the reminder system to utilize more accurate scheduling algorithms and implement real-time push notifications.  Allow users to customize reminder sensitivity (e.g., "Remind me 15 minutes before, plus or minus 2 minutes").  Includes a notification log for troubleshooting missed reminders.\n\n### Option C:\nFeature Title: **Dark Mode & Theme Customization**\nDescription: Introduce a fully functional dark mode option, accessible through the settings menu.  Expand theme options beyond light and dark, allowing users to select accent colors and customize the overall app appearance to suit their preferences.\n\n### Score Each Option:\n**Option A (Task Persistence & Sync Assurance):**\n- Originality (1–10): 6 (Cloud syncing is common, but the focus on reliability is key)\n- Feasibility (1–10): 7 (Requires significant backend work and QA, but technically achievable)\n- Impact (1–10): 9 (Addresses a critical bug causing frustration and data loss)\n\n**Option B (Intelligent & Reliable Reminders):**\n- Originality (1–10): 5 (Reminder systems exist, but improved accuracy and customizability can differentiate it)\n- Feasibility (1–10): 8 (Relatively straightforward to implement compared to a full data architecture overhaul)\n- Impact (1–10): 8 (Improves user experience and task completion rates, addressing another key pain point)\n\n**Option C (Dark Mode & Theme Customization):**\n- Originality (1–10): 4 (Dark mode is a standard feature in most apps)\n- Feasibility (1–10): 9 (Relatively easy to implement, mostly UI work)\n- Impact (1–10): 7 (Addresses a user request and improves usability, especially in low-light conditions)\n\n### Final Picks & Why:\n**Top Pick: Option A (Task Persistence & Sync Assurance)**\n\nWhile all three options address valid concerns, fixing the bug that causes tasks to disappear is paramount. Data loss is a major user experience killer and erodes trust in the app. Addressing this issue will have the biggest positive impact on user satisfaction.\n\n**Secondary Pick: Option B (Intelligent & Reliable Reminders)**\n\nAfter ensuring data is safe, improving the reliability of reminders is the next most important factor. Reminders are a core feature, and making them more dependable increases the value proposition of TaskBuddy. Option C, while desirable, is more of a cosmetic improvement and less critical than addressing functional issues.\n',
#  'prioritization': "Okay, let's break down the user feedback into individual features, assign ICE scores, and then analyze the results.\n\n**Features Breakdown and ICE Scoring:**\n\nBased on the user feedback, we can identify the following features:\n\n*   **Bug Fixes (Task Disappearance):** Addressing the issue of tasks disappearing after being marked as done.\n*   **Reminder Fixes:** Ensuring reminders are delivered on time.\n*   **Dark Mode Implementation:** Adding a dark mode option to the application.\n\nHere's the ICE scoring table:\n\n| Feature | Impact | Confidence | Effort | ICE Score |\n|---------|--------|------------|--------|------------|\n| Bug Fixes (Task Disappearance) | 9 | 9 | 4 | 20.25 |\n| Reminder Fixes | 8 | 8 | 3 | 21.33 |\n| Dark Mode Implementation | 6 | 7 | 5 | 8.4 |\n\n**Decision-Making Rationale:**\n\nThe ICE scores clearly prioritize bug fixes and reminder fixes over dark mode implementation. Here's the reasoning:\n\n*   **Bug Fixes (Task Disappearance):** This has a very high impact because it directly affects the core functionality of the application. If tasks disappear, the entire purpose of TaskBuddy is undermined. Confidence is also high because the user explicitly mentions this bug. The effort is estimated to be moderate, assuming the root cause can be identified and resolved without a complete architectural overhaul.\n*   **Reminder Fixes:** Timely reminders are crucial for task management. If reminders are unreliable, users will miss deadlines and lose trust in the app. The impact is high, confidence is high, and the effort is estimated to be relatively low, as it might involve tweaking the reminder scheduling system.\n*   **Dark Mode Implementation:** While dark mode is a popular feature and improves user experience, it doesn't directly impact the core functionality of TaskBuddy. The impact is moderate, confidence is moderate (users have requested it), and the effort is estimated to be moderate, potentially involving UI adjustments and testing across different devices.\n\n**Conclusion:**\n\nBased on the ICE scores, the development team should prioritize:\n\n1.  **Reminder Fixes**\n2.  **Bug Fixes (Task Disappearance)**\n3.  **Dark Mode Implementation**\n\nAddressing the core functionality issues (bug fixes and reminder fixes) will have the most significant positive impact on user satisfaction and the overall value of TaskBuddy. While dark mode is a desirable feature, it should be addressed after the more critical issues are resolved.\n",
#  'okr': "Objective: Improve TaskBuddy's reliability and user experience based on user feedback.\n- Key Result 1: Reduce bug reports related to task disappearance and reminder failures by 75% by end of next sprint (measured via bug tracking system).\n- Key Result 2: Implement dark mode and achieve a user satisfaction score of 4.5 out of 5 for the new feature (measured via in-app survey with a minimum of 200 responses) by the end of Q3.\n- Key Result 3: Increase average app rating on app stores from 3.8 to 4.2 stars by the end of Q3 (measured by aggregating ratings across all app stores).\n"}

# %%
# Define your agents and evaluation criteria
agents_to_evaluate = ["sentiment", "feedback", "issue", "competitor", "ideation", "prioritization", "okr"]
criteria = "Clarity, Depth, Relevance, Innovation, Coherence"

# Evaluate the flat multi-agent results
flat_scores_raw = {}

for agent in agents_to_evaluate:
    output = flat_results.get(agent, "")
    flat_scores_raw[agent] = evaluator.evaluate(output, criteria)
    time.sleep(2)  # ✅ Add this line to avoid burst quota issues
    
for agent in agents_to_evaluate:
    output = flat_results.get(agent, "")
    flat_scores_raw[agent] = evaluator.evaluate(output, criteria)

# Optional: extract numeric scores
def extract_score(text):
    match = re.search(r'(\d(?:\.\d)?)', text)
    return float(match.group(1)) if match else None

flat_numeric_scores = {agent: extract_score(score) for agent, score in flat_scores_raw.items()}

df_flat = pd.DataFrame({
    "Agent": agents_to_evaluate,
    "Score": [flat_numeric_scores[agent] for agent in agents_to_evaluate]
})
# Assuming you already have this
flat_numeric_scores = {agent: extract_score(score) for agent, score in flat_scores_raw.items()}
prompt_templates = {
    "sentiment": {"style": "One-Shot", "description": "Classifies sentiment using One-Shot prompting"},
    "feedback": {"style": "Few-Shot", "description": "Summarizes user feedback using Few-Shot prompting"},
    "issue": {"style": "CoT", "description": "Detects product blockers using Chain-of-Thought reasoning"},
    "competitor": {"style": "ReAct", "description": "Analyzes competition using ReAct prompting"},
    "ideation": {"style": "ToT", "description": "Generates features with Tree-of-Thought prompting"},
    "prioritization": {"style": "CoT + Scoring", "description": "Ranks features using ICE scoring with CoT"},
    "okr": {"style": "Few-Shot", "description": "Creates SMART OKRs using Few-Shot prompting"}
}

# Generate dataframe with smart injection
df_flat = pd.DataFrame({
    "Agent": agents_to_evaluate,
    "Agent_flat": [flat_numeric_scores[agent] for agent in agents_to_evaluate],
    "PromptStyle": [prompt_templates[agent]["style"] for agent in agents_to_evaluate],
    "Description": [prompt_templates[agent]["description"] for agent in agents_to_evaluate],
})


# Bar chart of flat agent scores
plt.figure(figsize=(10, 5))
sns.barplot(x="Agent", y="Agent_flat", data=df_flat, palette="Blues")
plt.title("Flat Multi-Agent Evaluation Scores")
plt.ylim(0, 5)
plt.grid(True)
plt.tight_layout()
plt.show()

display(df_flat)
# Out:
#             Agent  Agent_flat    PromptStyle  \
# 0       sentiment         5.0       One-Shot
# 1        feedback         3.0       Few-Shot
# 2           issue         4.0            CoT
# 3      competitor         5.0          ReAct
# 4        ideation         5.0            ToT
# 5  prioritization         5.0  CoT + Scoring
# 6             okr         4.0       Few-Shot
#
#                                                  Description
# 0              Classifies sentiment using One-Shot prompting
# 1          Summarizes user feedback using Few-Shot prompting
# 2  Detects product blockers using Chain-of-Thought reasoning
# 3                 Analyzes competition using ReAct prompting
# 4          Generates features with Tree-of-Thought prompting
# 5                  Ranks features using ICE scoring with CoT
# 6                Creates SMART OKRs using Few-Shot prompting

# %% [markdown]
# In the bar chart, we observe that the flat multi-agent setup performs consistently well across most agents, with top scores in sentiment classification, competitor analysis, ideation, and prioritization, while the feedback agent stands out as the weakest performer, suggesting potential issues with clarity or depth in summarizing user input.Now let's see how orchestrating multiple agents improve the performance

# %%
## === Step 1.6: Orchestrator ===
## This connects agents in logical order and passes relevant outputs between them.
def run_orchestrator(user_input: str, company_name="YourCompany") -> dict:
    results = {}

    # Step 1: Sentiment Agent
    sentiment = run_agent("sentiment", user_input, company_name)
    results["sentiment"] = sentiment

    # Step 2: Feedback Agent (summary)
    summary = run_agent("feedback", user_input, company_name)
    results["feedback"] = summary

    # Step 3: Issue Agent (reasoning + blockers)
    issue_analysis = run_agent("issue", summary, company_name)
    results["issue"] = issue_analysis

    # Step 4: Competitor Agent (optional broader market insight)
    competitor_insight = run_agent("competitor", user_input, company_name)
    results["competitor"] = competitor_insight

    # Step 5: Ideation Agent (from issue context)
    ideas = run_agent("ideation", issue_analysis, company_name)
    results["ideation"] = ideas

    # Step 6: Prioritization Agent (on proposed features)
    prioritization = run_agent("prioritization", ideas, company_name)
    results["prioritization"] = prioritization

    # Step 7: OKR Agent (structured planning)
    okr_plan = run_agent("okr", ideas, company_name)
    results["okr"] = okr_plan

    return results

# %% [markdown]
# I started with the easies series connection like chain to first see how it works then we can give more inputs to specific agents
# ![AI Agent Train](/kaggle/input/multi-agent-chain-architecture-image/multi agent chain architecture.png)

# %%
display(Image(filename="/kaggle/input/multi-agent-chain-architecture-image/multi agent chain architecture.png"))

# %%
# test the multi-agent orchestrator
user_input = """
I love the idea of TaskBuddy, but lately it’s been really buggy. 
Sometimes tasks disappear when I mark them as done, and reminders never come on time. 
Also, why is there still no dark mode? Feels like you’re not listening to users.
"""
company_name = "TaskBuddy"

# %% [markdown]
# We can see how grounding and archestrating agent can change the chaotic responses, guardrail responses and direct them with a logic. So let's self

# %%
# ✅ Load multi-agent results from working directory
try:
    with open("/kaggle/input/nextive-multiagent-output/nextive_multiagent_output.json", "r", encoding="utf-8") as f:
        multi_results = json.load(f)
    
    print("✅ Multi-agent results loaded successfully!\n")
    
    # Pretty print the results (only 'results' section if that's what you need)
    from pprint import pprint
    pprint(multi_results.get("results", multi_results))  # fallback to whole dict if no 'results'

except FileNotFoundError:
    print("❌ File not found: Make sure you've saved the multi-agent output first.")
except json.JSONDecodeError:
    print("❌ JSON decoding failed: File might be corrupted or empty.")
# Out:
# ✅ Multi-agent results loaded successfully!
#
# {'competitor': 'Okay, I need more information to provide a meaningful '
#                'competitive positioning summary.  I need to know **what '
#                'company or product you want me to analyze!**\n'
#                '\n'
#                '**Please provide me with the following information:**\n'
#                '\n'
#                '*   **The Company/Product:**  Who are we talking about?  '
#                '(e.g., "Tesla", "Coca-Cola", "a new AI-powered marketing '
#                'tool", "a local bakery")\n'
#                '*   **The Industry:**  What industry are they in? (e.g., '
#                '"Automotive", "Beverage", "SaaS Marketing", "Food Service")\n'
#                '*   **Key Competitors:**  Who are their main rivals? (e.g., '
#                '"Ford, GM, Toyota", "Pepsi", "HubSpot, Marketo", "Other local '
#                'bakeries, grocery store bakeries")\n'
#                '*   **Target Market:** Who are they selling to? (e.g., '
#                '"Environmentally conscious consumers", "Mass market", "Small '
#                'to medium-sized businesses", "Local residents")\n'
#                '\n'
#                '**Once you give me that information, I can provide a summary '
#                'like this:**\n'
#                '\n'
#                '**Example (Hypothetical "Acme Coffee Shop" - *This is just an '
#                'example, I need YOUR company details*):**\n'
#                '\n'
#                '**Company:** Acme Coffee Shop\n'
#                '**Industry:** Food Service - Coffee Shops\n'
#                "**Key Competitors:** Starbucks, Dunkin', Local independent "
#                'coffee shops\n'
#                '**Target Market:** Local residents, students, professionals '
#                'seeking a high-quality coffee experience and a comfortable '
#                'atmosphere.\n'
#                '\n'
#                '**Competitive Positioning Summary:**\n'
#                '\n'
#                'Acme Coffee Shop aims to be the premium, locally-focused '
#                "alternative to large chains like Starbucks and Dunkin'. They "
#                'position themselves as offering higher quality coffee beans, '
#                'ethically sourced ingredients, and a more personalized '
#                'customer experience than their larger competitors, while '
#                'maintaining competitive pricing with other independent shops.\n'
#                '\n'
#                '**Strengths & Differentiators:**\n'
#                '\n'
#                '*   **High-Quality Coffee:** Focus on sourcing premium, '
#                'ethically sourced beans and expert baristas.\n'
#                '*   **Local Focus:** Emphasis on community engagement, local '
#                'partnerships, and a welcoming atmosphere.\n'
#                '*   **Personalized Service:** Baristas trained to remember '
#                'customer preferences and offer tailored recommendations.\n'
#                '*   **Unique Menu Items:** Offering specialty drinks and '
#                'locally sourced pastries not found at chains.\n'
#                '\n'
#                '**Weaknesses or Gaps:**\n'
#                '\n'
#                '*   **Limited Brand Awareness:** Compared to established '
#                'chains.\n'
#                '*   **Smaller Scale:** Less marketing budget and fewer '
#                'locations.\n'
#                '*   **Potential Price Sensitivity:**  Higher quality '
#                'ingredients may translate to slightly higher prices.\n'
#                '*   **Operational Complexity:** Managing a smaller supply '
#                'chain and ensuring consistent quality.\n'
#                '\n'
#                '**Strategy Type:** Differentiation Strategy\n'
#                '\n'
#                "**Commentary using Porter's Five Forces:**\n"
#                '\n'
#                '*   **Threat of New Entrants:** Relatively high.  The coffee '
#                'shop industry has low barriers to entry, although building a '
#                'strong brand and loyal customer base is challenging.\n'
#                '*   **Bargaining Power of Buyers:** Moderate. Customers have '
#                "many choices, but Acme's focus on quality and service can "
#                'reduce price sensitivity.\n'
#                '*   **Bargaining Power of Suppliers:** Low to Moderate. '
#                'Sourcing high-quality, ethically sourced beans can increase '
#                'supplier power, but Acme can diversify suppliers to mitigate '
#                'this risk.\n'
#                '*   **Threat of Substitutes:** High. Consumers can choose tea, '
#                'energy drinks, or simply make coffee at home.\n'
#                '*   **Industry Rivalry:** High.  The coffee shop market is '
#                'competitive, with numerous national chains, local '
#                'independents, and even restaurants offering coffee.\n'
#                '\n'
#                '**Now, give me the details of the company *you* want me to '
#                "analyze, and I'll create a similar summary tailored to "
#                'them!**\n',
#  'feedback': '"Buggy behavior affecting task completion and reminders, along '
#              'with unfulfilled dark mode requests, indicate a need for '
#              'improved responsiveness to user feedback."\n',
#  'ideation': 'Okay, based on the provided context and thought process, here '
#              'are three feature ideas, their scores, and a final selection:\n'
#              '\n'
#              '### Option A:\n'
#              '**Feature Title:** Bug Squashing Bonanza: Task Completion & '
#              'Reminder Fixes\n'
#              '**Description:** A dedicated sprint focused entirely on '
#              'identifying, reproducing, and resolving bugs related to task '
#              'completion (saving, loading, editing) and reminder functionality '
#              '(scheduling, notifications). This includes increased testing and '
#              'code reviews in these areas.\n'
#              '\n'
#              '### Option B:\n'
#              '**Feature Title:** Dark Mode Dawn\n'
#              '**Description:** Implement a fully functional dark mode option '
#              'for the app, addressing a long-standing user request. This will '
#              'involve creating a new theme and ensuring all UI elements are '
#              'compatible and visually appealing in dark mode.\n'
#              '\n'
#              '### Option C:\n'
#              '**Feature Title:** The Feedback Fortress: User Voice '
#              'Integration\n'
#              '**Description:** Implement a dedicated in-app feedback system '
#              '(e.g., using a third-party SDK or building a custom solution) to '
#              'collect user suggestions, bug reports, and feature requests. '
#              'This also involves establishing a clear process for reviewing, '
#              'prioritizing, and responding to user feedback, including a '
#              'public roadmap.\n'
#              '\n'
#              '### Score Each Option:\n'
#              '\n'
#              '**Option A: Bug Squashing Bonanza**\n'
#              '*   Originality (1–10): 4 (Standard bug fix sprint)\n'
#              '*   Feasibility (1–10): 9 (Relatively straightforward, requires '
#              'dedicated resources)\n'
#              '*   Impact (1–10): 10 (Addresses critical blockers, directly '
#              'improves usability)\n'
#              '\n'
#              '**Option B: Dark Mode Dawn**\n'
#              '*   Originality (1–10): 3 (Common feature request)\n'
#              '*   Feasibility (1–10): 7 (Depends on UI framework; can be '
#              'complex for large apps)\n'
#              "*   Impact (1–10): 6 (Improves user experience, but doesn't "
#              'address critical bugs)\n'
#              '\n'
#              '**Option C: The Feedback Fortress**\n'
#              '*   Originality (1–10): 6 (Integrates feedback collection and '
#              'response)\n'
#              '*   Feasibility (1–10): 8 (Can leverage existing SDKs, but '
#              'requires process changes)\n'
#              '*   Impact (1–10): 8 (Improves user satisfaction, builds trust, '
#              'informs future development)\n'
#              '\n'
#              '### Final Picks & Why:\n'
#              '\n'
#              '**Primary Pick: Option A: Bug Squashing Bonanza**\n'
#              '\n'
#              '**Justification:** While all three options have merit, '
#              'addressing the critical bugs affecting task completion and '
#              'reminders is paramount. These bugs are severe blockers that '
#              'prevent users from effectively using the app. Fixing these '
#              'issues should be the top priority to ensure a stable and '
#              'reliable user experience. While the other options are valuable, '
#              'they are secondary to resolving these fundamental problems. '
#              'After the bugs are fixed, implementing the feedback system from '
#              'option C would be the next logical step.\n',
#  'issue': '### Thought Process:\n'
#           '1.  **Key Pain Points:**\n'
#           '    *   "Buggy behavior affecting task completion": Users are '
#           'experiencing bugs that directly prevent them from using the core '
#           'functionality (task completion).\n'
#           '    *   "Buggy behavior affecting reminders": Reminders, a key '
#           'feature for a task management app, are not working reliably.\n'
#           '    *   "Unfulfilled dark mode requests": Users have requested a '
#           "dark mode feature, and it hasn't been implemented.\n"
#           '    *   "Need for improved responsiveness to user feedback": Users '
#           "feel their feedback isn't being heard or acted upon.\n"
#           '\n'
#           '2.  **Mapping to Problems:**\n'
#           '    *   "Buggy behavior affecting task completion": Could be due to '
#           'code errors in task saving/loading, incorrect state management, or '
#           'database issues.\n'
#           '    *   "Buggy behavior affecting reminders": Likely problems with '
#           'the scheduling or notification system, permission issues, or OS '
#           'compatibility problems.\n'
#           '    *   "Unfulfilled dark mode requests": A feature gap, possibly '
#           'due to prioritization of other features, technical difficulties in '
#           'implementation, or lack of resources.\n'
#           '    *   "Need for improved responsiveness to user feedback": Could '
#           'stem from a lack of a formal feedback process, insufficient '
#           'resources for addressing feedback, or poor communication with '
#           'users.\n'
#           '\n'
#           '3.  **Blocker Determination:**\n'
#           '    *   Task completion bugs are a **severe blocker** because they '
#           "prevent users from using the app's primary function.\n"
#           '    *   Reminder bugs are a **severe blocker** as they undermine a '
#           'core feature.\n'
#           '    *   Lack of dark mode is a **minor blocker** or annoyance, but '
#           'the unresponsiveness to feedback amplifies the issue.\n'
#           '    *   Unresponsiveness to feedback is a **moderate blocker** as '
#           'it erodes user trust and satisfaction.\n'
#           '\n'
#           '### Final Issue (summary in one sentence):\n'
#           'The app suffers from critical bugs affecting task completion and '
#           'reminders, coupled with a lack of responsiveness to user feature '
#           'requests, particularly regarding dark mode.\n'
#           '\n'
#           '### Optional Root Cause Hypothesis:\n'
#           'Insufficient testing and quality assurance processes, combined with '
#           "a product roadmap that doesn't adequately prioritize bug fixes and "
#           'user-requested features.\n'
#           '\n'
#           '### Suggested Categories (e.g., Bug, UX Flaw, Performance, Feature '
#           'Gap):\n'
#           '*   Bug\n'
#           '*   Feature Gap\n'
#           '*   Responsiveness/Communication\n'
#           '\n'
#           '### Optional: Brainstorm Potential Solutions (bullet list)\n'
#           '*   Implement a more robust testing process (unit, integration, '
#           'user acceptance testing).\n'
#           '*   Prioritize bug fixes and performance improvements in upcoming '
#           'sprints.\n'
#           '*   Investigate and resolve the reminder scheduling/notification '
#           'issues.\n'
#           '*   Re-evaluate the dark mode feature request and assess its '
#           'feasibility and priority.\n'
#           '*   Establish a clear feedback loop with users, acknowledging their '
#           'input and providing updates on progress.\n'
#           '*   Consider a public-facing roadmap to manage user expectations.\n',
#  'okr': 'Okay, here\'s a SMART OKR based on the "Bug Squashing Bonanza" '
#         'feature, aiming for a specific, measurable, achievable, relevant, and '
#         'time-bound goal:\n'
#         '\n'
#         'Objective: Stabilize core task and reminder functionality for '
#         'improved user experience.\n'
#         '- Key Result 1: Reduce task completion error reports by 75% by end of '
#         'Q3 (baseline: average of last 3 months).\n'
#         '- Key Result 2: Decrease reminder notification failure rate to below '
#         '1% by end of Q3 (baseline: current 5%).\n'
#         '- Key Result 3: Achieve a 4.5-star average rating for task management '
#         'features in app store reviews by end of Q3 (currently 4.0 stars).\n',
#  'prioritization': "Okay, here's the ICE score evaluation for each feature, "
#                    'followed by the sorted table and the rationale:\n'
#                    '\n'
#                    '**ICE Score Calculation and Table**\n'
#                    '\n'
#                    'First, we need to translate the "Originality," '
#                    '"Feasibility," and "Impact" scores into the ICE '
#                    'framework\'s "Impact," "Confidence," and "Effort" '
#                    "categories, respectively.  We'll assume:\n"
#                    '\n'
#                    '*   **Impact:** Directly uses the given "Impact" score.\n'
#                    '*   **Confidence:** Uses the given "Feasibility" score.  '
#                    'The more feasible, the more confident we are in the '
#                    'estimate.\n'
#                    '*   **Effort:** Uses the given "Originality" score. The '
#                    'more original, the more effort it takes.\n'
#                    '\n'
#                    'Using these assumptions, we can create the ICE scores:\n'
#                    '\n'
#                    '**Option A: Bug Squashing Bonanza**\n'
#                    '\n'
#                    '*   Impact: 10\n'
#                    '*   Confidence: 9\n'
#                    '*   Effort: 4\n'
#                    '*   ICE Score: (10 * 9) / 4 = 22.5\n'
#                    '\n'
#                    '**Option B: Dark Mode Dawn**\n'
#                    '\n'
#                    '*   Impact: 6\n'
#                    '*   Confidence: 7\n'
#                    '*   Effort: 3\n'
#                    '*   ICE Score: (6 * 7) / 3 = 14.0\n'
#                    '\n'
#                    '**Option C: The Feedback Fortress**\n'
#                    '\n'
#                    '*   Impact: 8\n'
#                    '*   Confidence: 8\n'
#                    '*   Effort: 6\n'
#                    '*   ICE Score: (8 * 8) / 6 = 10.67\n'
#                    '\n'
#                    '**Sorted Table:**\n'
#                    '\n'
#                    '| Feature | Impact | Confidence | Effort | ICE Score |\n'
#                    '|---------|--------|------------|--------|------------|\n'
#                    '| Bug Squashing Bonanza | 10 | 9 | 4 | 22.5 |\n'
#                    '| Dark Mode Dawn | 6 | 7 | 3 | 14.0 |\n'
#                    '| The Feedback Fortress | 8 | 8 | 6 | 10.67 |\n'
#                    '\n'
#                    '**Decision-Making Rationale:**\n'
#                    '\n'
#                    'The ICE scoring model confirms the initial assessment. '
#                    '"Bug Squashing Bonanza" has the highest ICE score by a '
#                    'significant margin. This is primarily due to its high '
#                    'impact (addressing critical bugs) and relatively low '
#                    'effort (a dedicated sprint). While "Dark Mode Dawn" is a '
#                    "desirable feature and has a decent ICE score, it doesn't "
#                    'address the fundamental usability issues that the bug '
#                    'fixes will resolve. "The Feedback Fortress" has the lowest '
#                    "ICE score, indicating that while valuable, it's less "
#                    'impactful and requires more effort compared to the other '
#                    'two options.\n'
#                    '\n'
#                    'Therefore, the recommended prioritization remains:\n'
#                    '\n'
#                    '1.  **Bug Squashing Bonanza:** Fix the critical bugs '
#                    'affecting task completion and reminders.\n'
#                    '2.  **Dark Mode Dawn:** Implement the dark mode feature to '
#                    'improve user experience.\n'
#                    '3.  **The Feedback Fortress:** Implement the in-app '
#                    'feedback system to gather user insights and improve the '
#                    'product roadmap.\n',
#  'sentiment': "Here's the breakdown of the emotional tone:\n"
#               '\n'
#               '*   **Sentiment:** Predominantly **Negative**, but with a hint '
#               'of **Mixed**.\n'
#               '\n'
#               '**Explanation:**\n'
#               '\n'
#               '*   **Negative:** The feedback highlights several problems: '
#               'bugs causing data loss (disappearing tasks), unreliable '
#               'reminders, and a missing feature (dark mode) that the user '
#               'clearly desires. The phrase "Feels like you\'re not listening '
#               'to users" is a direct expression of frustration and '
#               'dissatisfaction.\n'
#               '*   **Mixed:** The opening phrase "I love the idea of '
#               'TaskBuddy" indicates an initial positive sentiment. This '
#               'suggests the user is invested in the product and wants it to '
#               'succeed, but is currently disappointed with its performance.'}

# %%
multiagent_export = {
    "metadata": {
        "strategy": "multi-agent",
        "type": "sequential",
        "company": company_name,
        "input": user_input.strip(),
        "description": "A sequential multi-agent architecture where each agent builds upon the output of the previous one. "
                       "Agents include: sentiment → feedback → issue → competitor → ideation → prioritization → OKR.",
        "timestamp": datetime.now().isoformat()
    },
    "results": multi_results  # orchestrator output
}

# %%
multi_results
# Out:
# {'metadata': {'strategy': 'multi-agent',
#   'type': 'sequential',
#   'company': 'TaskBuddy',
#   'input': 'I love the idea of TaskBuddy, but lately it’s been really buggy. \nSometimes tasks disappear when I mark them as done, and reminders never come on time. \nAlso, why is there still no dark mode? Feels like you’re not listening to users.',
#   'description': 'A sequential multi-agent architecture where each agent builds upon the output of the previous one. Agents include: sentiment → feedback → issue → competitor → ideation → prioritization → OKR.',
#   'timestamp': '2025-04-21T01:53:49.374351'},
#  'results': {'sentiment': 'Here\'s the breakdown of the emotional tone:\n\n*   **Sentiment:** Predominantly **Negative**, but with a hint of **Mixed**.\n\n**Explanation:**\n\n*   **Negative:** The feedback highlights several problems: bugs causing data loss (disappearing tasks), unreliable reminders, and a missing feature (dark mode) that the user clearly desires. The phrase "Feels like you\'re not listening to users" is a direct expression of frustration and dissatisfaction.\n*   **Mixed:** The opening phrase "I love the idea of TaskBuddy" indicates an initial positive sentiment. This suggests the user is invested in the product and wants it to succeed, but is currently disappointed with its performance.',
#   'feedback': '"Buggy behavior affecting task completion and reminders, along with unfulfilled dark mode requests, indicate a need for improved responsiveness to user feedback."\n',
#   'issue': '### Thought Process:\n1.  **Key Pain Points:**\n    *   "Buggy behavior affecting task completion": Users are experiencing bugs that directly prevent them from using the core functionality (task completion).\n    *   "Buggy behavior affecting reminders": Reminders, a key feature for a task management app, are not working reliably.\n    *   "Unfulfilled dark mode requests": Users have requested a dark mode feature, and it hasn\'t been implemented.\n    *   "Need for improved responsiveness to user feedback": Users feel their feedback isn\'t being heard or acted upon.\n\n2.  **Mapping to Problems:**\n    *   "Buggy behavior affecting task completion": Could be due to code errors in task saving/loading, incorrect state management, or database issues.\n    *   "Buggy behavior affecting reminders": Likely problems with the scheduling or notification system, permission issues, or OS compatibility problems.\n    *   "Unfulfilled dark mode requests": A feature gap, possibly due to prioritization of other features, technical difficulties in implementation, or lack of resources.\n    *   "Need for improved responsiveness to user feedback": Could stem from a lack of a formal feedback process, insufficient resources for addressing feedback, or poor communication with users.\n\n3.  **Blocker Determination:**\n    *   Task completion bugs are a **severe blocker** because they prevent users from using the app\'s primary function.\n    *   Reminder bugs are a **severe blocker** as they undermine a core feature.\n    *   Lack of dark mode is a **minor blocker** or annoyance, but the unresponsiveness to feedback amplifies the issue.\n    *   Unresponsiveness to feedback is a **moderate blocker** as it erodes user trust and satisfaction.\n\n### Final Issue (summary in one sentence):\nThe app suffers from critical bugs affecting task completion and reminders, coupled with a lack of responsiveness to user feature requests, particularly regarding dark mode.\n\n### Optional Root Cause Hypothesis:\nInsufficient testing and quality assurance processes, combined with a product roadmap that doesn\'t adequately prioritize bug fixes and user-requested features.\n\n### Suggested Categories (e.g., Bug, UX Flaw, Performance, Feature Gap):\n*   Bug\n*   Feature Gap\n*   Responsiveness/Communication\n\n### Optional: Brainstorm Potential Solutions (bullet list)\n*   Implement a more robust testing process (unit, integration, user acceptance testing).\n*   Prioritize bug fixes and performance improvements in upcoming sprints.\n*   Investigate and resolve the reminder scheduling/notification issues.\n*   Re-evaluate the dark mode feature request and assess its feasibility and priority.\n*   Establish a clear feedback loop with users, acknowledging their input and providing updates on progress.\n*   Consider a public-facing roadmap to manage user expectations.\n',
#   'competitor': 'Okay, I need more information to provide a meaningful competitive positioning summary.  I need to know **what company or product you want me to analyze!**\n\n**Please provide me with the following information:**\n\n*   **The Company/Product:**  Who are we talking about?  (e.g., "Tesla", "Coca-Cola", "a new AI-powered marketing tool", "a local bakery")\n*   **The Industry:**  What industry are they in? (e.g., "Automotive", "Beverage", "SaaS Marketing", "Food Service")\n*   **Key Competitors:**  Who are their main rivals? (e.g., "Ford, GM, Toyota", "Pepsi", "HubSpot, Marketo", "Other local bakeries, grocery store bakeries")\n*   **Target Market:** Who are they selling to? (e.g., "Environmentally conscious consumers", "Mass market", "Small to medium-sized businesses", "Local residents")\n\n**Once you give me that information, I can provide a summary like this:**\n\n**Example (Hypothetical "Acme Coffee Shop" - *This is just an example, I need YOUR company details*):**\n\n**Company:** Acme Coffee Shop\n**Industry:** Food Service - Coffee Shops\n**Key Competitors:** Starbucks, Dunkin\', Local independent coffee shops\n**Target Market:** Local residents, students, professionals seeking a high-quality coffee experience and a comfortable atmosphere.\n\n**Competitive Positioning Summary:**\n\nAcme Coffee Shop aims to be the premium, locally-focused alternative to large chains like Starbucks and Dunkin\'. They position themselves as offering higher quality coffee beans, ethically sourced ingredients, and a more personalized customer experience than their larger competitors, while maintaining competitive pricing with other independent shops.\n\n**Strengths & Differentiators:**\n\n*   **High-Quality Coffee:** Focus on sourcing premium, ethically sourced beans and expert baristas.\n*   **Local Focus:** Emphasis on community engagement, local partnerships, and a welcoming atmosphere.\n*   **Personalized Service:** Baristas trained to remember customer preferences and offer tailored recommendations.\n*   **Unique Menu Items:** Offering specialty drinks and locally sourced pastries not found at chains.\n\n**Weaknesses or Gaps:**\n\n*   **Limited Brand Awareness:** Compared to established chains.\n*   **Smaller Scale:** Less marketing budget and fewer locations.\n*   **Potential Price Sensitivity:**  Higher quality ingredients may translate to slightly higher prices.\n*   **Operational Complexity:** Managing a smaller supply chain and ensuring consistent quality.\n\n**Strategy Type:** Differentiation Strategy\n\n**Commentary using Porter\'s Five Forces:**\n\n*   **Threat of New Entrants:** Relatively high.  The coffee shop industry has low barriers to entry, although building a strong brand and loyal customer base is challenging.\n*   **Bargaining Power of Buyers:** Moderate. Customers have many choices, but Acme\'s focus on quality and service can reduce price sensitivity.\n*   **Bargaining Power of Suppliers:** Low to Moderate. Sourcing high-quality, ethically sourced beans can increase supplier power, but Acme can diversify suppliers to mitigate this risk.\n*   **Threat of Substitutes:** High. Consumers can choose tea, energy drinks, or simply make coffee at home.\n*   **Industry Rivalry:** High.  The coffee shop market is competitive, with numerous national chains, local independents, and even restaurants offering coffee.\n\n**Now, give me the details of the company *you* want me to analyze, and I\'ll create a similar summary tailored to them!**\n',
#   'ideation': "Okay, based on the provided context and thought process, here are three feature ideas, their scores, and a final selection:\n\n### Option A:\n**Feature Title:** Bug Squashing Bonanza: Task Completion & Reminder Fixes\n**Description:** A dedicated sprint focused entirely on identifying, reproducing, and resolving bugs related to task completion (saving, loading, editing) and reminder functionality (scheduling, notifications). This includes increased testing and code reviews in these areas.\n\n### Option B:\n**Feature Title:** Dark Mode Dawn\n**Description:** Implement a fully functional dark mode option for the app, addressing a long-standing user request. This will involve creating a new theme and ensuring all UI elements are compatible and visually appealing in dark mode.\n\n### Option C:\n**Feature Title:** The Feedback Fortress: User Voice Integration\n**Description:** Implement a dedicated in-app feedback system (e.g., using a third-party SDK or building a custom solution) to collect user suggestions, bug reports, and feature requests. This also involves establishing a clear process for reviewing, prioritizing, and responding to user feedback, including a public roadmap.\n\n### Score Each Option:\n\n**Option A: Bug Squashing Bonanza**\n*   Originality (1–10): 4 (Standard bug fix sprint)\n*   Feasibility (1–10): 9 (Relatively straightforward, requires dedicated resources)\n*   Impact (1–10): 10 (Addresses critical blockers, directly improves usability)\n\n**Option B: Dark Mode Dawn**\n*   Originality (1–10): 3 (Common feature request)\n*   Feasibility (1–10): 7 (Depends on UI framework; can be complex for large apps)\n*   Impact (1–10): 6 (Improves user experience, but doesn't address critical bugs)\n\n**Option C: The Feedback Fortress**\n*   Originality (1–10): 6 (Integrates feedback collection and response)\n*   Feasibility (1–10): 8 (Can leverage existing SDKs, but requires process changes)\n*   Impact (1–10): 8 (Improves user satisfaction, builds trust, informs future development)\n\n### Final Picks & Why:\n\n**Primary Pick: Option A: Bug Squashing Bonanza**\n\n**Justification:** While all three options have merit, addressing the critical bugs affecting task completion and reminders is paramount. These bugs are severe blockers that prevent users from effectively using the app. Fixing these issues should be the top priority to ensure a stable and reliable user experience. While the other options are valuable, they are secondary to resolving these fundamental problems. After the bugs are fixed, implementing the feedback system from option C would be the next logical step.\n",
#   'prioritization': 'Okay, here\'s the ICE score evaluation for each feature, followed by the sorted table and the rationale:\n\n**ICE Score Calculation and Table**\n\nFirst, we need to translate the "Originality," "Feasibility," and "Impact" scores into the ICE framework\'s "Impact," "Confidence," and "Effort" categories, respectively.  We\'ll assume:\n\n*   **Impact:** Directly uses the given "Impact" score.\n*   **Confidence:** Uses the given "Feasibility" score.  The more feasible, the more confident we are in the estimate.\n*   **Effort:** Uses the given "Originality" score. The more original, the more effort it takes.\n\nUsing these assumptions, we can create the ICE scores:\n\n**Option A: Bug Squashing Bonanza**\n\n*   Impact: 10\n*   Confidence: 9\n*   Effort: 4\n*   ICE Score: (10 * 9) / 4 = 22.5\n\n**Option B: Dark Mode Dawn**\n\n*   Impact: 6\n*   Confidence: 7\n*   Effort: 3\n*   ICE Score: (6 * 7) / 3 = 14.0\n\n**Option C: The Feedback Fortress**\n\n*   Impact: 8\n*   Confidence: 8\n*   Effort: 6\n*   ICE Score: (8 * 8) / 6 = 10.67\n\n**Sorted Table:**\n\n| Feature | Impact | Confidence | Effort | ICE Score |\n|---------|--------|------------|--------|------------|\n| Bug Squashing Bonanza | 10 | 9 | 4 | 22.5 |\n| Dark Mode Dawn | 6 | 7 | 3 | 14.0 |\n| The Feedback Fortress | 8 | 8 | 6 | 10.67 |\n\n**Decision-Making Rationale:**\n\nThe ICE scoring model confirms the initial assessment. "Bug Squashing Bonanza" has the highest ICE score by a significant margin. This is primarily due to its high impact (addressing critical bugs) and relatively low effort (a dedicated sprint). While "Dark Mode Dawn" is a desirable feature and has a decent ICE score, it doesn\'t address the fundamental usability issues that the bug fixes will resolve. "The Feedback Fortress" has the lowest ICE score, indicating that while valuable, it\'s less impactful and requires more effort compared to the other two options.\n\nTherefore, the recommended prioritization remains:\n\n1.  **Bug Squashing Bonanza:** Fix the critical bugs affecting task completion and reminders.\n2.  **Dark Mode Dawn:** Implement the dark mode feature to improve user experience.\n3.  **The Feedback Fortress:** Implement the in-app feedback system to gather user insights and improve the product roadmap.\n',
#   'okr': 'Okay, here\'s a SMART OKR based on the "Bug Squashing Bonanza" feature, aiming for a specific, measurable, achievable, relevant, and time-bound goal:\n\nObjective: Stabilize core task and reminder functionality for improved user experience.\n- Key Result 1: Reduce task completion error reports by 75% by end of Q3 (baseline: average of last 3 months).\n- Key Result 2: Decrease reminder notification failure rate to below 1% by end of Q3 (baseline: current 5%).\n- Key Result 3: Achieve a 4.5-star average rating for task management features in app store reviews by end of Q3 (currently 4.0 stars).\n'}}

# %% [markdown]
# Let's evaluate the orchestrated multi-agents

# %%
# 🔁 REDEFINE THIS if not already defined
evaluator = BaseAgent(name="SequentialEvaluator", prompt_style="Few-Shot", temperature=0.3)

# %%
# ✅ Step 1: Parse your full sequential_results string
def parse_sequential_sections(text):
    pattern = r"🔮?\s*(\w+)\s+Agent Output\s*\n(.*?)(?=\n🔮|\Z)"
    matches = re.findall(pattern, text, re.DOTALL)
    return {m[0].strip().lower(): m[1].strip() for m in matches}

# %%
multi_results= multi_results["results"]
multi_results
# Out:
# {'sentiment': 'Here\'s the breakdown of the emotional tone:\n\n*   **Sentiment:** Predominantly **Negative**, but with a hint of **Mixed**.\n\n**Explanation:**\n\n*   **Negative:** The feedback highlights several problems: bugs causing data loss (disappearing tasks), unreliable reminders, and a missing feature (dark mode) that the user clearly desires. The phrase "Feels like you\'re not listening to users" is a direct expression of frustration and dissatisfaction.\n*   **Mixed:** The opening phrase "I love the idea of TaskBuddy" indicates an initial positive sentiment. This suggests the user is invested in the product and wants it to succeed, but is currently disappointed with its performance.',
#  'feedback': '"Buggy behavior affecting task completion and reminders, along with unfulfilled dark mode requests, indicate a need for improved responsiveness to user feedback."\n',
#  'issue': '### Thought Process:\n1.  **Key Pain Points:**\n    *   "Buggy behavior affecting task completion": Users are experiencing bugs that directly prevent them from using the core functionality (task completion).\n    *   "Buggy behavior affecting reminders": Reminders, a key feature for a task management app, are not working reliably.\n    *   "Unfulfilled dark mode requests": Users have requested a dark mode feature, and it hasn\'t been implemented.\n    *   "Need for improved responsiveness to user feedback": Users feel their feedback isn\'t being heard or acted upon.\n\n2.  **Mapping to Problems:**\n    *   "Buggy behavior affecting task completion": Could be due to code errors in task saving/loading, incorrect state management, or database issues.\n    *   "Buggy behavior affecting reminders": Likely problems with the scheduling or notification system, permission issues, or OS compatibility problems.\n    *   "Unfulfilled dark mode requests": A feature gap, possibly due to prioritization of other features, technical difficulties in implementation, or lack of resources.\n    *   "Need for improved responsiveness to user feedback": Could stem from a lack of a formal feedback process, insufficient resources for addressing feedback, or poor communication with users.\n\n3.  **Blocker Determination:**\n    *   Task completion bugs are a **severe blocker** because they prevent users from using the app\'s primary function.\n    *   Reminder bugs are a **severe blocker** as they undermine a core feature.\n    *   Lack of dark mode is a **minor blocker** or annoyance, but the unresponsiveness to feedback amplifies the issue.\n    *   Unresponsiveness to feedback is a **moderate blocker** as it erodes user trust and satisfaction.\n\n### Final Issue (summary in one sentence):\nThe app suffers from critical bugs affecting task completion and reminders, coupled with a lack of responsiveness to user feature requests, particularly regarding dark mode.\n\n### Optional Root Cause Hypothesis:\nInsufficient testing and quality assurance processes, combined with a product roadmap that doesn\'t adequately prioritize bug fixes and user-requested features.\n\n### Suggested Categories (e.g., Bug, UX Flaw, Performance, Feature Gap):\n*   Bug\n*   Feature Gap\n*   Responsiveness/Communication\n\n### Optional: Brainstorm Potential Solutions (bullet list)\n*   Implement a more robust testing process (unit, integration, user acceptance testing).\n*   Prioritize bug fixes and performance improvements in upcoming sprints.\n*   Investigate and resolve the reminder scheduling/notification issues.\n*   Re-evaluate the dark mode feature request and assess its feasibility and priority.\n*   Establish a clear feedback loop with users, acknowledging their input and providing updates on progress.\n*   Consider a public-facing roadmap to manage user expectations.\n',
#  'competitor': 'Okay, I need more information to provide a meaningful competitive positioning summary.  I need to know **what company or product you want me to analyze!**\n\n**Please provide me with the following information:**\n\n*   **The Company/Product:**  Who are we talking about?  (e.g., "Tesla", "Coca-Cola", "a new AI-powered marketing tool", "a local bakery")\n*   **The Industry:**  What industry are they in? (e.g., "Automotive", "Beverage", "SaaS Marketing", "Food Service")\n*   **Key Competitors:**  Who are their main rivals? (e.g., "Ford, GM, Toyota", "Pepsi", "HubSpot, Marketo", "Other local bakeries, grocery store bakeries")\n*   **Target Market:** Who are they selling to? (e.g., "Environmentally conscious consumers", "Mass market", "Small to medium-sized businesses", "Local residents")\n\n**Once you give me that information, I can provide a summary like this:**\n\n**Example (Hypothetical "Acme Coffee Shop" - *This is just an example, I need YOUR company details*):**\n\n**Company:** Acme Coffee Shop\n**Industry:** Food Service - Coffee Shops\n**Key Competitors:** Starbucks, Dunkin\', Local independent coffee shops\n**Target Market:** Local residents, students, professionals seeking a high-quality coffee experience and a comfortable atmosphere.\n\n**Competitive Positioning Summary:**\n\nAcme Coffee Shop aims to be the premium, locally-focused alternative to large chains like Starbucks and Dunkin\'. They position themselves as offering higher quality coffee beans, ethically sourced ingredients, and a more personalized customer experience than their larger competitors, while maintaining competitive pricing with other independent shops.\n\n**Strengths & Differentiators:**\n\n*   **High-Quality Coffee:** Focus on sourcing premium, ethically sourced beans and expert baristas.\n*   **Local Focus:** Emphasis on community engagement, local partnerships, and a welcoming atmosphere.\n*   **Personalized Service:** Baristas trained to remember customer preferences and offer tailored recommendations.\n*   **Unique Menu Items:** Offering specialty drinks and locally sourced pastries not found at chains.\n\n**Weaknesses or Gaps:**\n\n*   **Limited Brand Awareness:** Compared to established chains.\n*   **Smaller Scale:** Less marketing budget and fewer locations.\n*   **Potential Price Sensitivity:**  Higher quality ingredients may translate to slightly higher prices.\n*   **Operational Complexity:** Managing a smaller supply chain and ensuring consistent quality.\n\n**Strategy Type:** Differentiation Strategy\n\n**Commentary using Porter\'s Five Forces:**\n\n*   **Threat of New Entrants:** Relatively high.  The coffee shop industry has low barriers to entry, although building a strong brand and loyal customer base is challenging.\n*   **Bargaining Power of Buyers:** Moderate. Customers have many choices, but Acme\'s focus on quality and service can reduce price sensitivity.\n*   **Bargaining Power of Suppliers:** Low to Moderate. Sourcing high-quality, ethically sourced beans can increase supplier power, but Acme can diversify suppliers to mitigate this risk.\n*   **Threat of Substitutes:** High. Consumers can choose tea, energy drinks, or simply make coffee at home.\n*   **Industry Rivalry:** High.  The coffee shop market is competitive, with numerous national chains, local independents, and even restaurants offering coffee.\n\n**Now, give me the details of the company *you* want me to analyze, and I\'ll create a similar summary tailored to them!**\n',
#  'ideation': "Okay, based on the provided context and thought process, here are three feature ideas, their scores, and a final selection:\n\n### Option A:\n**Feature Title:** Bug Squashing Bonanza: Task Completion & Reminder Fixes\n**Description:** A dedicated sprint focused entirely on identifying, reproducing, and resolving bugs related to task completion (saving, loading, editing) and reminder functionality (scheduling, notifications). This includes increased testing and code reviews in these areas.\n\n### Option B:\n**Feature Title:** Dark Mode Dawn\n**Description:** Implement a fully functional dark mode option for the app, addressing a long-standing user request. This will involve creating a new theme and ensuring all UI elements are compatible and visually appealing in dark mode.\n\n### Option C:\n**Feature Title:** The Feedback Fortress: User Voice Integration\n**Description:** Implement a dedicated in-app feedback system (e.g., using a third-party SDK or building a custom solution) to collect user suggestions, bug reports, and feature requests. This also involves establishing a clear process for reviewing, prioritizing, and responding to user feedback, including a public roadmap.\n\n### Score Each Option:\n\n**Option A: Bug Squashing Bonanza**\n*   Originality (1–10): 4 (Standard bug fix sprint)\n*   Feasibility (1–10): 9 (Relatively straightforward, requires dedicated resources)\n*   Impact (1–10): 10 (Addresses critical blockers, directly improves usability)\n\n**Option B: Dark Mode Dawn**\n*   Originality (1–10): 3 (Common feature request)\n*   Feasibility (1–10): 7 (Depends on UI framework; can be complex for large apps)\n*   Impact (1–10): 6 (Improves user experience, but doesn't address critical bugs)\n\n**Option C: The Feedback Fortress**\n*   Originality (1–10): 6 (Integrates feedback collection and response)\n*   Feasibility (1–10): 8 (Can leverage existing SDKs, but requires process changes)\n*   Impact (1–10): 8 (Improves user satisfaction, builds trust, informs future development)\n\n### Final Picks & Why:\n\n**Primary Pick: Option A: Bug Squashing Bonanza**\n\n**Justification:** While all three options have merit, addressing the critical bugs affecting task completion and reminders is paramount. These bugs are severe blockers that prevent users from effectively using the app. Fixing these issues should be the top priority to ensure a stable and reliable user experience. While the other options are valuable, they are secondary to resolving these fundamental problems. After the bugs are fixed, implementing the feedback system from option C would be the next logical step.\n",
#  'prioritization': 'Okay, here\'s the ICE score evaluation for each feature, followed by the sorted table and the rationale:\n\n**ICE Score Calculation and Table**\n\nFirst, we need to translate the "Originality," "Feasibility," and "Impact" scores into the ICE framework\'s "Impact," "Confidence," and "Effort" categories, respectively.  We\'ll assume:\n\n*   **Impact:** Directly uses the given "Impact" score.\n*   **Confidence:** Uses the given "Feasibility" score.  The more feasible, the more confident we are in the estimate.\n*   **Effort:** Uses the given "Originality" score. The more original, the more effort it takes.\n\nUsing these assumptions, we can create the ICE scores:\n\n**Option A: Bug Squashing Bonanza**\n\n*   Impact: 10\n*   Confidence: 9\n*   Effort: 4\n*   ICE Score: (10 * 9) / 4 = 22.5\n\n**Option B: Dark Mode Dawn**\n\n*   Impact: 6\n*   Confidence: 7\n*   Effort: 3\n*   ICE Score: (6 * 7) / 3 = 14.0\n\n**Option C: The Feedback Fortress**\n\n*   Impact: 8\n*   Confidence: 8\n*   Effort: 6\n*   ICE Score: (8 * 8) / 6 = 10.67\n\n**Sorted Table:**\n\n| Feature | Impact | Confidence | Effort | ICE Score |\n|---------|--------|------------|--------|------------|\n| Bug Squashing Bonanza | 10 | 9 | 4 | 22.5 |\n| Dark Mode Dawn | 6 | 7 | 3 | 14.0 |\n| The Feedback Fortress | 8 | 8 | 6 | 10.67 |\n\n**Decision-Making Rationale:**\n\nThe ICE scoring model confirms the initial assessment. "Bug Squashing Bonanza" has the highest ICE score by a significant margin. This is primarily due to its high impact (addressing critical bugs) and relatively low effort (a dedicated sprint). While "Dark Mode Dawn" is a desirable feature and has a decent ICE score, it doesn\'t address the fundamental usability issues that the bug fixes will resolve. "The Feedback Fortress" has the lowest ICE score, indicating that while valuable, it\'s less impactful and requires more effort compared to the other two options.\n\nTherefore, the recommended prioritization remains:\n\n1.  **Bug Squashing Bonanza:** Fix the critical bugs affecting task completion and reminders.\n2.  **Dark Mode Dawn:** Implement the dark mode feature to improve user experience.\n3.  **The Feedback Fortress:** Implement the in-app feedback system to gather user insights and improve the product roadmap.\n',
#  'okr': 'Okay, here\'s a SMART OKR based on the "Bug Squashing Bonanza" feature, aiming for a specific, measurable, achievable, relevant, and time-bound goal:\n\nObjective: Stabilize core task and reminder functionality for improved user experience.\n- Key Result 1: Reduce task completion error reports by 75% by end of Q3 (baseline: average of last 3 months).\n- Key Result 2: Decrease reminder notification failure rate to below 1% by end of Q3 (baseline: current 5%).\n- Key Result 3: Achieve a 4.5-star average rating for task management features in app store reviews by end of Q3 (currently 4.0 stars).\n'}

# %%
# Define criteria
criteria = "Clarity, Depth, Relevance, Innovation, Coherence"

# Evaluate
sequential_scores_raw = {
    agent: evaluator.evaluate(output, criteria)
    for agent, output in multi_results.items()
}

# Extract numeric scores
def extract_score(text):
    match = re.search(r'(\d(?:\.\d)?)', text)
    return float(match.group(1)) if match else None

sequential_numeric_scores = {
    agent: extract_score(score) for agent, score in sequential_scores_raw.items()
}

# Create DataFrame
df_seq = pd.DataFrame({
    "Agent": list(sequential_numeric_scores.keys()),
    "Sequential Score": list(sequential_numeric_scores.values())
})

# %%
# Merge with flat
df_combined = df_flat.copy()
df_combined = df_combined.merge(df_seq, on="Agent", how="left")
display(df_combined)
# Out:
#             Agent  Agent_flat    PromptStyle  \
# 0       sentiment         5.0       One-Shot
# 1        feedback         3.0       Few-Shot
# 2           issue         4.0            CoT
# 3      competitor         5.0          ReAct
# 4        ideation         5.0            ToT
# 5  prioritization         5.0  CoT + Scoring
# 6             okr         4.0       Few-Shot
#
#                                                  Description  Sequential Score
# 0              Classifies sentiment using One-Shot prompting               4.0
# 1          Summarizes user feedback using Few-Shot prompting               4.0
# 2  Detects product blockers using Chain-of-Thought reasoning               4.5
# 3                 Analyzes competition using ReAct prompting               5.0
# 4          Generates features with Tree-of-Thought prompting               4.0
# 5                  Ranks features using ICE scoring with CoT               5.0
# 6                Creates SMART OKRs using Few-Shot prompting               5.0

# %%
# Rebuild chart from this table
df_chart = df_combined[["Agent", "Agent_flat", "Sequential Score"]].melt(
    id_vars="Agent", var_name="Architecture", value_name="Score"
)
df_chart["Architecture"] = df_chart["Architecture"].replace({
    "Agent_flat": "Flat", 
    "Sequential Score": "Sequential"
})

# Custom color palette
palette = {
    "Flat": "#a3c9f1",         # Light blue
    "Sequential": "#3b76c4"    # Dark blue
}

# Plot the comparison bar chart
plt.figure(figsize=(12, 6))
sns.barplot(data=df_chart, x="Agent", y="Score", hue="Architecture", palette=palette)
plt.title("Multi-Agent Evaluation: Flat vs Sequential")
plt.ylim(0, 5)
plt.ylabel("Evaluation Score (1–5)")
plt.grid(True, axis="y", linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# 📌 Final Thoughts
# From the chart, it's clear that the sequential multi-agent setup excels in more analytical tasks, particularly in OKR generation and issue detection with root cause analysis. However, since I ran the self-evaluation function multiple times and received slightly different scores each time, the reliability of this evaluation could be improved. It may be worth refining the evaluation prompt itself for more consistent results.
#
# But then again — this is the nature of GenAI: a never-ending loop of experimentation and improvement! :))
#
# Thanks for reading.
# Best.
# Donna

# %% [markdown]
# ## 🚀 Nextify Interactive Dashboard
#
# You can explore the full prompt evaluation, LLM comparison, and multi-agent prototype here:
#
# 🔗 [[Open the Live Nextify Dashboard](http://nextify-dashboard-100.streamlit.app/))
